# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# %%
file = r"C:\Users\PcLaptop\Documents\GitHub\APlanet\Pilot_1\Rearrange_datasets\all_Madrid.xlsx"

xl1= pd.ExcelFile(file)      # Load spreadsheet
df1 = xl1.parse('Sheet1')    # Load a sheet into a DataFrame by name: df1
df1.index  = np.arange(len(df1))
df1 = df1.drop(columns=['Unnamed: 0'])

# %%
num_participants = len(df1)
num_participants
# Out:
# 181

# %%
#show all columns
pd.set_option('display.max_columns', None)
df1.head()
# Out:
#    participant.id_in_session  mod participant.code  \
# 0                          2    2         iu9re9u5
# 1                          4    4         76mq2acd
# 2                          5    1         n6c69l1z
# 3                          8    4         p7eprbp3
# 4                         11    3         epujf994
#
#            participant.time_started  player.inequality_perception  \
# 0  2022-07-18 13:56:52.428815+00:00                             3
# 1  2022-07-18 21:47:35.300273+00:00                             3
# 2  2022-07-18 22:45:11.140948+00:00                             3
# 3  2022-07-18 10:05:54.744504+00:00                             2
# 4  2022-07-18 10:53:49.868989+00:00                             3
#
#   What type of society do you think is Spain today – which diagram comes the closest?  \
# 0                                                  C
# 1                                                  C
# 2                                                  C
# 3                                                  B
# 4                                                  C
#
#    player.inequality_wish  \
# 0                       4
# 1                       4
# 2                       4
# 3                       5
# 4                       4
#
#   What do you think Spain ought to be like – which would you prefer?  \
# 0                                                  D
# 1                                                  D
# 2                                                  D
# 3                                                  E
# 4                                                  D
#
#    player.income_distribution  \
# 0                           3
# 1                           3
# 2                           2
# 3                           3
# 4                           4
#
#   How fair do you think the wealth distribution is in your country?  \
# 0                                             Unfair
# 1                                             Unfair
# 2                                               Fair
# 3                                             Unfair
# 4                                        Very unfair
#
#    player.postal_code The participant lives in Madrid:  \
# 0               28028                              Yes
# 1               28041                              Yes
# 2               28033                              Yes
# 3               28031                              Yes
# 4               28039                              Yes
#
#    player.driving_license Do you have a driver license?  player.access_to_car  \
# 0                       1                           Yes                     0
# 1                       1                           Yes                     1
# 2                       1                           Yes                     0
# 3                       1                           Yes                     1
# 4                       1                           Yes                     1
#
#   Do you own or have access to a car?  player.car_type  \
# 0                               I own              1.0
# 1    I do not own, but have access to              0.0
# 2                               I own              0.0
# 3    I do not own, but have access to              1.0
# 4    I do not own, but have access to              1.0
#
#   What kind of vehicle do you have access to? If you have access to multiple vehicles choose the one you use the most.  \
# 0                                             Diesel
# 1                                           Gasoline
# 2                                           Gasoline
# 3                                             Diesel
# 4                                             Diesel
#
#    player.access_to_bike  \
# 0                      2
# 1                      0
# 2                      2
# 3                      0
# 4                      0
#
#   Do you own or have access to a bike (electric or regular)?  \
# 0                            I do not have access to
# 1                                              I own
# 2                            I do not have access to
# 3                                              I own
# 4                                              I own
#
#    player.access_to_motorbyke Do you own or have access to a motorbyke?  \
# 0                           2                   I do not have access to
# 1                           2                   I do not have access to
# 2                           2                   I do not have access to
# 3                           2                   I do not have access to
# 4                           2                   I do not have access to
#
#    player.access_to_scooter Do you own or have access to a e-scooter?  \
# 0                         2                   I do not have access to
# 1                         2                   I do not have access to
# 2                         2                   I do not have access to
# 3                         2                   I do not have access to
# 4                         2                   I do not have access to
#
#    player.employ_status What is your employment status?  \
# 0                     2                         Student
# 1                     0                Full-time worker
# 2                     0                Full-time worker
# 3                     0                Full-time worker
# 4                     0                Full-time worker
#
#   player.trip_destination  player.trip_purpose  \
# 0                  Madrid                    1
# 1                  GETAFE                    0
# 2                 Pozuelo                    0
# 3     Madrid (Las Tablas)                    0
# 4                  Úbeda                     5
#
#   What is the purpose/destination of this trip? player.trip_other  \
# 0                               Education place               NaN
# 1                                     Workplace               NaN
# 2                                     Workplace               NaN
# 3                                     Workplace               NaN
# 4                        Visit family or friend               NaN
#
#    player.trip_moment At what time of the day do you typically travel?  \
# 0                   0                                          morning
# 1                   0                                          morning
# 2                   0                                          morning
# 3                   0                                          morning
# 4                   2                                          evening
#
#    player.trip_mode  \
# 0                 2
# 1                 0
# 2                 0
# 3                 4
# 4                 4
#
#   By which mode do you travel with during this trip? If you travel with multiple modes choose the mode that takes you the longest time.  \
# 0                                                Bus
# 1                               Private car (driver)
# 2                               Private car (driver)
# 3                                              Train
# 4                                              Train
#
#   player.mode_other  player.trip_traffic  \
# 0               NaN                    1
# 1               NaN                    1
# 2               NaN                    2
# 3               NaN                    1
# 4               NaN                    1
#
#   How are the traffic conditions normally on the trip?  player.trip_time  \
# 0                                 Somewhat congested                   1
# 1                                 Somewhat congested                   0
# 2                             Little or no congested                   1
# 3                                 Somewhat congested                   2
# 4                                 Somewhat congested                   4
#
#   What is the approximate travel time of this trip (one way)?  \
# 0                                      20-39 minutes
# 1                                      10-19 minutes
# 2                                      20-39 minutes
# 3                                      40-59 minutes
# 4                                  more than 2 hours
#
#    player.trip_cost  \
# 0                 0
# 1                 1
# 2                 2
# 3                 1
# 4                 5
#
#   What is the approximate cost of this trip (fuel, road tolls, parking, ticket price etc.), one way? If you are traveling by public transport and have a period ticket, please consider the average price per trip.  \
# 0                                    less than 1 EUR
# 1                                          1-2.5 EUR
# 2                                       2.5-4.99 EUR
# 3                                          1-2.5 EUR
# 4                                   More than 20 EUR
#
#    player.trip_alternative_mode  \
# 0                             1
# 1                             1
# 2                             4
# 3                             0
# 4                             1
#
#   If you were to make this trip using a different mode of travel than your usual mode, which would be the best alternative?  \
# 0                            Private car (passenger)
# 1                            Private car (passenger)
# 2                                              Train
# 3                               Private car (driver)
# 4                            Private car (passenger)
#
#    player.trip_alternative_rate   How would you rate your alternative?  \
# 0                             2      Much worse than my current choice
# 1                             1  Somewhat worse than my current choice
# 2                             2      Much worse than my current choice
# 3                             0    Almost as good as my current choice
# 4                             0    Almost as good as my current choice
#
#    player.trip_alternative_justification  player.control_question  \
# 0                                    NaN                        3
# 1                                    NaN                        3
# 2                                    NaN                        3
# 3                                    NaN                        3
# 4                                    NaN                        3
#
#   Answer to control question:  player.alternative1  \
# 0                     Correct                    4
# 1                     Correct                    5
# 2                     Correct                    5
# 3                     Correct                    4
# 4                     Correct                    4
#
#                                        Alternative 1  player.alternative2  \
# 0                               Investments in roads                    2
# 1  Investments in public transport, walking and c...                    4
# 2  Investments in public transport, walking and c...                    4
# 3                               Investments in roads                    5
# 4                               Investments in roads                    5
#
#                                        Alternative 2  player.alternative3  \
# 0                                Equal cash transfer                    5
# 1                               Investments in roads                    2
# 2                               Investments in roads                    1
# 3  Investments in public transport, walking and c...                    3
# 4  Investments in public transport, walking and c...                    1
#
#                                        Alternative 3  player.alternative4  \
# 0  Investments in public transport, walking and c...                    1
# 1                                Equal cash transfer                    3
# 2                                     General budget                    3
# 3              Cash transfer for low-income citizens                    1
# 4                                     General budget                    3
#
#                            Alternative 4  player.alternative5  \
# 0                         General budget                    3
# 1  Cash transfer for low-income citizens                    1
# 2  Cash transfer for low-income citizens                    2
# 3                         General budget                    2
# 4  Cash transfer for low-income citizens                    2
#
#                            Alternative 5  1_policy_choice  \
# 0  Cash transfer for low-income citizens                1
# 1                         General budget                1
# 2                    Equal cash transfer                2
# 3                    Equal cash transfer                3
# 4                    Equal cash transfer                2
#
#    1_What is your preferred policy type?  1_Price_UR_A  \
# 0                                      A             2
# 1                                      A             4
# 2                                      B             3
# 3  None of them, keep the current system             2
# 4                                      B             3
#
#   1_A_Price in urban areas, rush hour  1_Price_UN_A  \
# 0                            0.20 EUR             2
# 1                            0.50 EUR             4
# 2                            0.40 EUR             3
# 3                            0.20 EUR             1
# 4                            0.40 EUR             3
#
#   1_A_Price in urban areas, outside rush hour  1_Price_O_A  \
# 0                                    0.20 EUR            2
# 1                                    0.50 EUR            4
# 2                                    0.40 EUR            4
# 3                                    0.10 EUR            1
# 4                                    0.40 EUR            3
#
#   1_A_Price outside urban areas  1_EV_A 1_A_Price for electric vehicles  \
# 0                      0.02 EUR       2                        0.02 EUR
# 1                      0.05 EUR       3                        0.03 EUR
# 2                      0.05 EUR       3                        0.03 EUR
# 3                      0.01 EUR       3                        0.03 EUR
# 4                      0.03 EUR       3                        0.03 EUR
#
#    1_Revenue_A                                 1_A_Use of revenue  \
# 0            3              Cash transfer for low-income citizens
# 1            5  Investments in public transport, walking and c...
# 2            4                               Investments in roads
# 3            2                                Equal cash transfer
# 4            1                                     General budget
#
#    1_Price_UR_B 1_B_Price in urban areas, rush hour  1_Price_UN_B  \
# 0             3                            0.40 EUR             2
# 1             4                            0.50 EUR             4
# 2             4                            0.50 EUR             3
# 3             4                            0.50 EUR             1
# 4             3                            0.40 EUR             3
#
#   1_B_Price in urban areas, outside rush hour  1_Price_O_B  \
# 0                                    0.20 EUR            4
# 1                                    0.50 EUR            4
# 2                                    0.40 EUR            2
# 3                                    0.10 EUR            3
# 4                                    0.40 EUR            3
#
#   1_B_Price outside urban areas  1_EV_B 1_B_Price for electric vehicles  \
# 0                      0.05 EUR       2                        0.02 EUR
# 1                      0.05 EUR       3                        0.03 EUR
# 2                      0.02 EUR       2                        0.02 EUR
# 3                      0.03 EUR       4                        0.05 EUR
# 4                      0.03 EUR       4                        0.05 EUR
#
#    1_Revenue_B                                 1_B_Use of revenue  \
# 0            5  Investments in public transport, walking and c...
# 1            2                                Equal cash transfer
# 2            5  Investments in public transport, walking and c...
# 3            1                                     General budget
# 4            5  Investments in public transport, walking and c...
#
#    2_policy_choice 2_What is your preferred policy type?  2_Price_UR_A  \
# 0                1                                     A             3
# 1                2                                     B             4
# 2                2                                     B             2
# 3                2                                     B             3
# 4                2                                     B             3
#
#   2_A_Price in urban areas, rush hour  2_Price_UN_A  \
# 0                            0.40 EUR             3
# 1                            0.50 EUR             4
# 2                            0.20 EUR             1
# 3                            0.40 EUR             3
# 4                            0.40 EUR             2
#
#   2_A_Price in urban areas, outside rush hour  2_Price_O_A  \
# 0                                    0.40 EUR            2
# 1                                    0.50 EUR            1
# 2                                    0.10 EUR            2
# 3                                    0.40 EUR            3
# 4                                    0.20 EUR            4
#
#   2_A_Price outside urban areas  2_EV_A 2_A_Price for electric vehicles  \
# 0                      0.02 EUR       4                        0.05 EUR
# 1                      0.01 EUR       1                        0.01 EUR
# 2                      0.02 EUR       3                        0.03 EUR
# 3                      0.03 EUR       1                        0.01 EUR
# 4                      0.05 EUR       2                        0.02 EUR
#
#    2_Revenue_A                                 2_A_Use of revenue  \
# 0            2                                Equal cash transfer
# 1            3              Cash transfer for low-income citizens
# 2            2                                Equal cash transfer
# 3            2                                Equal cash transfer
# 4            5  Investments in public transport, walking and c...
#
#    2_Price_UR_B 2_B_Price in urban areas, rush hour  2_Price_UN_B  \
# 0             4                            0.50 EUR             3
# 1             2                            0.20 EUR             2
# 2             3                            0.40 EUR             3
# 3             2                            0.20 EUR             1
# 4             2                            0.20 EUR             2
#
#   2_B_Price in urban areas, outside rush hour  2_Price_O_B  \
# 0                                    0.40 EUR            3
# 1                                    0.20 EUR            3
# 2                                    0.40 EUR            3
# 3                                    0.10 EUR            2
# 4                                    0.20 EUR            2
#
#   2_B_Price outside urban areas  2_EV_B 2_B_Price for electric vehicles  \
# 0                      0.03 EUR       2                        0.02 EUR
# 1                      0.03 EUR       2                        0.02 EUR
# 2                      0.03 EUR       1                        0.01 EUR
# 3                      0.02 EUR       3                        0.03 EUR
# 4                      0.02 EUR       2                        0.02 EUR
#
#    2_Revenue_B                     2_B_Use of revenue  3_policy_choice  \
# 0            4                   Investments in roads                1
# 1            1                         General budget                1
# 2            2                    Equal cash transfer                2
# 3            2                    Equal cash transfer                2
# 4            3  Cash transfer for low-income citizens                1
#
#   3_What is your preferred policy type?  3_Price_UR_A  \
# 0                                     A             1
# 1                                     A             2
# 2                                     B             2
# 3                                     B             1
# 4                                     A             1
#
#   3_A_Price in urban areas, rush hour  3_Price_UN_A  \
# 0                            0.10 EUR             1
# 1                            0.20 EUR             2
# 2                            0.20 EUR             2
# 3                            0.10 EUR             1
# 4                            0.10 EUR             1
#
#   3_A_Price in urban areas, outside rush hour  3_Price_O_A  \
# 0                                    0.10 EUR            1
# 1                                    0.20 EUR            2
# 2                                    0.20 EUR            2
# 3                                    0.10 EUR            1
# 4                                    0.10 EUR            2
#
#   3_A_Price outside urban areas  3_EV_A 3_A_Price for electric vehicles  \
# 0                      0.01 EUR       4                        0.05 EUR
# 1                      0.02 EUR       3                        0.03 EUR
# 2                      0.02 EUR       2                        0.02 EUR
# 3                      0.01 EUR       4                        0.05 EUR
# 4                      0.02 EUR       2                        0.02 EUR
#
#    3_Revenue_A                                 3_A_Use of revenue  \
# 0            3              Cash transfer for low-income citizens
# 1            4                               Investments in roads
# 2            1                                     General budget
# 3            2                                Equal cash transfer
# 4            5  Investments in public transport, walking and c...
#
#    3_Price_UR_B 3_B_Price in urban areas, rush hour  3_Price_UN_B  \
# 0             1                            0.10 EUR             1
# 1             2                            0.20 EUR             2
# 2             2                            0.20 EUR             2
# 3             3                            0.40 EUR             3
# 4             4                            0.50 EUR             3
#
#   3_B_Price in urban areas, outside rush hour  3_Price_O_B  \
# 0                                    0.10 EUR            1
# 1                                    0.20 EUR            2
# 2                                    0.20 EUR            2
# 3                                    0.40 EUR            3
# 4                                    0.40 EUR            4
#
#   3_B_Price outside urban areas  3_EV_B 3_B_Price for electric vehicles  \
# 0                      0.01 EUR       3                        0.03 EUR
# 1                      0.02 EUR       2                        0.02 EUR
# 2                      0.02 EUR       2                        0.02 EUR
# 3                      0.03 EUR       3                        0.03 EUR
# 4                      0.05 EUR       2                        0.02 EUR
#
#    3_Revenue_B                                 3_B_Use of revenue  \
# 0            5  Investments in public transport, walking and c...
# 1            2                                Equal cash transfer
# 2            4                               Investments in roads
# 3            5  Investments in public transport, walking and c...
# 4            4                               Investments in roads
#
#    4_policy_choice 4_What is your preferred policy type?  4_Price_UR_A  \
# 0                1                                     A             3
# 1                2                                     B             4
# 2                2                                     B             3
# 3                2                                     B             4
# 4                2                                     B             4
#
#   4_A_Price in urban areas, rush hour  4_Price_UN_A  \
# 0                            0.40 EUR             3
# 1                            0.50 EUR             4
# 2                            0.40 EUR             3
# 3                            0.50 EUR             3
# 4                            0.50 EUR             4
#
#   4_A_Price in urban areas, outside rush hour  4_Price_O_A  \
# 0                                    0.40 EUR            3
# 1                                    0.50 EUR            4
# 2                                    0.40 EUR            3
# 3                                    0.40 EUR            2
# 4                                    0.50 EUR            4
#
#   4_A_Price outside urban areas  4_EV_A 4_A_Price for electric vehicles  \
# 0                      0.03 EUR       4                        0.05 EUR
# 1                      0.05 EUR       3                        0.03 EUR
# 2                      0.03 EUR       2                        0.02 EUR
# 3                      0.02 EUR       2                        0.02 EUR
# 4                      0.05 EUR       3                        0.03 EUR
#
#    4_Revenue_A                                 4_A_Use of revenue  \
# 0            5  Investments in public transport, walking and c...
# 1            3              Cash transfer for low-income citizens
# 2            3              Cash transfer for low-income citizens
# 3            5  Investments in public transport, walking and c...
# 4            2                                Equal cash transfer
#
#    4_Price_UR_B 4_B_Price in urban areas, rush hour  4_Price_UN_B  \
# 0             3                            0.40 EUR             3
# 1             1                            0.10 EUR             1
# 2             3                            0.40 EUR             3
# 3             3                            0.40 EUR             3
# 4             2                            0.20 EUR             2
#
#   4_B_Price in urban areas, outside rush hour  4_Price_O_B  \
# 0                                    0.40 EUR            3
# 1                                    0.10 EUR            1
# 2                                    0.40 EUR            3
# 3                                    0.40 EUR            4
# 4                                    0.20 EUR            2
#
#   4_B_Price outside urban areas  4_EV_B 4_B_Price for electric vehicles  \
# 0                      0.03 EUR       3                        0.03 EUR
# 1                      0.01 EUR       2                        0.02 EUR
# 2                      0.03 EUR       1                        0.01 EUR
# 3                      0.05 EUR       3                        0.03 EUR
# 4                      0.02 EUR       1                        0.01 EUR
#
#    4_Revenue_B                                 4_B_Use of revenue  \
# 0            1                                     General budget
# 1            5  Investments in public transport, walking and c...
# 2            2                                Equal cash transfer
# 3            4                               Investments in roads
# 4            4                               Investments in roads
#
#    5_policy_choice  5_What is your preferred policy type?  5_Price_UR_A  \
# 0                3  None of them, keep the current system             4
# 1                2                                      B             2
# 2                2                                      B             2
# 3                2                                      B             3
# 4                1                                      A             3
#
#   5_A_Price in urban areas, rush hour  5_Price_UN_A  \
# 0                            0.50 EUR             4
# 1                            0.20 EUR             2
# 2                            0.20 EUR             1
# 3                            0.40 EUR             3
# 4                            0.40 EUR             3
#
#   5_A_Price in urban areas, outside rush hour  5_Price_O_A  \
# 0                                    0.50 EUR            4
# 1                                    0.20 EUR            3
# 2                                    0.10 EUR            1
# 3                                    0.40 EUR            3
# 4                                    0.40 EUR            2
#
#   5_A_Price outside urban areas  5_EV_A 5_A_Price for electric vehicles  \
# 0                      0.05 EUR       3                        0.03 EUR
# 1                      0.03 EUR       4                        0.05 EUR
# 2                      0.01 EUR       3                        0.03 EUR
# 3                      0.03 EUR       1                        0.01 EUR
# 4                      0.02 EUR       4                        0.05 EUR
#
#    5_Revenue_A   5_A_Use of revenue  5_Price_UR_B  \
# 0            2  Equal cash transfer             2
# 1            1       General budget             4
# 2            2  Equal cash transfer             4
# 3            2  Equal cash transfer             3
# 4            2  Equal cash transfer             4
#
#   5_B_Price in urban areas, rush hour  5_Price_UN_B  \
# 0                            0.20 EUR             2
# 1                            0.50 EUR             2
# 2                            0.50 EUR             1
# 3                            0.40 EUR             3
# 4                            0.50 EUR             3
#
#   5_B_Price in urban areas, outside rush hour  5_Price_O_B  \
# 0                                    0.20 EUR            2
# 1                                    0.20 EUR            2
# 2                                    0.10 EUR            3
# 3                                    0.40 EUR            3
# 4                                    0.40 EUR            3
#
#   5_B_Price outside urban areas  5_EV_B 5_B_Price for electric vehicles  \
# 0                      0.02 EUR       1                        0.01 EUR
# 1                      0.02 EUR       4                        0.05 EUR
# 2                      0.03 EUR       4                        0.05 EUR
# 3                      0.03 EUR       2                        0.02 EUR
# 4                      0.03 EUR       2                        0.02 EUR
#
#    5_Revenue_B                     5_B_Use of revenue  6_policy_choice  \
# 0            4                   Investments in roads                2
# 1            3  Cash transfer for low-income citizens                1
# 2            1                         General budget                1
# 3            3  Cash transfer for low-income citizens                1
# 4            4                   Investments in roads                2
#
#   6_What is your preferred policy type?  6_Price_UR_A  \
# 0                                     B             4
# 1                                     A             3
# 2                                     A             3
# 3                                     A             2
# 4                                     B             1
#
#   6_A_Price in urban areas, rush hour  6_Price_UN_A  \
# 0                            0.50 EUR             3
# 1                            0.40 EUR             3
# 2                            0.40 EUR             3
# 3                            0.20 EUR             2
# 4                            0.10 EUR             1
#
#   6_A_Price in urban areas, outside rush hour  6_Price_O_A  \
# 0                                    0.40 EUR            4
# 1                                    0.40 EUR            1
# 2                                    0.40 EUR            3
# 3                                    0.20 EUR            2
# 4                                    0.10 EUR            1
#
#   6_A_Price outside urban areas  6_EV_A 6_A_Price for electric vehicles  \
# 0                      0.05 EUR       2                        0.02 EUR
# 1                      0.01 EUR       1                        0.01 EUR
# 2                      0.03 EUR       3                        0.03 EUR
# 3                      0.02 EUR       2                        0.02 EUR
# 4                      0.01 EUR       4                        0.05 EUR
#
#    6_Revenue_A                                 6_A_Use of revenue  \
# 0            4                               Investments in roads
# 1            5  Investments in public transport, walking and c...
# 2            5  Investments in public transport, walking and c...
# 3            4                               Investments in roads
# 4            3              Cash transfer for low-income citizens
#
#    6_Price_UR_B 6_B_Price in urban areas, rush hour  6_Price_UN_B  \
# 0             1                            0.10 EUR             1
# 1             4                            0.50 EUR             3
# 2             1                            0.10 EUR             1
# 3             2                            0.20 EUR             2
# 4             1                            0.10 EUR             1
#
#   6_B_Price in urban areas, outside rush hour  6_Price_O_B  \
# 0                                    0.10 EUR            2
# 1                                    0.40 EUR            4
# 2                                    0.10 EUR            1
# 3                                    0.20 EUR            2
# 4                                    0.10 EUR            1
#
#   6_B_Price outside urban areas  6_EV_B 6_B_Price for electric vehicles  \
# 0                      0.02 EUR       2                        0.02 EUR
# 1                      0.05 EUR       1                        0.01 EUR
# 2                      0.01 EUR       4                        0.05 EUR
# 3                      0.02 EUR       2                        0.02 EUR
# 4                      0.01 EUR       3                        0.03 EUR
#
#    6_Revenue_B                                 6_B_Use of revenue  \
# 0            5  Investments in public transport, walking and c...
# 1            1                                     General budget
# 2            2                                Equal cash transfer
# 3            1                                     General budget
# 4            5  Investments in public transport, walking and c...
#
#    player.SN_car_A Considering the following transport mode group:  player.EE  \
# 0                1                              A: Private vehicle         10
# 1                1                              A: Private vehicle         43
# 2                1                              A: Private vehicle         80
# 3                1                              A: Private vehicle         40
# 4                1                              A: Private vehicle         35
#
#   What share (in %) of other participants in the survey do you think have chosen one of the transport modes in A for their daily trip?  \
# 0                                              10.0%
# 1                                              43.0%
# 2                                              80.0%
# 3                                              40.0%
# 4                                              35.0%
#
#    player.PNB  \
# 0           0
# 1          33
# 2          90
# 3          25
# 4           5
#
#   In your opinion, what should the ideal percentage of people using transport modes in A for their daily trip be?  \
# 0                                               0.0%
# 1                                              33.0%
# 2                                              90.0%
# 3                                              25.0%
# 4                                               5.0%
#
#    player.NE  \
# 0          5
# 1          5
# 2         50
# 3         10
# 4          5
#
#   What share (in %) of other participants in the survey do you think have mostly chosen option A (answered more than 50%) in the previous question?  \
# 0                                               5.0%
# 1                                               5.0%
# 2                                              50.0%
# 3                                              10.0%
# 4                                               5.0%
#
#    player.my_trip  \
# 0              90
# 1              75
# 2              40
# 3             100
# 4              75
#
#   Considering the last year, how often (in %) did you use your chosen transport mode for your daily trip?  \
# 0                                                90%
# 1                                                75%
# 2                                                40%
# 3                                               100%
# 4                                                75%
#
#    player.HH  \
# 0        100
# 1         75
# 2          1
# 3         25
# 4          5
#
#   Imagine that most of the people answering this survey say that they use option A for their daily trip and that most of them think that other people should also use option A. How often (in %) would you use option A in this scenario?  \
# 0                                               100%
# 1                                                75%
# 2                                                 1%
# 3                                                25%
# 4                                                 5%
#
#    player.HL  \
# 0        100
# 1         75
# 2          1
# 3         25
# 4          5
#
#   Imagine that most of the people answering this survey say that they use option A for their daily trip and that most of them think that other people should use option B. How often (in %) would you use option A in this scenario?  \
# 0                                               100%
# 1                                                75%
# 2                                                 1%
# 3                                                25%
# 4                                                 5%
#
#    player.LH  \
# 0        100
# 1         75
# 2          2
# 3         25
# 4          5
#
#   Imagine that most of the people answering this survey say that they use option B for their daily trip and that most of them think that other people should use option A. How often (in %) would you use option A in this scenario?  \
# 0                                               100%
# 1                                                75%
# 2                                                 2%
# 3                                                25%
# 4                                                 5%
#
#    player.LL  \
# 0        100
# 1         75
# 2         20
# 3         25
# 4          5
#
#   Imagine that most of the people answering this survey say that they use option B for their daily trip and that most of them also think that other people should use option B. How often (in %) would you use option A in this scenario?  \
# 0                                               100%
# 1                                                75%
# 2                                                20%
# 3                                                25%
# 4                                                 5%
#
#    player.year_born  Which year were you born?  player.gender  \
# 0              1999                       1999              1
# 1              1998                       1998              1
# 2              1998                       1998              0
# 3              2000                       2000              1
# 4              1996                       1996              1
#
#   How do you identify as?  player.education  \
# 0                     man                 1
# 1                     man                 3
# 2                   woman                 2
# 3                     man                 3
# 4                     man                 1
#
#   What is your highest level of education?  player.income  \
# 0                              high school              5
# 1           university (more than 4 years)              2
# 2           university (less than 4 years)              0
# 3           university (more than 4 years)              2
# 4                              high school              0
#
#   What is your income per year?  player.family  \
# 0             prefer not to say              3
# 1                   20k-30k EUR              1
# 2             less than 10k EUR              4
# 3                   20k-30k EUR              4
# 4             less than 10k EUR              4
#
#    How many people does your household have including you?  player.children  \
# 0                                                  3                      0
# 1                                                  1                      0
# 2                                                  4                      0
# 3                                                  4                      0
# 4                                                  4                      0
#
#    How many children under the age of 15 live with you?  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    player.trust_parlament  \
# 0                       1
# 1                       3
# 2                       4
# 3                       4
# 4                       4
#
#   How much do you personally trust the following institutions from 1 to 7, where 1 means ‘No trust at all’ and 7 means ‘Trust compltely’? Parlament:   \
# 0                                                  1
# 1                                                  3
# 2                                                  4
# 3                                                  4
# 4                                                  4
#
#    player.trust_county County council:  player.trust_municipality  \
# 0                    1               1                          1
# 1                    4               4                          4
# 2                    4               4                          5
# 3                    6               6                          5
# 4                    7               7                          6
#
#   Municipal council  player.trust_government Government:  \
# 0                 1                        1           1
# 1                 4                        4           4
# 2                 5                        2           2
# 3                 5                        2           2
# 4                 6                        1           1
#
#    player.trust_politicians National politicians:  player.trust_parties  \
# 0                         1                     1                     1
# 1                         3                     3                     2
# 2                         3                     3                     3
# 3                         3                     3                     2
# 4                         5                     5                     4
#
#   Political parties:   player.vote  \
# 0                   1           13
# 1                   2            9
# 2                   3            1
# 3                   2            1
# 4                   4            1
#
#   Which political party you voted for in the last election?  \
# 0                              prefiero no responder
# 1                                            MP-EQUO
# 2                                    Partido Popular
# 3                                    Partido Popular
# 4                                    Partido Popular
#
#    player.air_pollution  \
# 0                     3
# 1                     2
# 2                     5
# 3                     3
# 4                     6
#
#   How much do you agree with the following statements from 1 to 7, where 1 means ‘I completely disagree’ and 7 means ‘I completely agree’? Air pollution derived by cars is one of the major causes of premature death in Europe:  \
# 0                                                  3
# 1                                                  2
# 2                                                  5
# 3                                                  3
# 4                                                  6
#
#    player.road_pricing  \
# 0                    3
# 1                    4
# 2                    6
# 3                    5
# 4                    3
#
#   The introduction of policies such as road pricing will alleviate congestion problems:  \
# 0                                                  3
# 1                                                  4
# 2                                                  6
# 3                                                  5
# 4                                                  3
#
#    player.revenues  \
# 0                2
# 1                5
# 2                6
# 3                2
# 4                4
#
#   Revenues collected through taxes are used to create a well-functioning welfare state and society:  \
# 0                                                  2
# 1                                                  5
# 2                                                  6
# 3                                                  2
# 4                                                  4
#
#    player.tax Tax revenues should be used to help those who are more in need:  \
# 0           3                                                  3
# 1           3                                                  3
# 2           6                                                  6
# 3           5                                                  5
# 4           5                                                  5
#
#                                      player.comments  session.label  \
# 0                                            gracias            NaN
# 1                                       Buen trabajo            NaN
# 2                                      todo correcto            NaN
# 3                                                  .            NaN
# 4  Espero que no utilicen estos datos para aplica...            NaN
#
#    session.experimenter_name  session.time_scheduled  session.time_started  \
# 0                        NaN                     NaN                   NaN
# 1                        NaN                     NaN                   NaN
# 2                        NaN                     NaN                   NaN
# 3                        NaN                     NaN                   NaN
# 4                        NaN                     NaN                   NaN
#
#    session.mturk_HITId  session.mturk_HITGroupId  session.comment
# 0                  NaN                       NaN              NaN
# 1                  NaN                       NaN              NaN
# 2                  NaN                       NaN              NaN
# 3                  NaN                       NaN              NaN
# 4                  NaN                       NaN              NaN

# %%
column= df1.columns[9]
tab=df1.groupby([column]).count()*100/num_participants
tab=tab.loc[['Very fair', 'Fair', 'Unfair','Very unfair','I do not know']]
ax=tab.plot(kind='bar', y=1, title=column, figsize=(6,4), color='moccasin', edgecolor='k', legend=False)
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2, w_pad=5, h_pad=3)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\wealth_distrib.png')
plt.show()

# %%
#print all column names
df1
# Out:
#      participant.id_in_session  mod participant.code  \
# 0                            2    2         iu9re9u5
# 1                            4    4         76mq2acd
# 2                            5    1         n6c69l1z
# 3                            8    4         p7eprbp3
# 4                           11    3         epujf994
# ..                         ...  ...              ...
# 176                        293    1         k7q5nz72
# 177                        294    2         cqz7qq56
# 178                        295    3         0ledyfgt
# 179                        296    4         sh0t9561
# 180                        300    4         g6en7ef2
#
#              participant.time_started  player.inequality_perception  \
# 0    2022-07-18 13:56:52.428815+00:00                             3
# 1    2022-07-18 21:47:35.300273+00:00                             3
# 2    2022-07-18 22:45:11.140948+00:00                             3
# 3    2022-07-18 10:05:54.744504+00:00                             2
# 4    2022-07-18 10:53:49.868989+00:00                             3
# ..                                ...                           ...
# 176  2022-07-18 12:40:30.284504+00:00                             2
# 177  2022-07-18 09:56:53.980523+00:00                             3
# 178  2022-07-18 10:09:45.456843+00:00                             3
# 179  2022-07-18 09:58:09.254829+00:00                             2
# 180  2022-07-19 09:35:29.933572+00:00                             2
#
#     What type of society do you think is Spain today – which diagram comes the closest?  \
# 0                                                    C
# 1                                                    C
# 2                                                    C
# 3                                                    B
# 4                                                    C
# ..                                                 ...
# 176                                                  B
# 177                                                  C
# 178                                                  C
# 179                                                  B
# 180                                                  B
#
#      player.inequality_wish  \
# 0                         4
# 1                         4
# 2                         4
# 3                         5
# 4                         4
# ..                      ...
# 176                       4
# 177                       4
# 178                       4
# 179                       4
# 180                       5
#
#     What do you think Spain ought to be like – which would you prefer?  \
# 0                                                    D
# 1                                                    D
# 2                                                    D
# 3                                                    E
# 4                                                    D
# ..                                                 ...
# 176                                                  D
# 177                                                  D
# 178                                                  D
# 179                                                  D
# 180                                                  E
#
#      player.income_distribution  \
# 0                             3
# 1                             3
# 2                             2
# 3                             3
# 4                             4
# ..                          ...
# 176                           3
# 177                           2
# 178                           3
# 179                           4
# 180                           3
#
#     How fair do you think the wealth distribution is in your country?  \
# 0                                               Unfair
# 1                                               Unfair
# 2                                                 Fair
# 3                                               Unfair
# 4                                          Very unfair
# ..                                                 ...
# 176                                             Unfair
# 177                                               Fair
# 178                                             Unfair
# 179                                        Very unfair
# 180                                             Unfair
#
#      player.postal_code The participant lives in Madrid:  \
# 0                 28028                              Yes
# 1                 28041                              Yes
# 2                 28033                              Yes
# 3                 28031                              Yes
# 4                 28039                              Yes
# ..                  ...                              ...
# 176               28341                              Yes
# 177               28023                              Yes
# 178               28440                              Yes
# 179               28902                              Yes
# 180               28045                              Yes
#
#      player.driving_license Do you have a driver license?  \
# 0                         1                           Yes
# 1                         1                           Yes
# 2                         1                           Yes
# 3                         1                           Yes
# 4                         1                           Yes
# ..                      ...                           ...
# 176                       1                           Yes
# 177                       1                           Yes
# 178                       0                            No
# 179                       1                           Yes
# 180                       0                            No
#
#      player.access_to_car Do you own or have access to a car?  \
# 0                       0                               I own
# 1                       1    I do not own, but have access to
# 2                       0                               I own
# 3                       1    I do not own, but have access to
# 4                       1    I do not own, but have access to
# ..                    ...                                 ...
# 176                     0                               I own
# 177                     1    I do not own, but have access to
# 178                     1    I do not own, but have access to
# 179                     1    I do not own, but have access to
# 180                     1    I do not own, but have access to
#
#      player.car_type  \
# 0                1.0
# 1                0.0
# 2                0.0
# 3                1.0
# 4                1.0
# ..               ...
# 176              1.0
# 177              1.0
# 178              1.0
# 179              1.0
# 180              1.0
#
#     What kind of vehicle do you have access to? If you have access to multiple vehicles choose the one you use the most.  \
# 0                                               Diesel
# 1                                             Gasoline
# 2                                             Gasoline
# 3                                               Diesel
# 4                                               Diesel
# ..                                                 ...
# 176                                             Diesel
# 177                                             Diesel
# 178                                             Diesel
# 179                                             Diesel
# 180                                             Diesel
#
#      player.access_to_bike  \
# 0                        2
# 1                        0
# 2                        2
# 3                        0
# 4                        0
# ..                     ...
# 176                      0
# 177                      2
# 178                      2
# 179                      0
# 180                      1
#
#     Do you own or have access to a bike (electric or regular)?  \
# 0                              I do not have access to
# 1                                                I own
# 2                              I do not have access to
# 3                                                I own
# 4                                                I own
# ..                                                 ...
# 176                                              I own
# 177                            I do not have access to
# 178                            I do not have access to
# 179                                              I own
# 180                   I do not own, but have access to
#
#      player.access_to_motorbyke Do you own or have access to a motorbyke?  \
# 0                             2                   I do not have access to
# 1                             2                   I do not have access to
# 2                             2                   I do not have access to
# 3                             2                   I do not have access to
# 4                             2                   I do not have access to
# ..                          ...                                       ...
# 176                           2                   I do not have access to
# 177                           2                   I do not have access to
# 178                           2                   I do not have access to
# 179                           2                   I do not have access to
# 180                           2                   I do not have access to
#
#      player.access_to_scooter Do you own or have access to a e-scooter?  \
# 0                           2                   I do not have access to
# 1                           2                   I do not have access to
# 2                           2                   I do not have access to
# 3                           2                   I do not have access to
# 4                           2                   I do not have access to
# ..                        ...                                       ...
# 176                         2                   I do not have access to
# 177                         2                   I do not have access to
# 178                         2                   I do not have access to
# 179                         2                   I do not have access to
# 180                         2                   I do not have access to
#
#      player.employ_status What is your employment status?  \
# 0                       2                         Student
# 1                       0                Full-time worker
# 2                       0                Full-time worker
# 3                       0                Full-time worker
# 4                       0                Full-time worker
# ..                    ...                             ...
# 176                     4                      Unemployed
# 177                     0                Full-time worker
# 178                     2                         Student
# 179                     2                         Student
# 180                     2                         Student
#
#     player.trip_destination  player.trip_purpose  \
# 0                    Madrid                    1
# 1                    GETAFE                    0
# 2                   Pozuelo                    0
# 3       Madrid (Las Tablas)                    0
# 4                    Úbeda                     5
# ..                      ...                  ...
# 176               Valdemoro                    4
# 177                  Madrid                    0
# 178          Madrid capital                    6
# 179                Leganés                     1
# 180                  Madrid                    0
#
#     What is the purpose/destination of this trip? player.trip_other  \
# 0                                 Education place               NaN
# 1                                       Workplace               NaN
# 2                                       Workplace               NaN
# 3                                       Workplace               NaN
# 4                          Visit family or friend               NaN
# ..                                            ...               ...
# 176                           Errands or shopping               NaN
# 177                                     Workplace               NaN
# 178       Leisure activity (cultural, sport, etc)               NaN
# 179                               Education place               NaN
# 180                                     Workplace               NaN
#
#      player.trip_moment At what time of the day do you typically travel?  \
# 0                     0                                          morning
# 1                     0                                          morning
# 2                     0                                          morning
# 3                     0                                          morning
# 4                     2                                          evening
# ..                  ...                                              ...
# 176                   0                                          morning
# 177                   0                                          morning
# 178                   2                                          evening
# 179                   0                                          morning
# 180                   0                                          morning
#
#      player.trip_mode  \
# 0                   2
# 1                   0
# 2                   0
# 3                   4
# 4                   4
# ..                ...
# 176                 0
# 177                 3
# 178                 2
# 179                 2
# 180                 3
#
#     By which mode do you travel with during this trip? If you travel with multiple modes choose the mode that takes you the longest time.  \
# 0                                                  Bus
# 1                                 Private car (driver)
# 2                                 Private car (driver)
# 3                                                Train
# 4                                                Train
# ..                                                 ...
# 176                               Private car (driver)
# 177                          Metro, tram or light rail
# 178                                                Bus
# 179                                                Bus
# 180                          Metro, tram or light rail
#
#     player.mode_other  player.trip_traffic  \
# 0                 NaN                    1
# 1                 NaN                    1
# 2                 NaN                    2
# 3                 NaN                    1
# 4                 NaN                    1
# ..                ...                  ...
# 176               NaN                    1
# 177               NaN                    1
# 178               NaN                    2
# 179               NaN                    1
# 180               NaN                    1
#
#     How are the traffic conditions normally on the trip?  player.trip_time  \
# 0                                   Somewhat congested                   1
# 1                                   Somewhat congested                   0
# 2                               Little or no congested                   1
# 3                                   Somewhat congested                   2
# 4                                   Somewhat congested                   4
# ..                                                 ...                 ...
# 176                                 Somewhat congested                   0
# 177                                 Somewhat congested                   2
# 178                             Little or no congested                   2
# 179                                 Somewhat congested                   1
# 180                                 Somewhat congested                   1
#
#     What is the approximate travel time of this trip (one way)?  \
# 0                                        20-39 minutes
# 1                                        10-19 minutes
# 2                                        20-39 minutes
# 3                                        40-59 minutes
# 4                                    more than 2 hours
# ..                                                 ...
# 176                                      10-19 minutes
# 177                                      40-59 minutes
# 178                                      40-59 minutes
# 179                                      20-39 minutes
# 180                                      20-39 minutes
#
#      player.trip_cost  \
# 0                   0
# 1                   1
# 2                   2
# 3                   1
# 4                   5
# ..                ...
# 176                 2
# 177                 2
# 178                 2
# 179                 0
# 180                 1
#
#     What is the approximate cost of this trip (fuel, road tolls, parking, ticket price etc.), one way? If you are traveling by public transport and have a period ticket, please consider the average price per trip.  \
# 0                                      less than 1 EUR
# 1                                            1-2.5 EUR
# 2                                         2.5-4.99 EUR
# 3                                            1-2.5 EUR
# 4                                     More than 20 EUR
# ..                                                 ...
# 176                                       2.5-4.99 EUR
# 177                                       2.5-4.99 EUR
# 178                                       2.5-4.99 EUR
# 179                                    less than 1 EUR
# 180                                          1-2.5 EUR
#
#      player.trip_alternative_mode  \
# 0                               1
# 1                               1
# 2                               4
# 3                               0
# 4                               1
# ..                            ...
# 176                             2
# 177                             2
# 178                             1
# 179                             3
# 180                             6
#
#     If you were to make this trip using a different mode of travel than your usual mode, which would be the best alternative?  \
# 0                              Private car (passenger)
# 1                              Private car (passenger)
# 2                                                Train
# 3                                 Private car (driver)
# 4                              Private car (passenger)
# ..                                                 ...
# 176                                                Bus
# 177                                                Bus
# 178                            Private car (passenger)
# 179                          Metro, tram or light rail
# 180                         Bike (regular or electric)
#
#      player.trip_alternative_rate   How would you rate your alternative?  \
# 0                               2      Much worse than my current choice
# 1                               1  Somewhat worse than my current choice
# 2                               2      Much worse than my current choice
# 3                               0    Almost as good as my current choice
# 4                               0    Almost as good as my current choice
# ..                            ...                                    ...
# 176                             1  Somewhat worse than my current choice
# 177                             1  Somewhat worse than my current choice
# 178                             0    Almost as good as my current choice
# 179                             0    Almost as good as my current choice
# 180                             0    Almost as good as my current choice
#
#      player.trip_alternative_justification  player.control_question  \
# 0                                      NaN                        3
# 1                                      NaN                        3
# 2                                      NaN                        3
# 3                                      NaN                        3
# 4                                      NaN                        3
# ..                                     ...                      ...
# 176                                    NaN                        3
# 177                                    NaN                        3
# 178                                    NaN                        3
# 179                                    NaN                        3
# 180                                    NaN                        3
#
#     Answer to control question:  player.alternative1  \
# 0                       Correct                    4
# 1                       Correct                    5
# 2                       Correct                    5
# 3                       Correct                    4
# 4                       Correct                    4
# ..                          ...                  ...
# 176                     Correct                    3
# 177                     Correct                    2
# 178                     Correct                    3
# 179                     Correct                    4
# 180                     Correct                    1
#
#                                          Alternative 1  player.alternative2  \
# 0                                 Investments in roads                    2
# 1    Investments in public transport, walking and c...                    4
# 2    Investments in public transport, walking and c...                    4
# 3                                 Investments in roads                    5
# 4                                 Investments in roads                    5
# ..                                                 ...                  ...
# 176              Cash transfer for low-income citizens                    5
# 177                                Equal cash transfer                    5
# 178              Cash transfer for low-income citizens                    2
# 179                               Investments in roads                    5
# 180                                     General budget                    5
#
#                                          Alternative 2  player.alternative3  \
# 0                                  Equal cash transfer                    5
# 1                                 Investments in roads                    2
# 2                                 Investments in roads                    1
# 3    Investments in public transport, walking and c...                    3
# 4    Investments in public transport, walking and c...                    1
# ..                                                 ...                  ...
# 176  Investments in public transport, walking and c...                    4
# 177  Investments in public transport, walking and c...                    4
# 178                                Equal cash transfer                    5
# 179  Investments in public transport, walking and c...                    3
# 180  Investments in public transport, walking and c...                    3
#
#                                          Alternative 3  player.alternative4  \
# 0    Investments in public transport, walking and c...                    1
# 1                                  Equal cash transfer                    3
# 2                                       General budget                    3
# 3                Cash transfer for low-income citizens                    1
# 4                                       General budget                    3
# ..                                                 ...                  ...
# 176                               Investments in roads                    2
# 177                               Investments in roads                    3
# 178  Investments in public transport, walking and c...                    4
# 179              Cash transfer for low-income citizens                    1
# 180              Cash transfer for low-income citizens                    4
#
#                              Alternative 4  player.alternative5  \
# 0                           General budget                    3
# 1    Cash transfer for low-income citizens                    1
# 2    Cash transfer for low-income citizens                    2
# 3                           General budget                    2
# 4    Cash transfer for low-income citizens                    2
# ..                                     ...                  ...
# 176                    Equal cash transfer                    1
# 177  Cash transfer for low-income citizens                    1
# 178                   Investments in roads                    1
# 179                         General budget                    2
# 180                   Investments in roads                    2
#
#                              Alternative 5  1_policy_choice  \
# 0    Cash transfer for low-income citizens                1
# 1                           General budget                1
# 2                      Equal cash transfer                2
# 3                      Equal cash transfer                3
# 4                      Equal cash transfer                2
# ..                                     ...              ...
# 176                         General budget                1
# 177                         General budget                1
# 178                         General budget                3
# 179                    Equal cash transfer                3
# 180                    Equal cash transfer                1
#
#      1_What is your preferred policy type?  1_Price_UR_A  \
# 0                                        A             2
# 1                                        A             4
# 2                                        B             3
# 3    None of them, keep the current system             2
# 4                                        B             3
# ..                                     ...           ...
# 176                                      A             2
# 177                                      A             2
# 178  None of them, keep the current system             2
# 179  None of them, keep the current system             3
# 180                                      A             2
#
#     1_A_Price in urban areas, rush hour  1_Price_UN_A  \
# 0                              0.20 EUR             2
# 1                              0.50 EUR             4
# 2                              0.40 EUR             3
# 3                              0.20 EUR             1
# 4                              0.40 EUR             3
# ..                                  ...           ...
# 176                            0.20 EUR             2
# 177                            0.20 EUR             2
# 178                            0.20 EUR             2
# 179                            0.40 EUR             3
# 180                            0.20 EUR             2
#
#     1_A_Price in urban areas, outside rush hour  1_Price_O_A  \
# 0                                      0.20 EUR            2
# 1                                      0.50 EUR            4
# 2                                      0.40 EUR            4
# 3                                      0.10 EUR            1
# 4                                      0.40 EUR            3
# ..                                          ...          ...
# 176                                    0.20 EUR            2
# 177                                    0.20 EUR            3
# 178                                    0.20 EUR            2
# 179                                    0.40 EUR            3
# 180                                    0.20 EUR            3
#
#     1_A_Price outside urban areas  1_EV_A 1_A_Price for electric vehicles  \
# 0                        0.02 EUR       2                        0.02 EUR
# 1                        0.05 EUR       3                        0.03 EUR
# 2                        0.05 EUR       3                        0.03 EUR
# 3                        0.01 EUR       3                        0.03 EUR
# 4                        0.03 EUR       3                        0.03 EUR
# ..                            ...     ...                             ...
# 176                      0.02 EUR       2                        0.02 EUR
# 177                      0.03 EUR       2                        0.02 EUR
# 178                      0.02 EUR       2                        0.02 EUR
# 179                      0.03 EUR       3                        0.03 EUR
# 180                      0.03 EUR       2                        0.02 EUR
#
#      1_Revenue_A                                 1_A_Use of revenue  \
# 0              3              Cash transfer for low-income citizens
# 1              5  Investments in public transport, walking and c...
# 2              4                               Investments in roads
# 3              2                                Equal cash transfer
# 4              1                                     General budget
# ..           ...                                                ...
# 176            4                               Investments in roads
# 177            1                                     General budget
# 178            1                                     General budget
# 179            5  Investments in public transport, walking and c...
# 180            1                                     General budget
#
#      1_Price_UR_B 1_B_Price in urban areas, rush hour  1_Price_UN_B  \
# 0               3                            0.40 EUR             2
# 1               4                            0.50 EUR             4
# 2               4                            0.50 EUR             3
# 3               4                            0.50 EUR             1
# 4               3                            0.40 EUR             3
# ..            ...                                 ...           ...
# 176             2                            0.20 EUR             2
# 177             4                            0.50 EUR             4
# 178             2                            0.20 EUR             2
# 179             1                            0.10 EUR             1
# 180             4                            0.50 EUR             4
#
#     1_B_Price in urban areas, outside rush hour  1_Price_O_B  \
# 0                                      0.20 EUR            4
# 1                                      0.50 EUR            4
# 2                                      0.40 EUR            2
# 3                                      0.10 EUR            3
# 4                                      0.40 EUR            3
# ..                                          ...          ...
# 176                                    0.20 EUR            2
# 177                                    0.50 EUR            1
# 178                                    0.20 EUR            2
# 179                                    0.10 EUR            1
# 180                                    0.50 EUR            1
#
#     1_B_Price outside urban areas  1_EV_B 1_B_Price for electric vehicles  \
# 0                        0.05 EUR       2                        0.02 EUR
# 1                        0.05 EUR       3                        0.03 EUR
# 2                        0.02 EUR       2                        0.02 EUR
# 3                        0.03 EUR       4                        0.05 EUR
# 4                        0.03 EUR       4                        0.05 EUR
# ..                            ...     ...                             ...
# 176                      0.02 EUR       2                        0.02 EUR
# 177                      0.01 EUR       1                        0.01 EUR
# 178                      0.02 EUR       2                        0.02 EUR
# 179                      0.01 EUR       4                        0.05 EUR
# 180                      0.01 EUR       1                        0.01 EUR
#
#      1_Revenue_B                                 1_B_Use of revenue  \
# 0              5  Investments in public transport, walking and c...
# 1              2                                Equal cash transfer
# 2              5  Investments in public transport, walking and c...
# 3              1                                     General budget
# 4              5  Investments in public transport, walking and c...
# ..           ...                                                ...
# 176            1                                     General budget
# 177            3              Cash transfer for low-income citizens
# 178            4                               Investments in roads
# 179            2                                Equal cash transfer
# 180            3              Cash transfer for low-income citizens
#
#      2_policy_choice 2_What is your preferred policy type?  2_Price_UR_A  \
# 0                  1                                     A             3
# 1                  2                                     B             4
# 2                  2                                     B             2
# 3                  2                                     B             3
# 4                  2                                     B             3
# ..               ...                                   ...           ...
# 176                2                                     B             3
# 177                2                                     B             2
# 178                2                                     B             3
# 179                2                                     B             3
# 180                2                                     B             4
#
#     2_A_Price in urban areas, rush hour  2_Price_UN_A  \
# 0                              0.40 EUR             3
# 1                              0.50 EUR             4
# 2                              0.20 EUR             1
# 3                              0.40 EUR             3
# 4                              0.40 EUR             2
# ..                                  ...           ...
# 176                            0.40 EUR             3
# 177                            0.20 EUR             2
# 178                            0.40 EUR             3
# 179                            0.40 EUR             3
# 180                            0.50 EUR             4
#
#     2_A_Price in urban areas, outside rush hour  2_Price_O_A  \
# 0                                      0.40 EUR            2
# 1                                      0.50 EUR            1
# 2                                      0.10 EUR            2
# 3                                      0.40 EUR            3
# 4                                      0.20 EUR            4
# ..                                          ...          ...
# 176                                    0.40 EUR            3
# 177                                    0.20 EUR            2
# 178                                    0.40 EUR            3
# 179                                    0.40 EUR            4
# 180                                    0.50 EUR            4
#
#     2_A_Price outside urban areas  2_EV_A 2_A_Price for electric vehicles  \
# 0                        0.02 EUR       4                        0.05 EUR
# 1                        0.01 EUR       1                        0.01 EUR
# 2                        0.02 EUR       3                        0.03 EUR
# 3                        0.03 EUR       1                        0.01 EUR
# 4                        0.05 EUR       2                        0.02 EUR
# ..                            ...     ...                             ...
# 176                      0.03 EUR       1                        0.01 EUR
# 177                      0.02 EUR       2                        0.02 EUR
# 178                      0.03 EUR       1                        0.01 EUR
# 179                      0.05 EUR       3                        0.03 EUR
# 180                      0.05 EUR       3                        0.03 EUR
#
#      2_Revenue_A                                 2_A_Use of revenue  \
# 0              2                                Equal cash transfer
# 1              3              Cash transfer for low-income citizens
# 2              2                                Equal cash transfer
# 3              2                                Equal cash transfer
# 4              5  Investments in public transport, walking and c...
# ..           ...                                                ...
# 176            2                                Equal cash transfer
# 177            2                                Equal cash transfer
# 178            2                                Equal cash transfer
# 179            4                               Investments in roads
# 180            3              Cash transfer for low-income citizens
#
#      2_Price_UR_B 2_B_Price in urban areas, rush hour  2_Price_UN_B  \
# 0               4                            0.50 EUR             3
# 1               2                            0.20 EUR             2
# 2               3                            0.40 EUR             3
# 3               2                            0.20 EUR             1
# 4               2                            0.20 EUR             2
# ..            ...                                 ...           ...
# 176             3                            0.40 EUR             3
# 177             2                            0.20 EUR             2
# 178             2                            0.20 EUR             1
# 179             4                            0.50 EUR             3
# 180             1                            0.10 EUR             1
#
#     2_B_Price in urban areas, outside rush hour  2_Price_O_B  \
# 0                                      0.40 EUR            3
# 1                                      0.20 EUR            3
# 2                                      0.40 EUR            3
# 3                                      0.10 EUR            2
# 4                                      0.20 EUR            2
# ..                                          ...          ...
# 176                                    0.40 EUR            3
# 177                                    0.20 EUR            2
# 178                                    0.10 EUR            2
# 179                                    0.40 EUR            2
# 180                                    0.10 EUR            1
#
#     2_B_Price outside urban areas  2_EV_B 2_B_Price for electric vehicles  \
# 0                        0.03 EUR       2                        0.02 EUR
# 1                        0.03 EUR       2                        0.02 EUR
# 2                        0.03 EUR       1                        0.01 EUR
# 3                        0.02 EUR       3                        0.03 EUR
# 4                        0.02 EUR       2                        0.02 EUR
# ..                            ...     ...                             ...
# 176                      0.03 EUR       2                        0.02 EUR
# 177                      0.02 EUR       3                        0.03 EUR
# 178                      0.02 EUR       3                        0.03 EUR
# 179                      0.02 EUR       2                        0.02 EUR
# 180                      0.01 EUR       2                        0.02 EUR
#
#      2_Revenue_B                                 2_B_Use of revenue  \
# 0              4                               Investments in roads
# 1              1                                     General budget
# 2              2                                Equal cash transfer
# 3              2                                Equal cash transfer
# 4              3              Cash transfer for low-income citizens
# ..           ...                                                ...
# 176            3              Cash transfer for low-income citizens
# 177            4                               Investments in roads
# 178            2                                Equal cash transfer
# 179            5  Investments in public transport, walking and c...
# 180            5  Investments in public transport, walking and c...
#
#      3_policy_choice 3_What is your preferred policy type?  3_Price_UR_A  \
# 0                  1                                     A             1
# 1                  1                                     A             2
# 2                  2                                     B             2
# 3                  2                                     B             1
# 4                  1                                     A             1
# ..               ...                                   ...           ...
# 176                2                                     B             3
# 177                1                                     A             4
# 178                1                                     A             3
# 179                2                                     B             4
# 180                1                                     A             2
#
#     3_A_Price in urban areas, rush hour  3_Price_UN_A  \
# 0                              0.10 EUR             1
# 1                              0.20 EUR             2
# 2                              0.20 EUR             2
# 3                              0.10 EUR             1
# 4                              0.10 EUR             1
# ..                                  ...           ...
# 176                            0.40 EUR             3
# 177                            0.50 EUR             4
# 178                            0.40 EUR             3
# 179                            0.50 EUR             1
# 180                            0.20 EUR             2
#
#     3_A_Price in urban areas, outside rush hour  3_Price_O_A  \
# 0                                      0.10 EUR            1
# ...
# 180                                                  0
#
#      player.trust_parlament  \
# 0                         1
# 1                         3
# 2                         4
# 3                         4
# 4                         4
# ..                      ...
# 176                       3
# 177                       5
# 178                       9
# 179                       4
# 180                       7
#
#     How much do you personally trust the following institutions from 1 to 7, where 1 means ‘No trust at all’ and 7 means ‘Trust compltely’? Parlament:   \
# 0                                                    1
# 1                                                    3
# 2                                                    4
# 3                                                    4
# 4                                                    4
# ..                                                 ...
# 176                                                  3
# 177                                                  5
# 178                                      I do not know
# 179                                                  4
# 180                                                  7
#
#      player.trust_county County council:  player.trust_municipality  \
# 0                      1               1                          1
# 1                      4               4                          4
# 2                      4               4                          5
# 3                      6               6                          5
# 4                      7               7                          6
# ..                   ...             ...                        ...
# 176                    3               3                          4
# 177                    4               4                          7
# 178                    2               2                          2
# 179                    2               2                          5
# 180                    6               6                          5
#
#     Municipal council  player.trust_government Government:  \
# 0                   1                        1           1
# 1                   4                        4           4
# 2                   5                        2           2
# 3                   5                        2           2
# 4                   6                        1           1
# ..                ...                      ...         ...
# 176                 4                        3           3
# 177                 7                        2           2
# 178                 2                        4           4
# 179                 5                        4           4
# 180                 5                        7           7
#
#      player.trust_politicians National politicians:  player.trust_parties  \
# 0                           1                     1                     1
# 1                           3                     3                     2
# 2                           3                     3                     3
# 3                           3                     3                     2
# 4                           5                     5                     4
# ..                        ...                   ...                   ...
# 176                         2                     2                     2
# 177                         1                     1                     1
# 178                         3                     3                     5
# 179                         4                     4                     2
# 180                         7                     7                     5
#
#     Political parties:   player.vote  \
# 0                     1           13
# 1                     2            9
# 2                     3            1
# 3                     2            1
# 4                     4            1
# ..                  ...          ...
# 176                   2            1
# 177                   1            0
# 178                   5            0
# 179                   2           12
# 180                   5            0
#
#     Which political party you voted for in the last election?  \
# 0                                prefiero no responder
# 1                                              MP-EQUO
# 2                                      Partido Popular
# 3                                      Partido Popular
# 4                                      Partido Popular
# ..                                                 ...
# 176                                    Partido Popular
# 177                                               PSOE
# 178                                               PSOE
# 179                                       otro partido
# 180                                               PSOE
#
#      player.air_pollution  \
# 0                       3
# 1                       2
# 2                       5
# 3                       3
# 4                       6
# ..                    ...
# 176                     5
# 177                     4
# 178                     4
# 179                     5
# 180                     9
#
#     How much do you agree with the following statements from 1 to 7, where 1 means ‘I completely disagree’ and 7 means ‘I completely agree’? Air pollution derived by cars is one of the major causes of premature death in Europe:  \
# 0                                                    3
# 1                                                    2
# 2                                                    5
# 3                                                    3
# 4                                                    6
# ..                                                 ...
# 176                                                  5
# 177                                                  4
# 178                                                  4
# 179                                                  5
# 180                                      I do not know
#
#      player.road_pricing  \
# 0                      3
# 1                      4
# 2                      6
# 3                      5
# 4                      3
# ..                   ...
# 176                    2
# 177                    2
# 178                    4
# 179                    2
# 180                    6
#
#     The introduction of policies such as road pricing will alleviate congestion problems:  \
# 0                                                    3
# 1                                                    4
# 2                                                    6
# 3                                                    5
# 4                                                    3
# ..                                                 ...
# 176                                                  2
# 177                                                  2
# 178                                                  4
# 179                                                  2
# 180                                                  6
#
#      player.revenues  \
# 0                  2
# 1                  5
# 2                  6
# 3                  2
# 4                  4
# ..               ...
# 176                3
# 177                2
# 178                4
# 179                4
# 180                6
#
#     Revenues collected through taxes are used to create a well-functioning welfare state and society:  \
# 0                                                    2
# 1                                                    5
# 2                                                    6
# 3                                                    2
# 4                                                    4
# ..                                                 ...
# 176                                                  3
# 177                                                  2
# 178                                                  4
# 179                                                  4
# 180                                                  6
#
#      player.tax  \
# 0             3
# 1             3
# 2             6
# 3             5
# 4             5
# ..          ...
# 176           4
# 177           4
# 178           5
# 179           5
# 180           5
#
#     Tax revenues should be used to help those who are more in need:  \
# 0                                                    3
# 1                                                    3
# 2                                                    6
# 3                                                    5
# 4                                                    5
# ..                                                 ...
# 176                                                  4
# 177                                                  4
# 178                                                  5
# 179                                                  5
# 180                                                  5
#
#                                        player.comments  session.label  \
# 0                                              gracias            NaN
# 1                                         Buen trabajo            NaN
# 2                                        todo correcto            NaN
# 3                                                    .            NaN
# 4    Espero que no utilicen estos datos para aplica...            NaN
# ..                                                 ...            ...
# 176                                                  .            NaN
# 177  todo ha estado muy bien explicado, se entendía...            NaN
# 178  A veces las preguntas llevan tiempo para refle...            NaN
# 179                                                NaN            NaN
# 180                                                NaN            NaN
#
#      session.experimenter_name  session.time_scheduled  session.time_started  \
# 0                          NaN                     NaN                   NaN
# 1                          NaN                     NaN                   NaN
# 2                          NaN                     NaN                   NaN
# 3                          NaN                     NaN                   NaN
# 4                          NaN                     NaN                   NaN
# ..                         ...                     ...                   ...
# 176                        NaN                     NaN                   NaN
# 177                        NaN                     NaN                   NaN
# 178                        NaN                     NaN                   NaN
# 179                        NaN                     NaN                   NaN
# 180                        NaN                     NaN                   NaN
#
#      session.mturk_HITId  session.mturk_HITGroupId  session.comment
# 0                    NaN                       NaN              NaN
# 1                    NaN                       NaN              NaN
# 2                    NaN                       NaN              NaN
# 3                    NaN                       NaN              NaN
# 4                    NaN                       NaN              NaN
# ..                   ...                       ...              ...
# 176                  NaN                       NaN              NaN
# 177                  NaN                       NaN              NaN
# 178                  NaN                       NaN              NaN
# 179                  NaN                       NaN              NaN
# 180                  NaN                       NaN              NaN
#
# [181 rows x 250 columns]

# %%
column= df1.columns[13]

tab=df1.groupby([column]).count()*100/num_participants
#tab=tab.rename(index={'I own': 'I own','I do not own, but have access to':'I do not own,\n but have access to','I do not have access to':'I do not have\n access to'})
tab=tab.loc[['Yes','No']]
ax=tab.plot(kind='bar', y=1, title=column, figsize=(5,4), color='moccasin', edgecolor='k', legend=False)
plt.xticks(rotation=0)
plt.xlabel('')
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.tight_layout(pad=2, w_pad=5, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\dr_lic.png')
plt.show()

# %%
column= df1.columns[15]
tab=df1.groupby([column]).count()*100/num_participants
tab=tab.rename(index={'I own': 'I own','I do not own, but have access to':'I do not own,\n but have access to','I do not have access to':'I do not have\n access to'})
tab=tab.loc[['I own', 'I do not own,\n but have access to', 'I do not have\n access to']]
ax=tab.plot(kind='bar', y=1, title=column, figsize=(5,4), color='moccasin', edgecolor='k', legend=False)
plt.xticks(rotation=0)
plt.xlabel('')
#plt.ylim([0,100])
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.tight_layout(pad=2, w_pad=5, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\acc_car.png')
plt.show()

# %%
df1.columns[17]
# Out:
# 'What kind of vehicle do you have access to? If you have access to multiple vehicles choose the one you use the most.'

# %%
column= 'What kind of vehicle do you have access to? If you have access to multiple vehicles choose the one you use the most.'
tab=df1.groupby([column]).count()*100/num_participants
tab=tab.rename(index={'Hybrid or plug-in hybrid':'Hybrid or\n plug-in hybrid'})
tab=tab.loc[['Gasoline', 'Diesel', 'Hybrid or\n plug-in hybrid','Electric']]
ax=tab.plot(kind='bar', y=1, title=column, figsize=(7,4), color='moccasin', edgecolor='k', legend=False)
plt.xticks(rotation=0)
plt.title('What kind of vehicle do you have access to? If you have\n access to multiple vehicles choose the one you use the most.')
plt.xlabel('')
#plt.ylim([0,100])
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.tight_layout(pad=2, w_pad=5, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\gasoline.png')
plt.show()

# %%
df1.columns[19]
# Out:
# 'Do you own or have access to a bike (electric or regular)?'

# %%
column= 'Do you own or have access to a bike (electric or regular)?'
tab=df1.groupby([column]).count()*100/num_participants
#df1=df1.rename(columns={column:'Do you own or have access to\n a bike (electric or regular)?'})
tab=tab.rename(index={'I own': 'I own','I do not own, but have access to':'I do not own,\n but have access to','I do not have access to':'I do not have\n access to'})
tab=tab.loc[['I own', 'I do not own,\n but have access to', 'I do not have\n access to']]
#column= df1.columns[20]
ax=tab.plot(kind='bar', y=1, title = column + '\n', figsize=(4.5,4), color='moccasin', edgecolor='k', legend=False)
plt.ylim([0,100])
plt.xticks(rotation=0)
plt.xlabel('')
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\acc_bike.png')
plt.show()

# %%
column= 'Do you own or have access to a motorbyke?'
tab=df1.groupby([column]).count()*100/num_participants
#df1=df1.rename(columns={'Do you own or have access to a motorbyke?':'Do you own or have access\n to a motorbike?'})
#column= df1.columns[22]
tab=tab.rename(index={'I own': 'I own','I do not own, but have access to':'I do not own,\n but have access to','I do not have access to':'I do not have\n access to'})
tab=tab.loc[['I own', 'I do not own,\n but have access to', 'I do not have\n access to']]
ax=tab.plot(kind='bar', y=1, title = column+ '\n', figsize=(4.5,4), color='moccasin', edgecolor='k', legend=False)
plt.ylim([0,100])
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\acc_moto.png')
plt.show()

# %%
column= 'Do you own or have access to a motorbyke?'
tab=df1.groupby([column]).count()*100/num_participants
#df1=df1.rename(columns={'Do you own or have access to a motorbyke?':'Do you own or have access\n to a motorbike?'})
tab=tab.rename(index={'I own': 'I own','I do not own, but have access to':'I do not own,\n but have access to','I do not have access to':'I do not have\n access to'})
tab=tab.loc[['I own', 'I do not own,\n but have access to', 'I do not have\n access to']]
ax=tab.plot(kind='bar', y=1, title = column+ '\n', figsize=(4.5,4), color='moccasin', edgecolor='k', legend=False)
plt.ylim([0,100])
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\acc_sc.png')
plt.show()

# %%
column= df1.columns[31]
tab=df1.groupby([column]).count()*100/num_participants
#df1=df1.rename(columns={'Do you own or have access to a motorbyke?':'Do you own or have access\n to a motorbike?'})
tab=tab.loc[['morning','afternoon','evening','night']]
#tab=tab.rename(index={'Education place':'Education\n place','Trip within my job/for job purposes':'Trip within\n my job/for\n job purposes','Bring/pick up children or adult':'Bring/pick\n up children\n or adult','Errands or shopping':'Errands or\n shopping','Visit family or friend':'Visit family\n or friend','Leisure activity (cultural, sport, etc)':'Leisure \nactivity (cultural,\n sport, etc)'})

ax=tab.plot(kind='bar', y=1, title = column, figsize=(6,4), color='moccasin', edgecolor='k', legend=False)
#plt.ylim([0,181])
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\time.png')
plt.show()

# %%
column= df1.columns[33]
tab=df1.groupby([column]).count()*100/num_participants
#tab=tab.loc[['Private car (driver)','Private car (passenger)','Bus','Metro, tram or light rail','Train','Walk','Bike (regular or electric)','E-scooter','Motorcycle','Ferry','Other']]
tab=tab.rename(index={'Private car (driver)':'Private car\n (driver)','Metro, tram or light rail':'Metro, tram\n or light rail','Private car (passenger)':'Private car\n (passenger)','Bike (regular or electric)':'Bike (regular\n or electric)'})

ax=tab.plot(kind='bar', y=1, title = 'By which mode do you travel with during this trip?\n If you travel with multiple modes choose the mode that takes you the longest time.', figsize=(10,4), color='moccasin', edgecolor='k', legend=False)
#plt.ylim([0,181])
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\type.png')
plt.show()

# %%
column= df1.columns[36]
tab=df1.groupby([column]).count()*100/num_participants
tab=tab.loc[['Heavily congested','Somewhat congested','Little or no congested']]
#tab=tab.rename(index={'Private car (driver)':'Private car\n (driver)','Metro, tram or light rail':'Metro, tram\n or light rail','Private car (passenger)':'Private car\n (passenger)','Bike (regular or electric)':'Bike (regular\n or electric)'})

ax=tab.plot(kind='bar', y=1, title = column, figsize=(6,4), color='moccasin', edgecolor='k', legend=False)
#plt.ylim([0,181])
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\traffic.png')
plt.show()

# %%
column= df1.columns[38]
tab=df1.groupby([column]).count()*100/num_participants
#df1=df1.rename(columns={'Do you own or have access to a motorbyke?':'Do you own or have access\n to a motorbike?'})
tab=tab.loc[['10-19 minutes','20-39 minutes','40-59 minutes','1-2 hours','more than 2 hours']]
#tab=tab.rename(index={'Education place':'Education\n place','Trip within my job/for job purposes':'Trip within\n my job/for\n job purposes','Bring/pick up children or adult':'Bring/pick\n up children\n or adult','Errands or shopping':'Errands or\n shopping','Visit family or friend':'Visit family\n or friend','Leisure activity (cultural, sport, etc)':'Leisure \nactivity (cultural,\n sport, etc)'})

ax=tab.plot(kind='bar', y=1, title = column, figsize=(8,4), color='moccasin', edgecolor='k', legend=False)
#plt.ylim([0,181])
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\duration_trip.png')
plt.show()

# %%
column= df1.columns[40]
tab=df1.groupby([column]).count()*100/num_participants
#df1=df1.rename(columns={'Do you own or have access to a motorbyke?':'Do you own or have access\n to a motorbike?'})
tab=tab.loc[['less than 1 EUR','1-2.5 EUR','2.5-4.99 EUR','5-9.99 EUR','10-19.99 EUR','More than 20 EUR']]
#tab=tab.rename(index={'Education place':'Education\n place','Trip within my job/for job purposes':'Trip within\n my job/for\n job purposes','Bring/pick up children or adult':'Bring/pick\n up children\n or adult','Errands or shopping':'Errands or\n shopping','Visit family or friend':'Visit family\n or friend','Leisure activity (cultural, sport, etc)':'Leisure \nactivity (cultural,\n sport, etc)'})

ax=tab.plot(kind='bar', y=1, title = 'What is the approximate cost of this trip (fuel, road tolls, parking, ticket\n price etc.), one way? If you are traveling by public transport and have\n a period ticket, please consider the average price per trip.', figsize=(8,4), color='moccasin', edgecolor='k', legend=False)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
#plt.ylim([0,181])
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\price.png')
plt.show()

# %%
column= df1.columns[42]
tab=df1.groupby([column]).count()*100/num_participants
#df1=df1.rename(columns={'Do you own or have access to a motorbyke?':'Do you own or have access\n to a motorbike?'})
#tab=tab.loc[['Private car (driver)','Private car (passenger)','Bus','Metro, tram or light rail','Train','Walk','Bike (regular or electric)','E-scooter','Motorcycle','Ferry','I have no available alternatives']]
tab=tab.rename(index={'Private car (driver)':'Private car\n (driver)','Metro, tram or light rail':'Metro, tram\n or light rail','Private car (passenger)':'Private car\n (passenger)','Bike (regular or electric)':'Bike (regular\n or electric)','I have no available alternatives':'I have no\n available\n alternatives'})

ax=tab.plot(kind='bar', y=1, title = 'If you were to make this trip using a different mode of\n travel than your usual mode, which would be the best alternative?', figsize=(10,4), color='moccasin', edgecolor='k', legend=False)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
#plt.ylim([0,181])
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\alt.png')
plt.show()

# %%
column= df1.columns[47]
tab=df1.groupby([column]).count()*100/num_participants
#df1=df1.rename(columns={'Do you own or have access to a motorbyke?':'Do you own or have access\n to a motorbike?'})
#tab=tab.loc[['Almost as good as my current choice','Somewhat worse than my current choice','Much worse than my current choice','I do not know']]
#tab=tab.rename(index={'Almost as good as my current choice':'Almost as good as\n my current choice','Somewhat worse than my current choice':'Somewhat worse than\n my current choice','Much worse than my current choice':'Much worse than\n my current choice'})

ax=tab.plot(kind='bar', y=1, title = column, figsize=(3,3), color='moccasin', edgecolor='k', legend=False)
plt.ylim([0,100])
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\control.png')
plt.show()

# %%
column= df1.columns[44]
tab=df1.groupby([column]).count()*100/num_participants
#df1=df1.rename(columns={'Do you own or have access to a motorbyke?':'Do you own or have access\n to a motorbike?'})
tab=tab.loc[['Almost as good as my current choice','Somewhat worse than my current choice','Much worse than my current choice','I do not know']]
tab=tab.rename(index={'Almost as good as my current choice':'Almost as good as\n my current choice','Somewhat worse than my current choice':'Somewhat worse than\n my current choice','Much worse than my current choice':'Much worse than\n my current choice'})

ax=tab.plot(kind='bar', y=1, title = column, figsize=(7,4), color='moccasin', edgecolor='k', legend=False)
#plt.ylim([0,181])
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\rate_alt.png')
plt.show()

# %%
column= df1.columns[209]
#dens_a = stats.gaussian_kde(a['player.my_trip'])
n, x_a, _ = plt.hist(df1[column],bins=30,density=True, label='Set B', color='moccasin', edgecolor='black')
#plt.plot(x_a,dens_a(x_a), label='Set B probability density function',color='r')
#a.groupby([column]).count().plot(kind='bar', y=1, title='', figsize=(7,5),color='moccasin', edgecolor='k', legend=False)
#plt.yticks([0,0.05,0.1,0.15,0.2],[0,5,10,15,20])
plt.title('In which year were you born?')
#plt.tight_layout(pad=2, w_pad=8, h_pad=2)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\age.png')
plt.show()

# %%
column= df1.columns[211]
tab=df1.groupby([column]).count()*100/num_participants
#df1=df1.rename(columns={'Do you own or have access to a motorbyke?':'Do you own or have access\n to a motorbike?'})
tab=tab.loc[['woman','man','prefer not to say']]
#tab=tab.rename(index={'Education place':'Education\n place','Trip within my job/for job purposes':'Trip within\n my job/for\n job purposes','Bring/pick up children or adult':'Bring/pick\n up children\n or adult','Errands or shopping':'Errands or\n shopping','Visit family or friend':'Visit family\n or friend','Leisure activity (cultural, sport, etc)':'Leisure \nactivity (cultural,\n sport, etc)'})

ax=tab.plot(kind='bar', y=1, title = column, figsize=(5,4), color='moccasin', edgecolor='k', legend=False)
#plt.ylim([0,181])
plt.xticks(rotation=0)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\gender.png')
plt.show()

# %%
column= df1.columns[213]
tab=df1.groupby([column]).count()*100/num_participants
#df1=df1.rename(columns={'Do you own or have access to a motorbyke?':'Do you own or have access\n to a motorbike?'})
#tab=tab.loc[['woman','man','prefer not to say']]
tab=tab.rename(index={'elementary school':'elementary\n school','high school':'high\n school','university (less than 4 years)':'university (less\n than 4 years)','university (more than 4 years)':'university (more\n than 4 years)'})

ax=tab.plot(kind='bar', y=1, title = column, figsize=(6,4), color='moccasin', edgecolor='k', legend=False)
#plt.ylim([0,181])
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\edu.png')
plt.show()

# %%
column= df1.columns[215]
tab=df1.groupby([column]).count()*100/num_participants
#df1=df1.rename(columns={'Do you own or have access to a motorbyke?':'Do you own or have access\n to a motorbike?'})
tab=tab.loc[['less than 10k EUR','10k-20k EUR','20k-30k EUR','30k-40k EUR','more than 40k EUR','prefer not to say']]
#tab=tab.rename(index={'elementary school':'elementary\n school','high school':'high\n school','university (less than 4 years)':'university (less\n than 4 years)','university (more than 4 years)':'university (more\n than 4 years)'})

ax=tab.plot(kind='bar', y=1, title = column, figsize=(10,4), color='moccasin', edgecolor='k', legend=False)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
#plt.ylim([0,181])
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\income.png')
plt.show()

# %%
column= df1.columns[217]
tab=df1.groupby([column]).count()*100/num_participants
#df1=df1.rename(columns={'Do you own or have access to a motorbyke?':'Do you own or have access\n to a motorbike?'})
#tab=tab.loc[['woman','man','prefer not to say']]
#tab=tab.rename(index={'elementary school':'elementary\n school','high school':'high\n school','university (less than 4 years)':'university (less\n than 4 years)','university (more than 4 years)':'university (more\n than 4 years)'})

ax=tab.plot(kind='bar', y=1, title = column, figsize=(6,4), color='moccasin', edgecolor='k', legend=False)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
#plt.ylim([0,181])
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\number_people.png')
plt.show()

# %%
column= df1.columns[219]
tab=df1.groupby([column]).count()*100/num_participants
#df1=df1.rename(columns={'Do you own or have access to a motorbyke?':'Do you own or have access\n to a motorbike?'})
#tab=tab.loc[['woman','man','prefer not to say']]
#tab=tab.rename(index={'elementary school':'elementary\n school','high school':'high\n school','university (less than 4 years)':'university (less\n than 4 years)','university (more than 4 years)':'university (more\n than 4 years)'})

ax=tab.plot(kind='bar', y=1, title = column, figsize=(6,4), color='moccasin', edgecolor='k', legend=False)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
#plt.ylim([0,181])
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\child.png')
plt.show()

# %%
column= 'Which political party you voted for in the last election?'
tab=df1.groupby([column]).count()*100/num_participants
#df1=df1.rename(columns={'Do you own or have access to a motorbyke?':'Do you own or have access\n to a motorbike?'})
#tab=tab.loc[['PSOE','Partido Popular','Vox','Unidas Podemos','ERC-Cat','Ciudadanos','JxCat','PNV','EHB','MP-EQUO','BNG','Compromís','otro partido','prefiero no responder']]
tab=tab.rename(index={'Partido Popular':'Partido\n Popular','Unidas Podemos':'Unidas\n Podemos','otro partido':'otro\n partido','prefiero no responder':'prefiero \nno responder'})

ax=tab.plot(kind='bar', y=1, title = column, figsize=(13,4), color='moccasin', edgecolor='k', legend=False)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
#plt.ylim([0,181])
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\vote.png')
plt.show()

# %% [markdown]
# ## All plots

# %% [markdown]
# Some alternatives on x-axis are not in logical order

# %%
for i in [9,13,15,19,21,23,25,26,28,31,33,36,38,40,42,44,209,211,213,215,217,219,221,223,225,227,229,231,233,235,237,239,241]:
    column= df1.columns[i]
    
    df1.groupby([column]).count().plot(kind='bar', y=1, title=column, figsize=(9,9),color='moccasin', edgecolor='k', legend=False)
    plt.xticks(rotation=70)
    plt.xlabel('')
    #plt.axis().set_xlabel('')
    #plt.figure(figsize=(9,9))
    #plt.tight_layout(pad=2, w_pad=8, h_pad=2)
    #plt.savefig('ABCharts_all_madrid%d.png' %i)
    plt.show()

# %%
df1=df1.rename(columns={"How much do you personally trust the following institutions from 1 to 7, where 1 means ‘No trust at all’ and 7 means ‘Trust compltely’? Parlament: ": "Parlament","County council:":"County council","Government:": "Government", "National politicians:":"National politicians", "Political parties: ":"Political parties"})

# %%
column= df1.columns[222]
a=df1.groupby([column]).count()['mod']
per=0
s=0
for j in range(1,8):
    per=per+j*a[j]
    s=s+a[j]

# %%
#Averages

for i in [222,224,226,228,230,234,236,238,240,242]:
    column= df1.columns[i]
    a=df1.groupby([column]).count()['mod']
    per=0
    s=0
    for j in range(1,8):
        per=per+j*a[j]
        s=s+a[j]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\PcLaptop\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\PcLaptop\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\PcLaptop\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 7
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 9
#       7 s=0
#       8 for j in range(1,8):
# ----> 9     per=per+j*a[j]
#      10     s=s+a[j]
#
# File c:\Users\PcLaptop\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:1007, in Series.__getitem__(self, key)
#    1004     return self._values[key]
#    1006 elif key_is_scalar:
# -> 1007     return self._get_value(key)
#    1009 if is_hashable(key):
#    1010     # Otherwise index.get_value will raise InvalidIndexError
#    1011     try:
#    1012         # For labels that don't resolve as scalars like tuples and frozensets
#
# File c:\Users\PcLaptop\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:1116, in Series._get_value(self, label, takeable)
#    1113     return self._values[label]
#    1115 # Similar to Index.get_value, but we do not fall back to positional
# -> 1116 loc = self.index.get_loc(label)
#    1118 if is_integer(loc):
#    1119     return self._values[loc]
#
# File c:\Users\PcLaptop\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 7

# %%
for i in [232]:
    column= df1.columns[i]
    a=df1.groupby([column]).count()['mod']
    per=0
    s=0
    for j in range(1,7):
        per=per+j*a[j]
        s=s+a[j]

# %%
column= df1.columns[232]
a=df1.groupby([column]).count()['mod']

# %%
df1.columns[222]
a=df1.groupby([df1.columns[222]]).count()['mod']
per=0
s=0
for j in range(1,8):
    per=per+j*a[j]
    s=s+a[j] 
s,a.sum(),a
# Out:
# (164,
#  181,
#  Parlament
#  1                         36
#  2                         20
#  3                         36
#  4                         30
#  5                         32
#  6                          9
#  7                          1
#  I do not know             12
#  I prefer to not answer     5
#  Name: mod, dtype: int64)

# %%
for i in [18,34,43,222]:
    column= df1.columns[i]
    
    df1.groupby([column]).count().plot(kind='bar', y=1, title=column, figsize=(15,9),color='moccasin', edgecolor='k', legend=False)
    plt.xticks(rotation=70)
    plt.xlabel('')
    #plt.axis().set_xlabel('')
    #plt.figure(figsize=(9,9))
    plt.tight_layout(pad=2, w_pad=8, h_pad=2)
    #plt.savefig('ABCharts_all_madrid%d.png' %i)
    plt.show()

# %%
for i in [236]:
    column= df1.columns[i]
    
    df1.groupby([column]).count().plot(kind='bar', y=1, title=column, figsize=(20,9),color='azure', edgecolor='k', legend=False)
    plt.xticks(rotation=70)
    plt.xlabel('')
    #plt.axis().set_xlabel('')
    #plt.figure(figsize=(9,9))
    plt.tight_layout(pad=2, w_pad=8, h_pad=2)
    #plt.savefig('BCharts_all_%d.png' %i)
    plt.show()

# %%
lst = ['Investments in public transport, walking and cycling','Investments in roads','Cash transfer for low-income citizens','Equal cash transfer','General budget']

bars1=df1.groupby([df1['Alternative 1']]).count()['mod'].loc[lst].tolist()
bars2=df1.groupby([df1['Alternative 2']]).count()['mod'].loc[lst].tolist()
bars3=df1.groupby([df1['Alternative 3']]).count()['mod'].loc[lst].tolist()
bars4=df1.groupby([df1['Alternative 4']]).count()['mod'].loc[lst].tolist()
bars5=df1.groupby([df1['Alternative 5']]).count()['mod'].loc[lst].tolist()

bars12=np.add(bars1, bars2).tolist()
bars123=np.add(bars12,bars3).tolist()
bars1234=np.add(bars123,bars4).tolist()

# The position of the bars on the x-axis
r = [0,1,2,3,4]
 
# Names of group and bar width
names = ['Investments in public\n transport, walking\n and cycling','Investments\n in roads','Cash transfer\n for low-income\n citizens','Equal cash transfer','General budget']

fig, ax = plt.subplots(figsize=(15,8))

ax.bar(r, bars1,  width=0.9, label=('Alternative 1'))
ax.bar(r, bars2, bottom=bars1,  width=0.9, label=('Alternative 2'))
ax.bar(r, bars3, bottom=bars12,  width=0.9, label=('Alternative 3'))
ax.bar(r, bars4, bottom=bars123, width=0.9, label=('Alternative 4'))
ax.bar(r, bars5, bottom=bars1234,  width=0.9, label=('Alternative 5'))

for i in range(5):
    plt.text(i, bars1[i]/2, '%s'%(int(df1.groupby([df1['Alternative 1']]).count()['mod'].loc[lst][i]*100/num_participants)) + '%', va = 'center', ha = 'center', fontsize = 10)
    plt.text(i, bars1[i]+bars2[i]/2, '%s'%(int(df1.groupby([df1['Alternative 2']]).count()['mod'].loc[lst][i]*100/num_participants))  + '%', va = 'center', ha = 'center',  fontsize = 10)
    plt.text(i, bars12[i]+bars3[i]/2, '%s'%(int(df1.groupby([df1['Alternative 3']]).count()['mod'].loc[lst][i]*100/num_participants))  + '%', va = 'center', ha = 'center',  fontsize = 10)
    plt.text(i, bars123[i]+bars4[i]/2, '%s'%(int(df1.groupby([df1['Alternative 4']]).count()['mod'].loc[lst][i]*100/num_participants))  + '%', va = 'center', ha = 'center', fontsize = 10)
    plt.text(i, bars1234[i]+bars5[i]/2, '%s'%(int(df1.groupby([df1['Alternative 5']]).count()['mod'].loc[lst][i]*100/num_participants))  + '%', va = 'center', ha = 'center',  fontsize = 10)


plt.xticks(r, names,fontsize=15)
plt.ylabel('Percentage for each alternative',fontsize=15)
ax.set_yticks(np.linspace(0,181,5))
ax.set_yticklabels(np.linspace(0,100,5),fontsize=15) 
plt.legend(fontsize=15)

#plt.savefig('Alteratives_Madrid.pdf')
 
plt.show()

# %%
lst=['A', 'B', 'C', 'D', 'E','I do not know']

fig=plt.figure(figsize=(10,6))
barWidth = 0.25

bars1=df1.groupby([df1['What type of society do you think is Spain today – which diagram comes the closest?']]).count()['mod'].loc[lst].tolist()
bars2=df1.groupby([df1['What do you think Spain ought to be like – which would you prefer?']]).count()['mod'].loc[lst].tolist()

r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]

plt.bar(r1, bars1, width=barWidth, edgecolor='white', label='What type of society do you think is Spain today?')
plt.bar(r2, bars2, width=barWidth, edgecolor='white', label='What do you think Spain ought to be like?')
 
plt.xticks([r + barWidth for r in range(len(bars1))], ['A', 'B', 'C', 'D', 'E','I do not know'], fontsize=13)
plt.yticks(fontsize=11)
plt.legend()

#plt.savefig("table_Madrid.pdf")
plt.show()

# %%
new=df1.groupby(['By which mode do you travel with during this trip? If you travel with multiple modes choose the mode that takes you the longest time.','If you were to make this trip using a different mode of travel than your usual mode, which would be the best alternative?'])
chord=new.size().reset_index(name="Time")
#chord.to_excel("chord_madrid.xlsx")
