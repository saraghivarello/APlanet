# %%
import pandas as pd
import numpy as np
import math
import matplotlib as plt

# %% [markdown]
# ## Import data

# %%
file = r"C:\Users\PcLaptop\Documents\GitHub\APlanet\Pilot_1\Data\Part3.xlsx"

xl1= pd.ExcelFile(file)      # Load spreadsheet
df1 = xl1.parse('Sheet1')    # Load a sheet into a DataFrame by name: df1

df1.dropna(subset = ["participant._round_number"], inplace=True)  # If column "" contains NaN, remove that row

df1 = df1.loc[:, (df1 != 0).any(axis=0)]
#df1 = df1.drop(274)
lenght=len(df1['player.SN_car_A'])
df1.index  = np.arange(lenght)

# %%
df1.drop(['participant.label','participant._index_in_pages','participant.mturk_assignment_id','participant.mturk_assignment_id','participant._max_page_index',
          'participant._current_app_name','participant._current_page_name',
          'participant._current_page_name','participant.ip_address', 'participant._round_number','participant.mturk_worker_id',
          'participant.visited','player.id_in_group',
          'group.id_in_subsession','subsession.round_number', 'session.code','player.paypal_account'], inplace=True, axis=1)

# %%
df1
# Out:
#      participant.id_in_session participant.code  \
# 0                            1         o9x6ki7q
# 1                            2         iu9re9u5
# 2                            3         0prglina
# 3                            4         76mq2acd
# 4                            5         n6c69l1z
# ..                         ...              ...
# 279                        295         0ledyfgt
# 280                        296         sh0t9561
# 281                        297         33czh01y
# 282                        299         adjl7p00
# 283                        300         g6en7ef2
#
#              participant.time_started  player.SN_car_A  player.EE  player.PNB  \
# 0    2022-07-18 17:15:55.868817+00:00              1.0       40.0        80.0
# 1    2022-07-18 13:56:52.428815+00:00              1.0       10.0         0.0
# 2    2022-07-18 09:56:59.145068+00:00              1.0       60.0        40.0
# ...

# %% [markdown]
# ## Add columns with text (of questions and answers)

# %%
# module
v=[]
for i in df1['participant.id_in_session']:
    v.append((i-1)%4+1)
df1.insert(loc=1, column='mod', value=v)

# %%
# player.SN_car_A

v=[]
for i in range(lenght):
    if math.isnan(df1['player.SN_car_A'][i]) is True:
        v.append('-')
    elif df1['player.SN_car_A'][i]==0: 
        v.append('A: Public Transport, cycling and walking')
    elif df1['player.SN_car_A'][i]==1: 
        v.append('A: Private vehicle')
df1.insert(loc=5, column='Considering the following transport mode group:', value=v)

# %%
# EE

v=[]
for i in range(lenght):
    if math.isnan(df1['player.SN_car_A'][i]) is True:
        v.append('-')
    elif df1['player.SN_car_A'][i]==1: 
        v.append('%s%%'%df1['player.EE'][i])
    elif df1['player.SN_car_A'][i]==0: 
        v.append('%s%%'%(100-df1['player.EE'][i]))
df1.insert(loc=7, column='What share (in %) of other participants in the survey do you think have chosen one of the transport modes in A for their daily trip?', value=v)

# %%
# PNB

v=[]
for i in range(lenght):
    if math.isnan(df1['player.SN_car_A'][i]) is True:
        v.append('-')
    elif df1['player.SN_car_A'][i]==1: 
        v.append('%s%%'%df1['player.PNB'][i])
    elif df1['player.SN_car_A'][i]==0: 
        v.append('%s%%'%(100-df1['player.PNB'][i]))
df1.insert(loc=9, column='In your opinion, what should the ideal percentage of people using transport modes in A for their daily trip be?', value=v)

# %%
# NE

v=[]
for i in range(lenght):
    if math.isnan(df1['player.SN_car_A'][i]) is True:
        v.append('-')
    elif df1['player.SN_car_A'][i]==1: 
        v.append('%s%%'%df1['player.NE'][i])
    elif df1['player.SN_car_A'][i]==0: 
        v.append('%s%%'%(100-df1['player.NE'][i]))
    else: v.append('-')
df1.insert(loc=11, column='What share (in %) of other participants in the survey do you think have mostly chosen option A (answered more than 50%) in the previous question?', value=v)

# %%
# my_trip

v=[]
for i in df1['player.my_trip']:
    if math.isnan(i) is True:
        v.append('-')
    else: v.append('%d%%' %i)
df1.insert(loc=13, column='Considering the last year, how often (in %) did you use your chosen transport mode for your daily trip?', value=v)

# %%
# HH

v=[]
for i in df1['player.HH']:
    if math.isnan(i) is True:
        v.append('-')
    else: v.append('%d%%' %i)
df1.insert(loc=15, column='Imagine that most of the people answering this survey say that they use option A for their daily trip and that most of them think that other people should also use option A. How often (in %) would you use option A in this scenario?', value=v)

# %%
# HL

v=[]
for i in df1['player.HL']:
    if math.isnan(i) is True:
        v.append('-')
    else: v.append('%d%%' %i)
df1.insert(loc=17, column='Imagine that most of the people answering this survey say that they use option A for their daily trip and that most of them think that other people should use option B. How often (in %) would you use option A in this scenario?', value=v)

# %%
# LH

v=[]
for i in df1['player.LH']:
    if math.isnan(i) is True:
        v.append('-')
    else: v.append('%d%%' %i)
df1.insert(loc=19, column='Imagine that most of the people answering this survey say that they use option B for their daily trip and that most of them think that other people should use option A. How often (in %) would you use option A in this scenario?', value=v)

# %%
# LL

v=[]
for i in df1['player.LL']:
    if math.isnan(i) is True:
        v.append('-')
    else: v.append('%d%%' %i)
df1.insert(loc=21, column='Imagine that most of the people answering this survey say that they use option B for their daily trip and that most of them also think that other people should use option B. How often (in %) would you use option A in this scenario?', value=v)

# %%
# year_born

v=[]
for i in df1['player.year_born']:
    if math.isnan(i) is True:
        v.append('-')
    else: v.append('%d' %int(i))
df1.insert(loc=23, column='Which year were you born?', value=v)

# %%
# gender

v=[]
for i in df1['player.gender']:
    if math.isnan(i) is True:
        v.append('-')
    elif i==0:
        v.append('woman')
    elif i==1:
        v.append('man')
    elif i==2:
        v.append('other')
    elif i==3:
        v.append('prefer not to say')
df1.insert(loc=25, column='How do you identify as?', value=v)

# %%
# education

v=[]
for i in df1['player.education']:
    if math.isnan(i) is True:
        v.append('-')
    elif i==0:
        v.append('elementary school')
    elif i==1:
        v.append('high school')
    elif i==2:
        v.append('university (less than 4 years)')
    elif i==3:
        v.append('university (more than 4 years)')
df1.insert(loc=27, column='What is your highest level of education?', value=v)

# %%
# income

v=[]
for i in df1['player.income']:
    if math.isnan(i) is True:
        v.append('-')
    elif i==0:
        v.append('less than 10k EUR')
    elif i==1:
        v.append('10k-20k EUR')
    elif i==2:
        v.append('20k-30k EUR')
    elif i==3:
        v.append('30k-40k EUR')
    elif i==4:
        v.append('more than 40k EUR')
    elif i==5:
        v.append('prefer not to say')
df1.insert(loc=29, column='What is your income per year?', value=v)

# %%
# family

v=[]
for i in df1['player.family']:
    if math.isnan(i) is True:
        v.append('-')
    else: v.append('%d' %int(i))
df1.insert(loc=31, column='How many people does your household have including you?', value=v)

# %%
# children

v=[]
for i in df1['player.children']:
    if math.isnan(i) is True:
        v.append('-')
    else: v.append('%d' %int(i))
df1.insert(loc=33, column='How many children under the age of 15 live with you?', value=v)

# %%
# trust_parlament

v=[]
for i in df1['player.trust_parlament']:
    if math.isnan(i) is True:
        v.append('-')
    elif (i>=0) & (i<8):
        v.append(int(i))
    elif i==8:
        v.append('I prefer not to answer')
    elif i==9:
        v.append('I do not know')
df1.insert(loc=35, column='How much do you personally trust the following institutions from 1 to 7, where 1 means ‘No trust at all’ and 7 means ‘Trust compltely’? Parlament: ', value=v)

# county

v=[]
for i in df1['player.trust_county']:
    if math.isnan(i) is True:
        v.append('-')
    elif (i>=0) & (i<8):
        v.append(int(i))
    elif i==8:
        v.append('I prefer not to answer')
    elif i==9:
        v.append('I do not know')
df1.insert(loc=37, column='County council:', value=v)

# municipality

v=[]
for i in df1['player.trust_municipality']:
    if math.isnan(i) is True:
        v.append('-')
    elif (i>=0) & (i<8):
        v.append(int(i))
    elif i==8:
        v.append('I prefer not to answer')
    elif i==9:
        v.append('I do not know')
df1.insert(loc=39, column='Municipal council:', value=v)

# government

v=[]
for i in df1['player.trust_government']:
    if math.isnan(i) is True:
        v.append('-')
    elif (i>=0) & (i<8):
        v.append(int(i))
    elif i==8:
        v.append('I prefer not to answer')
    elif i==9:
        v.append('I do not know')
df1.insert(loc=41, column='Government:', value=v)

# politicians

v=[]
for i in df1['player.trust_politicians']:
    if math.isnan(i) is True:
        v.append('-')
    elif (i>=0) & (i<8):
        v.append(int(i))
    elif i==8:
        v.append('I prefer not to answer')
    elif i==9:
        v.append('I do not know')
df1.insert(loc=43, column='National politicians:', value=v)

# Political parties

v=[]
for i in df1['player.trust_parties']:
    if math.isnan(i) is True:
        v.append('-')
    elif (i>=0) & (i<8):
        v.append(int(i))
    elif i==8:
        v.append('I prefer not to answer')
    elif i==9:
        v.append('I do not know')
df1.insert(loc=45, column='Political parties:', value=v)

# %%
# vote

v=[]
for i in df1['player.vote']:
    if math.isnan(i) is True:
        v.append('-')
    elif i==0:
        v.append('PSOE')
    elif i==1:
        v.append('Partido Popular')
    elif i==2:
        v.append('Vox')
    elif i==3:
        v.append('Unidas Podemos')
    elif i==4:
        v.append('ERC-Cat')
    elif i==5:
        v.append('Ciudadanos')
    elif i==6:
        v.append('JxCat')
    elif i==7:
        v.append('PNV')
    elif i==8:
        v.append('EHB')
    elif i==9:
        v.append('MP-EQUO')
    elif i==10:
        v.append('BNG')
    elif i==11:
        v.append('Compromís')
    elif i==12:
        v.append('otro partido')
    elif i==13:
        v.append('prefiero no responder')
    
df1.insert(loc=47, column='Which political party you voted for in the last election?', value=v)

# %%
# air_pollution

v=[]
for i in df1['player.air_pollution']:
    if math.isnan(i) is True:
        v.append('-')
    elif (i>=0) & (i<8):
        v.append(int(i))
    elif i==8:
        v.append('I prefer not to answer')
    elif i==9:
        v.append('I do not know')
df1.insert(loc=49, column='How much do you agree with the following statements from 1 to 7, where 1 means ‘I completely disagree’ and 7 means ‘I completely agree’? Air pollution derived by cars is one of the major causes of premature death in Europe:', value=v)

# road_pricing

v=[]
for i in df1['player.road_pricing']:
    if math.isnan(i) is True:
        v.append('-')
    elif (i>=0) & (i<8):
        v.append(int(i))
    elif i==8:
        v.append('I prefer not to answer')
    elif i==9:
        v.append('I do not know')
df1.insert(loc=51, column='The introduction of policies such as road pricing will alleviate congestion problems:', value=v)

# revenues

v=[]
for i in df1['player.revenues']:
    if math.isnan(i) is True:
        v.append('-')
    elif (i>=0) & (i<8):
        v.append(int(i))
    elif i==8:
        v.append('I prefer not to answer')
    elif i==9:
        v.append('I do not know')
df1.insert(loc=53, column='Revenues collected through taxes are used to create a well-functioning welfare state and society:', value=v)

# tax

v=[]
for i in df1['player.tax']:
    if math.isnan(i) is True:
        v.append('-')
    elif (i>=0) & (i<8):
        v.append(int(i))
    elif i==8:
        v.append('I prefer not to answer')
    elif i==9:
        v.append('I do not know')
df1.insert(loc=55, column='Tax revenues should be used to help those who are more in need:', value=v)

# %% [markdown]
# ## Check and export excel

# %%
np.shape(df1)
# Out:
# (284, 64)

# %%
pd.set_option('display.max_columns', None)
df1.head()
# Out:
#    participant.id_in_session  mod participant.code  \
# 0                          1    1         o9x6ki7q
# 1                          2    2         iu9re9u5
# 2                          3    3         0prglina
# 3                          4    4         76mq2acd
# 4                          5    1         n6c69l1z
#
#            participant.time_started  player.SN_car_A  \
# 0  2022-07-18 17:15:55.868817+00:00              1.0
# 1  2022-07-18 13:56:52.428815+00:00              1.0
# 2  2022-07-18 09:56:59.145068+00:00              1.0
# 3  2022-07-18 21:47:35.300273+00:00              1.0
# 4  2022-07-18 22:45:11.140948+00:00              1.0
#
#   Considering the following transport mode group:  player.EE  \
# 0                              A: Private vehicle       40.0
# 1                              A: Private vehicle       10.0
# 2                              A: Private vehicle       60.0
# 3                              A: Private vehicle       43.0
# ...

# %%
df1.to_excel(r"C:\Users\PcLaptop\Documents\GitHub\APlanet\Pilot_1\Rearrange_datasets\Part3_text.xlsx")
