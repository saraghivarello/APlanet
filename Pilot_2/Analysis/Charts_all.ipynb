# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# %%
file = r"C:\Users\PcLaptop\Documents\GitHub\APlanet\Pilot_2\Rearrange_datasets\all_Madrid.xlsx"

xl1= pd.ExcelFile(file)      # Load spreadsheet
df1 = xl1.parse('Sheet1')    # Load a sheet into a DataFrame by name: df1
df1.index  = np.arange(len(df1))

# %%
df1
# Out:
#     participant.code        treatment  participant.id_in_session  \
# 0           ooxl8r2l         Baseline                          1
# 1           i6cytpys        Pollution                          2
# 2           js43i4q6  Public Services                          3
# 3           wjalnvbm     Road Pricing                          4
# 4           bt4ub78z      Social Norm                          5
# ..               ...              ...                        ...
# 478         emins2el      Social Norm                        385
# 479         rz5has1n        Pollution                        392
# 480         99ekoser         Baseline                        396
# 481         8nr05dcp     Road Pricing                        399
# 482         f1wh7sy7      Social Norm                        400
#
#      player.municipality_home What is the municipality of your home address?  \
# 0                          81                                Madrid - Centro
# 1                          85                 Madrid - Fuencarral - El Pardo
# 2                          78                            Madrid - Arganzuela
# 3                          73                                        Leganés
# 4                           3                                     Alamo (El)
# ..                        ...                                            ...
# 478                        81                                Madrid - Centro
# 479                        83                              Madrid - Chamberí
# 480                        85                 Madrid - Fuencarral - El Pardo
# 481                        46                               Collado Villalba
# 482                        64                                         Getafe
#
#      player.driving_license Do you have a driver license?  \
# 0                         1                           Yes
# 1                         1                           Yes
# 2                         1                           Yes
# 3                         1                           Yes
# 4                         1                           Yes
# ..                      ...                           ...
# 478                       1                           Yes
# 479                       1                           Yes
# 480                       1                           Yes
# 481                       1                           Yes
# 482                       1                           Yes
#
#      player.access_to_car Do you own or have access to a car?  \
# 0                       0                               I own
# 1                       1    I do not own, but have access to
# 2                       1    I do not own, but have access to
# 3                       1    I do not own, but have access to
# 4                       0                               I own
# ..                    ...                                 ...
# 478                     0                               I own
# 479                     2             I do not have access to
# 480                     0                               I own
# 481                     0                               I own
# 482                     0                               I own
#
#      player.car_type  ... player.trust_parties  Political parties:   \
# 0                0.0  ...                  4.0                    4
# 1                1.0  ...                  1.0                    1
# 2                1.0  ...                  2.0                    2
# 3                1.0  ...                  1.0                    1
# 4                0.0  ...                  3.0                    3
# ..               ...  ...                  ...                  ...
# 478              0.0  ...                  1.0                    1
# 479              NaN  ...                  NaN                  NaN
# 480              0.0  ...                  1.0                    1
# 481              1.0  ...                  1.0                    1
# 482              1.0  ...                  1.0                    1
#
#     player.trust_politicians  National politicians: player.vote  \
# 0                        5.0                      5         3.0
# 1                        1.0                      1         1.0
# 2                        3.0                      3         1.0
# 3                        1.0                      1        13.0
# 4                        4.0                      4         3.0
# ..                       ...                    ...         ...
# 478                      1.0                      1         1.0
# 479                      NaN                    NaN         NaN
# 480                      1.0                      1         1.0
# 481                      1.0                      1        13.0
# 482                      1.0                      1        13.0
#
#      Which political party you voted for in the last election?  \
# 0                                       Unidas Podemos
# 1                                      Partido Popular
# 2                                      Partido Popular
# 3                                prefiero no responder
# 4                                       Unidas Podemos
# ..                                                 ...
# 478                                    Partido Popular
# 479                                                NaN
# 480                                    Partido Popular
# 481                              prefiero no responder
# 482                              prefiero no responder
#
#     player.year_born  session.code.1 subsession.round_number      treatment.1
# 0             1979.0        uln4i2w2                     1.0         Baseline
# 1             1999.0        uln4i2w2                     1.0        Pollution
# 2             1999.0        uln4i2w2                     1.0  Public Services
# 3             1999.0        uln4i2w2                     1.0     Road Pricing
# 4             2000.0        uln4i2w2                     1.0      Social Norm
# ..               ...             ...                     ...              ...
# 478           1997.0        heqbzlzk                     1.0      Social Norm
# 479              NaN             NaN                     NaN              NaN
# 480           1998.0        heqbzlzk                     1.0         Baseline
# 481           1971.0        heqbzlzk                     1.0     Road Pricing
# 482           1993.0        heqbzlzk                     1.0      Social Norm
#
# [483 rows x 296 columns]

# %%
num_participants = len(df1)
num_participants
# Out:
# 483

# %%
#show all columns
pd.set_option('display.max_columns', None)
#df1.head()

# %%
column= 'What is the municipality of your home address?'
tab=df1.groupby([column]).count()*100/num_participants
ax=tab.plot(kind='bar', y=1, title=column, figsize=(20,4), color='moccasin', edgecolor='k', legend=False)
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2, w_pad=5, h_pad=3)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\wealth_distrib.png')
plt.show()

# %%
column= 'How fair do you think the wealth distribution is in your country?'
tab=df1.groupby([column]).count()*100/num_participants
tab=tab.loc[['Very fair', 'Fair', 'Unfair','Very unfair','I do not know']]
ax=tab.plot(kind='bar', y=1, title=column, figsize=(6,4), color='moccasin', edgecolor='k', legend=False)
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2, w_pad=5, h_pad=3)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\wealth_distrib.png')
plt.show()

# %%
column= 'Do you have a driver license?'

tab=df1.groupby([column]).count()*100/num_participants
#tab=tab.rename(index={'I own': 'I own','I do not own, but have access to':'I do not own,\n but have access to','I do not have access to':'I do not have\n access to'})
tab=tab.loc[['Yes','No']]
ax=tab.plot(kind='bar', y=1, title=column, figsize=(5,4), color='moccasin', edgecolor='k', legend=False)
plt.xticks(rotation=0)
plt.xlabel('')
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.tight_layout(pad=2, w_pad=5, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\dr_lic.png')
plt.show()

# %%
column=  'Do you own or have access to a car?'
tab=df1.groupby([column]).count()*100/num_participants
tab=tab.rename(index={'I own': 'I own','I do not own, but have access to':'I do not own,\n but have access to','I do not have access to':'I do not have\n access to'})
tab=tab.loc[['I own', 'I do not own,\n but have access to', 'I do not have\n access to']]
ax=tab.plot(kind='bar', y=1, title=column, figsize=(5,4), color='moccasin', edgecolor='k', legend=False)
plt.xticks(rotation=0)
plt.xlabel('')
#plt.ylim([0,100])
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.tight_layout(pad=2, w_pad=5, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\acc_car.png')
plt.show()

# %%
column= 'What kind of vehicle do you have access to? If you have access to multiple vehicles choose the one you use the most.'
tab=df1.groupby([column]).count()*100/num_participants
tab=tab.rename(index={'Hybrid or plug-in hybrid':'Hybrid or\n plug-in hybrid'})
tab=tab.loc[['Gasoline', 'Diesel', 'Hybrid or\n plug-in hybrid','Electric']]
ax=tab.plot(kind='bar', y=1, title=column, figsize=(7,4), color='moccasin', edgecolor='k', legend=False)
plt.xticks(rotation=0)
plt.title('What kind of vehicle do you have access to? If you have\n access to multiple vehicles choose the one you use the most.')
plt.xlabel('')
#plt.ylim([0,100])
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.tight_layout(pad=2, w_pad=5, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\gasoline.png')
plt.show()

# %%
column= 'Are you planning to buy a car in the next year?'
tab=df1.groupby([column]).count()*100/num_participants
tab=tab.rename(index={'Yes, hybrid or plug-in hybrid':'Yes, hybrid or\n plug-in hybrid'})
tab=tab.loc[['No', 'Yes, gasoline', 'Yes, diesel', 'Yes, hybrid or\n plug-in hybrid','Yes, electric']]
ax=tab.plot(kind='bar', y=1, title=column, figsize=(7,4), color='moccasin', edgecolor='k', legend=False)
plt.xticks(rotation=0)
plt.title('What kind of vehicle do you have access to? If you have\n access to multiple vehicles choose the one you use the most.')
plt.xlabel('')
#plt.ylim([0,100])
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.tight_layout(pad=2, w_pad=5, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\gasoline.png')
plt.show()

# %%
column= 'What is the purpose/destination of this trip?'
tab=df1.groupby([column]).count()*100/num_participants
tab=tab.rename(index={'Education place':'Education\n place','Trip within my job/for job purposes':'Trip within\n my job/for\n job purposes','Bring/pick up children or adult':'Bring/pick\n up children\n or adult','Errands or shopping':'Errands or\n shopping','Visit family or friend':'Visit family\n or friend','Leisure activity (cultural, sport, etc)':'Leisure \nactivity (cultural,\n sport, etc)'})
ax=tab.plot(kind='bar', y=1, title = column + '\n', figsize=(10,4), color='moccasin', edgecolor='k', legend=False)
plt.ylim([0,100])
plt.xticks(rotation=0)
plt.xlabel('')
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
#plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\acc_bike.png')
plt.show()

# %%
column= 'Do you own or have access to a bike (electric or regular)?'
tab=df1.groupby([column]).count()*100/num_participants
#df1=df1.rename(columns={column:'Do you own or have access to\n a bike (electric or regular)?'})
tab=tab.rename(index={'I own': 'I own','I do not own, but have access to':'I do not own,\n but have access to','I do not have access to':'I do not have\n access to'})
tab=tab.loc[['I own', 'I do not own,\n but have access to', 'I do not have\n access to']]
#column= df1.columns[20]
ax=tab.plot(kind='bar', y=1, title = column + '\n', figsize=(4.5,4), color='moccasin', edgecolor='k', legend=False)
plt.ylim([0,100])
plt.xticks(rotation=0)
plt.xlabel('')
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\acc_bike.png')
plt.show()

# %%
column= 'Do you own or have access to a motorbyke?'
tab=df1.groupby([column]).count()*100/num_participants
#df1=df1.rename(columns={'Do you own or have access to a motorbyke?':'Do you own or have access\n to a motorbike?'})
#column= df1.columns[22]
tab=tab.rename(index={'I own': 'I own','I do not own, but have access to':'I do not own,\n but have access to','I do not have access to':'I do not have\n access to'})
tab=tab.loc[['I own', 'I do not own,\n but have access to', 'I do not have\n access to']]
ax=tab.plot(kind='bar', y=1, title = 'Do you own or have access to a motorbike?\n', figsize=(4.5,4), color='moccasin', edgecolor='k', legend=False)
plt.ylim([0,100])
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\acc_moto.png')
plt.show()

# %%
column= 'Do you own or have access to a e-scooter?'
tab=df1.groupby([column]).count()*100/num_participants
#df1=df1.rename(columns={'Do you own or have access to a motorbyke?':'Do you own or have access\n to a motorbike?'})
#column= df1.columns[22]
tab=tab.rename(index={'I own': 'I own','I do not own, but have access to':'I do not own,\n but have access to','I do not have access to':'I do not have\n access to'})
tab=tab.loc[['I own', 'I do not own,\n but have access to', 'I do not have\n access to']]
ax=tab.plot(kind='bar', y=1, title = 'Do you own or have access to a e-scooter?\n', figsize=(4.5,4), color='moccasin', edgecolor='k', legend=False)
plt.ylim([0,100])
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\acc_moto.png')
plt.show()

# %%
column='At what time of the day do you typically travel?'
tab=df1.groupby([column]).count()*100/num_participants
#df1=df1.rename(columns={'Do you own or have access to a motorbyke?':'Do you own or have access\n to a motorbike?'})
tab=tab.loc[['morning','afternoon','evening','night']]

ax=tab.plot(kind='bar', y=1, title = column, figsize=(6,4), color='moccasin', edgecolor='k', legend=False)
#plt.ylim([0,181])
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\time.png')
plt.show()

# %%
column= 'By which mode do you travel with during this trip? If you travel with multiple modes choose the mode that takes you the longest time.'
tab=df1.groupby([column]).count()*100/num_participants
#tab=tab.loc[['Private car (driver)','Private car (passenger)','Bus','Metro, tram or light rail','Train','Walk','Bike (regular or electric)','E-scooter','Motorcycle','Ferry','Other']]
tab=tab.rename(index={'Private car (driver)':'Private car\n (driver)','Metro, tram or light rail':'Metro, tram\n or light rail','Private car (passenger)':'Private car\n (passenger)','Bike (regular or electric)':'Bike (regular\n or electric)'})

ax=tab.plot(kind='bar', y=1, title = 'By which mode do you travel with during this trip?\n If you travel with multiple modes choose the mode that takes you the longest time.', figsize=(10,4), color='moccasin', edgecolor='k', legend=False)
#plt.ylim([0,181])
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\type.png')
plt.show()

# %%
#count how many people use private car or motorcycle
df1['By which mode do you travel with during this trip? If you travel with multiple modes choose the mode that takes you the longest time.'].value_counts()
private_transport = 108+9+8
private_transport/len(df1)
# Out:
# 0.2587991718426501

# %%
column= 'How are the traffic conditions normally on the trip?'
tab=df1.groupby([column]).count()*100/num_participants
tab=tab.loc[['Heavily congested','Somewhat congested','Little or no congested']]
#tab=tab.rename(index={'Private car (driver)':'Private car\n (driver)','Metro, tram or light rail':'Metro, tram\n or light rail','Private car (passenger)':'Private car\n (passenger)','Bike (regular or electric)':'Bike (regular\n or electric)'})

ax=tab.plot(kind='bar', y=1, title = column, figsize=(6,4), color='moccasin', edgecolor='k', legend=False)
#plt.ylim([0,181])
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\traffic.png')
plt.show()

# %%
column= 'What is the approximate travel time of this trip (one way)?'
tab=df1.groupby([column]).count()*100/num_participants
#df1=df1.rename(columns={'Do you own or have access to a motorbyke?':'Do you own or have access\n to a motorbike?'})
tab=tab.loc[['10-19 minutes','20-39 minutes','40-59 minutes','1-2 hours','more than 2 hours']]
#tab=tab.rename(index={'Education place':'Education\n place','Trip within my job/for job purposes':'Trip within\n my job/for\n job purposes','Bring/pick up children or adult':'Bring/pick\n up children\n or adult','Errands or shopping':'Errands or\n shopping','Visit family or friend':'Visit family\n or friend','Leisure activity (cultural, sport, etc)':'Leisure \nactivity (cultural,\n sport, etc)'})

ax=tab.plot(kind='bar', y=1, title = column, figsize=(8,4), color='moccasin', edgecolor='k', legend=False)
#plt.ylim([0,181])
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\duration_trip.png')
plt.show()

# %%
df1
# Out:
#     participant.code        treatment  participant.id_in_session  \
# 0           ooxl8r2l         Baseline                          1
# 1           i6cytpys        Pollution                          2
# 2           js43i4q6  Public Services                          3
# 3           wjalnvbm     Road Pricing                          4
# 4           bt4ub78z      Social Norm                          5
# ..               ...              ...                        ...
# 478         emins2el      Social Norm                        385
# 479         rz5has1n        Pollution                        392
# 480         99ekoser         Baseline                        396
# 481         8nr05dcp     Road Pricing                        399
# 482         f1wh7sy7      Social Norm                        400
#
#      player.municipality_home What is the municipality of your home address?  \
# 0                          81                                Madrid - Centro
# 1                          85                 Madrid - Fuencarral - El Pardo
# 2                          78                            Madrid - Arganzuela
# 3                          73                                        Leganés
# 4                           3                                     Alamo (El)
# ..                        ...                                            ...
# 478                        81                                Madrid - Centro
# 479                        83                              Madrid - Chamberí
# 480                        85                 Madrid - Fuencarral - El Pardo
# 481                        46                               Collado Villalba
# 482                        64                                         Getafe
#
#      player.driving_license Do you have a driver license?  \
# 0                         1                           Yes
# 1                         1                           Yes
# 2                         1                           Yes
# 3                         1                           Yes
# 4                         1                           Yes
# ..                      ...                           ...
# 478                       1                           Yes
# 479                       1                           Yes
# 480                       1                           Yes
# 481                       1                           Yes
# 482                       1                           Yes
#
#      player.access_to_car Do you own or have access to a car?  \
# 0                       0                               I own
# 1                       1    I do not own, but have access to
# 2                       1    I do not own, but have access to
# 3                       1    I do not own, but have access to
# 4                       0                               I own
# ..                    ...                                 ...
# 478                     0                               I own
# 479                     2             I do not have access to
# 480                     0                               I own
# 481                     0                               I own
# 482                     0                               I own
#
#      player.car_type  \
# 0                0.0
# 1                1.0
# 2                1.0
# 3                1.0
# 4                0.0
# ..               ...
# 478              0.0
# 479              NaN
# 480              0.0
# 481              1.0
# 482              1.0
#
#     What kind of vehicle do you have access to? If you have access to multiple vehicles choose the one you use the most.  \
# 0                                             Gasoline
# 1                                               Diesel
# 2                                               Diesel
# 3                                               Diesel
# 4                                             Gasoline
# ..                                                 ...
# 478                                           Gasoline
# 479                                                  -
# 480                                           Gasoline
# 481                                             Diesel
# 482                                             Diesel
#
#      player.buy_car_type Are you planning to buy a car in the next year?  \
# 0                    NaN                                               -
# 1                    4.0                                              No
# 2                    4.0                                              No
# 3                    4.0                                              No
# 4                    NaN                                               -
# ..                   ...                                             ...
# 478                  NaN                                               -
# 479                  4.0                                              No
# 480                  NaN                                               -
# 481                  NaN                                               -
# 482                  NaN                                               -
#
#      player.access_to_bike  \
# 0                        1
# 1                        1
# 2                        0
# 3                        0
# 4                        0
# ..                     ...
# 478                      2
# 479                      2
# 480                      0
# 481                      2
# 482                      2
#
#     Do you own or have access to a bike (electric or regular)?  \
# 0                     I do not own, but have access to
# 1                     I do not own, but have access to
# 2                                                I own
# 3                                                I own
# 4                                                I own
# ..                                                 ...
# 478                            I do not have access to
# 479                            I do not have access to
# 480                                              I own
# 481                            I do not have access to
# 482                            I do not have access to
#
#      player.access_to_motorbyke Do you own or have access to a motorbyke?  \
# 0                             2                   I do not have access to
# 1                             2                   I do not have access to
# 2                             2                   I do not have access to
# 3                             2                   I do not have access to
# 4                             1          I do not own, but have access to
# ..                          ...                                       ...
# 478                           2                   I do not have access to
# 479                           2                   I do not have access to
# 480                           2                   I do not have access to
# 481                           2                   I do not have access to
# 482                           2                   I do not have access to
#
#      player.access_to_scooter Do you own or have access to a e-scooter?  \
# 0                           2                   I do not have access to
# 1                           2                   I do not have access to
# 2                           2                   I do not have access to
# 3                           2                   I do not have access to
# 4                           0                                     I own
# ..                        ...                                       ...
# 478                         2                   I do not have access to
# 479                         2                   I do not have access to
# 480                         2                   I do not have access to
# 481                         2                   I do not have access to
# 482                         2                   I do not have access to
#
#      player.employ_status What is your employment status?  \
# 0                       2                         Student
# 1                       0                Full-time worker
# 2                       0                Full-time worker
# 3                       2                         Student
# 4                       2                         Student
# ..                    ...                             ...
# 478                     2                         Student
# 479                     0                Full-time worker
# 480                     0                Full-time worker
# 481                     0                Full-time worker
# 482                     0                Full-time worker
#
#      player.municipality_destination  \
# 0                                 81
# 1                                 82
# 2                                 94
# 3                                 81
# 4                                 79
# ..                               ...
# 478                               64
# 479                               86
# 480                               92
# 481                               46
# 482                               91
#
#     Where is the destination of this trip? (municipality)  \
# 0                                      Madrid - Centro
# 1                                   Madrid - Chamartín
# 2                                      Madrid - Tetuán
# 3                                      Madrid - Centro
# 4                                     Madrid - Barajas
# ..                                                 ...
# 478                                             Getafe
# 479                                 Madrid - Hortaleza
# 480                                 Madrid - Salamanca
# 481                                   Collado Villalba
# 482                                    Madrid - Retiro
#
#      player.trip_purpose What is the purpose/destination of this trip?  \
# 0                      3               Bring/pick up children or adult
# 1                      0                                     Workplace
# 2                      0                                     Workplace
# 3                      1                               Education place
# 4                      4                           Errands or shopping
# ..                   ...                                           ...
# 478                    1                               Education place
# 479                    0                                     Workplace
# 480                    0                                     Workplace
# 481                    2           Trip within my job/for job purposes
# 482                    0                                     Workplace
#
#     player.trip_other  player.trip_moment  \
# 0                 NaN                   0
# 1                 NaN                   0
# 2                 NaN                   0
# 3                 NaN                   2
# 4                 NaN                   2
# ..                ...                 ...
# 478               NaN                   2
# 479               NaN                   0
# 480               NaN                   0
# 481               NaN                   0
# 482               NaN                   0
#
#     At what time of the day do you typically travel?  player.trip_mode  \
# 0                                            morning                 5
# 1                                            morning                 3
# 2                                            morning                 2
# 3                                            evening                 2
# 4                                            evening                 0
# ..                                               ...               ...
# 478                                          evening                 3
# 479                                          morning                 3
# 480                                          morning                 1
# 481                                          morning                 0
# 482                                          morning                 3
#
#     By which mode do you travel with during this trip? If you travel with multiple modes choose the mode that takes you the longest time.  \
# 0                                                 Walk
# 1                            Metro, tram or light rail
# 2                                                  Bus
# 3                                                  Bus
# 4                                 Private car (driver)
# ..                                                 ...
# 478                          Metro, tram or light rail
# 479                          Metro, tram or light rail
# 480                            Private car (passenger)
# 481                               Private car (driver)
# 482                          Metro, tram or light rail
#
#     player.mode_other  player.trip_traffic  \
# 0                 NaN                    2
# 1                 NaN                    1
# 2                 NaN                    0
# 3                 NaN                    1
# 4                 NaN                    1
# ..                ...                  ...
# 478               NaN                    1
# 479               NaN                    1
# 480               NaN                    1
# 481               NaN                    2
# 482               NaN                    0
#
#     How are the traffic conditions normally on the trip?  player.trip_time  \
# 0                               Little or no congested                   0
# 1                                   Somewhat congested                   1
# 2                                    Heavily congested                   1
# 3                                   Somewhat congested                   3
# 4                                   Somewhat congested                   1
# ..                                                 ...                 ...
# 478                                 Somewhat congested                   2
# 479                                 Somewhat congested                   2
# 480                                 Somewhat congested                   1
# 481                             Little or no congested                   0
# 482                                  Heavily congested                   2
#
#     What is the approximate travel time of this trip (one way)?  \
# 0                                        10-19 minutes
# 1                                        20-39 minutes
# 2                                        20-39 minutes
# 3                                            1-2 hours
# 4                                        20-39 minutes
# ..                                                 ...
# 478                                      40-59 minutes
# 479                                      40-59 minutes
# 480                                      20-39 minutes
# 481                                      10-19 minutes
# 482                                      40-59 minutes
#
#      player.trip_cost  \
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   5
# ..                ...
# 478                 2
# 479                 2
# 480                 1
# 481                 2
# 482                 3
#
#     What is the approximate cost of this trip (fuel, road tolls, parking, ticket price etc.), one way? If you are traveling by public transport and have a period ticket, please consider the average price per trip.  \
# 0                                      less than 1 EUR
# 1                                      less than 1 EUR
# 2                                      less than 1 EUR
# 3                                      less than 1 EUR
# 4                                     More than 20 EUR
# ..                                                 ...
# 478                                       2.5-4.99 EUR
# 479                                       2.5-4.99 EUR
# 480                                          1-2.5 EUR
# 481                                       2.5-4.99 EUR
# 482                                         5-9.99 EUR
#
#      player.trip_tolls  player.trip_alternative_mode  \
# 0                  NaN                             7
# 1                  NaN                             2
# 2                  NaN                             4
# 3                  NaN                             4
# 4                  1.0                             1
# ..                 ...                           ...
# 478                NaN                             1
# 479                NaN                             0
# 480                1.0                             3
# 481                1.0                            10
# 482                NaN                             0
#
#     If you were to make this trip using a different mode of travel than your usual mode, which would be the best alternative?  \
# 0                                            E-scooter
# 1                                                  Bus
# 2                                                Train
# 3                                                Train
# 4                              Private car (passenger)
# ..                                                 ...
# 478                            Private car (passenger)
# 479                               Private car (driver)
# 480                          Metro, tram or light rail
# 481                   I have no available alternatives
# 482                               Private car (driver)
#
#      player.trip_alternative_rate   How would you rate your alternative?  \
# 0                             1.0  Somewhat worse than my current choice
# 1                             0.0    Almost as good as my current choice
# 2                             1.0  Somewhat worse than my current choice
# 3                             1.0  Somewhat worse than my current choice
# 4                             0.0    Almost as good as my current choice
# ..                            ...                                    ...
# 478                           0.0    Almost as good as my current choice
# 479                           0.0    Almost as good as my current choice
# 480                           1.0  Somewhat worse than my current choice
# 481                           NaN                                      -
# 482                           0.0    Almost as good as my current choice
#
#                  player.trip_alternative_justification  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 478                                                NaN
# 479                                                NaN
# 480                                                NaN
# 481  En transporte público llevaria más tiempo. No ...
# 482                                                NaN
#
#      player.inequality_perception  \
# 0                               1
# 1                               3
# 2                               1
# 3                               2
# 4                               5
# ..                            ...
# 478                             1
# 479                             4
# 480                             4
# 481                             1
# 482                             3
#
#     What type of society do you think is Spain today – which diagram comes the closest?  \
# 0                                                    A
# 1                                                    C
# 2                                                    A
# 3                                                    B
# 4                                                    E
# ..                                                 ...
# 478                                                  A
# 479                                                  D
# 480                                                  D
# 481                                                  A
# 482                                                  C
#
#      player.inequality_wish  \
# 0                         4
# 1                         4
# 2                         4
# 3                         5
# 4                         4
# ..                      ...
# 478                       4
# 479                       4
# 480                       5
# 481                       3
# 482                       4
#
#     What do you think Spain ought to be like – which would you prefer?  \
# 0                                                    D
# 1                                                    D
# 2                                                    D
# 3                                                    E
# 4                                                    D
# ..                                                 ...
# 478                                                  D
# 479                                                  D
# 480                                                  E
# 481                                                  C
# 482                                                  D
#
#      player.income_distribution  \
# 0                             4
# 1                             2
# 2                             4
# 3                             3
# 4                             3
# ..                          ...
# 478                           3
# 479                           2
# 480                           2
# 481                           4
# 482                           3
#
#     How fair do you think the wealth distribution is in your country?  \
# 0                                          Very unfair
# 1                                                 Fair
# 2                                          Very unfair
# 3                                               Unfair
# 4                                               Unfair
# ..                                                 ...
# 478                                             Unfair
# 479                                               Fair
# 480                                               Fair
# 481                                        Very unfair
# 482                                             Unfair
#
#     session.code  control_question1  control_question2  attributes_binary_1  \
# 0       uln4i2w2                  3                NaN                  1.0
# 1       uln4i2w2                  3                NaN                  0.0
# 2       uln4i2w2                  3                NaN                  0.0
# 3       uln4i2w2                  3                NaN                  0.0
# 4       uln4i2w2                  3                NaN                  0.0
# ..           ...                ...                ...                  ...
# 478     heqbzlzk                  3                NaN                  1.0
# 479     heqbzlzk                  3                NaN                  NaN
# 480     heqbzlzk                  3                NaN                  0.0
# 481     heqbzlzk                  2                3.0                  0.0
# 482     heqbzlzk                  3                NaN                  1.0
#
#      attributes_binary_2  attributes_binary_3  attributes_binary_4  \
# 0                    1.0                  1.0                  1.0
# 1                    0.0                  0.0                  1.0
# 2                    0.0                  1.0                  0.0
# 3                    1.0                  0.0                  0.0
# 4                    0.0                  0.0                  0.0
# ..                   ...                  ...                  ...
# 478                  1.0                  1.0                  1.0
# 479                  NaN                  NaN                  NaN
# 480                  0.0                  0.0                  1.0
# 481                  0.0                  0.0                  0.0
# 482                  1.0                  0.0                  0.0
#
#      attributes_binary_5  1_alternative1  1_policy_choice  \
# 0                    0.0               5              3.0
# 1                    0.0               5              1.0
# 2                    0.0               5              2.0
# 3                    0.0               5              1.0
# 4                    0.0               1              2.0
# ..                   ...             ...              ...
# 478                  0.0               4              3.0
# 479                  NaN               4              1.0
# 480                  0.0               4              1.0
# 481                  0.0               5              3.0
# 482                  0.0               1              3.0
#
#      1_What is your preferred policy type?  2_policy_choice  \
# 0    None of them, keep the current system              3.0
# 1                                        A              1.0
# 2                                        B              3.0
# 3                                        A              2.0
# 4                                        B              1.0
# ..                                     ...              ...
# 478  None of them, keep the current system              1.0
# 479                                      A              2.0
# 480                                      A              1.0
# 481  None of them, keep the current system              3.0
# 482  None of them, keep the current system              3.0
#
#      2_What is your preferred policy type?  3_policy_choice  \
# 0    None of them, keep the current system              3.0
# 1                                        A              1.0
# 2    None of them, keep the current system              2.0
# 3                                        B              2.0
# 4                                        A              1.0
# ..                                     ...              ...
# 478                                      A              1.0
# 479                                      B              1.0
# 480                                      A              1.0
# 481  None of them, keep the current system              3.0
# 482  None of them, keep the current system              1.0
#
#      3_What is your preferred policy type?  4_policy_choice  \
# 0    None of them, keep the current system              2.0
# 1                                        A              2.0
# 2                                        B              1.0
# 3                                        B              2.0
# 4                                        A              2.0
# ..                                     ...              ...
# 478                                      A              2.0
# 479                                      A              2.0
# 480                                      A              2.0
# 481  None of them, keep the current system              3.0
# 482                                      A              1.0
#
#      4_What is your preferred policy type?  5_policy_choice  \
# 0                                        B              3.0
# 1                                        B              2.0
# 2                                        A              1.0
# 3                                        B              2.0
# 4                                        B              1.0
# ..                                     ...              ...
# 478                                      B              2.0
# 479                                      B              NaN
# 480                                      B              1.0
# 481  None of them, keep the current system              3.0
# 482                                      A              1.0
#
#      5_What is your preferred policy type?  6_policy_choice  \
# 0    None of them, keep the current system              3.0
# 1                                        B              1.0
# 2                                        A              2.0
# 3                                        B              2.0
# 4                                        A              2.0
# ..                                     ...              ...
# 478                                      B              1.0
# 479                                      -              NaN
# 480                                      A              2.0
# 481  None of them, keep the current system              3.0
# 482                                      A              3.0
#
#      6_What is your preferred policy type?  7_policy_choice  \
# 0    None of them, keep the current system              3.0
# 1                                        A              1.0
# 2                                        B              2.0
# 3                                        B              1.0
# 4                                        B              2.0
# ..                                     ...              ...
# 478                                      A              1.0
# 479                                      -              NaN
# 480                                      B              2.0
# 481  None of them, keep the current system              3.0
# 482  None of them, keep the current system              3.0
#
#      7_What is your preferred policy type?  8_policy_choice  \
# 0    None of them, keep the current system              3.0
# 1                                        A              1.0
# 2                                        B              2.0
# 3                                        A              2.0
# 4                                        B              2.0
# ..                                     ...              ...
# 478                                      A              2.0
# 479                                      -              NaN
# 480                                      B              1.0
# 481  None of them, keep the current system              3.0
# 482  None of them, keep the current system              3.0
#
#      8_What is your preferred policy type?  1_Price_UR_A  \
# 0    None of them, keep the current system             3
# 1                                        A             4
# 2                                        B             4
# 3                                        B             3
# 4                                        B             2
# ..                                     ...           ...
# 478                                      B             3
# 479                                      -             3
# 480                                      A             2
# 481  None of them, keep the current system             3
# 482  None of them, keep the current system             4
#
#     1_A_Price in urban areas, rush hour  2_Price_UR_A  \
# 0                              0.40 EUR           4.0
# 1                              0.50 EUR           4.0
# 2                              0.50 EUR           3.0
# 3                              0.40 EUR           3.0
# 4                              0.20 EUR           4.0
# ..                                  ...           ...
# 478                            0.40 EUR           4.0
# 479                            0.40 EUR           3.0
# 480                            0.20 EUR           3.0
# 481                            0.40 EUR           3.0
# 482                            0.50 EUR           4.0
#
#     2_A_Price in urban areas, rush hour  3_Price_UR_A  \
# 0                              0.50 EUR           4.0
# 1                              0.50 EUR           3.0
# 2                              0.40 EUR           1.0
# 3                              0.40 EUR           3.0
# 4                              0.50 EUR           2.0
# ..                                  ...           ...
# 478                            0.50 EUR           1.0
# 479                            0.40 EUR           1.0
# 480                            0.40 EUR           1.0
# 481                            0.40 EUR           3.0
# 482                            0.50 EUR           4.0
#
#     3_A_Price in urban areas, rush hour  4_Price_UR_A  \
# 0                              0.50 EUR           1.0
# 1                              0.40 EUR           3.0
# 2                              0.10 EUR           2.0
# 3                              0.40 EUR           2.0
# 4                              0.20 EUR           3.0
# ..                                  ...           ...
# 478                            0.10 EUR           4.0
# 479                            0.10 EUR           3.0
# 480                            0.10 EUR           2.0
# 481                            0.40 EUR           3.0
# 482                            0.50 EUR           1.0
#
#     4_A_Price in urban areas, rush hour  5_Price_UR_A  \
# 0                              0.10 EUR           4.0
# 1                              0.40 EUR           3.0
# 2                              0.20 EUR           1.0
# 3                              0.20 EUR           3.0
# 4                              0.40 EUR           2.0
# ..                                  ...           ...
# 478                            0.50 EUR           3.0
# 479                            0.40 EUR           4.0
# 480                            0.20 EUR           3.0
# 481                            0.40 EUR           2.0
# 482                            0.10 EUR           3.0
#
#     5_A_Price in urban areas, rush hour  6_Price_UR_A  \
# 0                              0.50 EUR           2.0
# 1                              0.40 EUR           1.0
# 2                              0.10 EUR           3.0
# 3                              0.40 EUR           3.0
# 4                              0.20 EUR           4.0
# ..                                  ...           ...
# 478                            0.40 EUR           4.0
# 479                            0.50 EUR           NaN
# 480                            0.40 EUR           4.0
# 481                            0.20 EUR           4.0
# 482                            0.40 EUR           3.0
#
#     6_A_Price in urban areas, rush hour  7_Price_UR_A  \
# 0                              0.20 EUR           4.0
# 1                              0.10 EUR           3.0
# 2                              0.40 EUR           2.0
# 3                              0.40 EUR           4.0
# 4                              0.50 EUR           1.0
# ..                                  ...           ...
# 478                            0.50 EUR           3.0
# 479                                   -           NaN
# 480                            0.50 EUR           4.0
# 481                            0.50 EUR           2.0
# 482                            0.40 EUR           1.0
#
#     7_A_Price in urban areas, rush hour  8_Price_UR_A  \
# 0                              0.50 EUR           3.0
# 1                              0.40 EUR           1.0
# 2                              0.20 EUR           4.0
# 3                              0.50 EUR           4.0
# 4                              0.10 EUR           1.0
# ..                                  ...           ...
# 478                            0.40 EUR           3.0
# 479                                   -           NaN
# 480                            0.50 EUR           3.0
# 481                            0.20 EUR           2.0
# 482                            0.10 EUR           4.0
#
#     8_A_Price in urban areas, rush hour  1_Price_UN_A  \
# 0                              0.40 EUR             3
# 1                              0.10 EUR             1
# 2                              0.50 EUR             1
# 3                              0.50 EUR             1
# 4                              0.10 EUR             1
# ..                                  ...           ...
# 478                            0.40 EUR             1
# 479                                   -             1
# 480                            0.40 EUR             1
# 481                            0.20 EUR             1
# 482                            0.50 EUR             3
#
#     1_A_Price in urban areas, outside rush hour  2_Price_UN_A  \
# 0                                      0.40 EUR           1.0
# 1                                      0.10 EUR           4.0
# 2                                      0.10 EUR           4.0
# 3                                      0.10 EUR           4.0
# 4                                      0.10 EUR           1.0
# ..                                          ...           ...
# 478                                    0.10 EUR           4.0
# 479                                    0.10 EUR           4.0
# 480                                    0.10 EUR           2.0
# 481                                    0.10 EUR           2.0
# 482                                    0.40 EUR           4.0
#
#     2_A_Price in urban areas, outside rush hour  3_Price_UN_A  \
# 0                                      0.10 EUR           1.0
# 1                                      0.50 EUR           2.0
# 2                                      0.50 EUR           1.0
# 3                                      0.50 EUR           3.0
# 4                                      0.10 EUR           2.0
# ..                                          ...           ...
# 478                                    0.50 EUR           1.0
# 479                                    0.50 EUR           1.0
# 480                                    0.20 EUR           1.0
# 481                                    0.20 EUR           4.0
# 482                                    0.50 EUR           2.0
#
#     3_A_Price in urban areas, outside rush hour  4_Price_UN_A  \
# 0                                      0.10 EUR           1.0
# 1                                      0.20 EUR           4.0
# 2                                      0.10 EUR           1.0
# 3                                      0.40 EUR           2.0
# 4                                      0.20 EUR           1.0
# ..                                          ...           ...
# 478                                    0.10 EUR           2.0
# 479                                    0.10 EUR           3.0
# 480                                    0.10 EUR           2.0
# 481                                    0.50 EUR           3.0
# 482                                    0.20 EUR           1.0
#
#     4_A_Price in urban areas, outside rush hour  5_Price_UN_A  \
# 0                                      0.10 EUR           4.0
# 1                                      0.50 EUR           1.0
# 2                                      0.10 EUR           1.0
# 3                                      0.20 EUR           1.0
# 4                                      0.10 EUR           1.0
# ..                                          ...           ...
# 478                                    0.20 EUR           1.0
# 479                                    0.40 EUR           4.0
# 480                                    0.20 EUR           3.0
# 481                                    0.40 EUR           2.0
# 482                                    0.10 EUR           2.0
#
#     5_A_Price in urban areas, outside rush hour  6_Price_UN_A  \
# 0                                      0.50 EUR           1.0
# 1                                      0.10 EUR           1.0
# 2                                      0.10 EUR           2.0
# 3                                      0.10 EUR           1.0
# 4                                      0.10 EUR           3.0
# ..                                          ...           ...
# 478                                    0.10 EUR           4.0
# 479                                    0.50 EUR           NaN
# 480                                    0.40 EUR           1.0
# 481                                    0.20 EUR           2.0
# 482                                    0.20 EUR           2.0
#
#     6_A_Price in urban areas, outside rush hour  7_Price_UN_A  \
# 0                                      0.10 EUR           2.0
# 1                                      0.10 EUR           1.0
# 2                                      0.20 EUR           2.0
# 3                                      0.10 EUR           2.0
# 4                                      0.40 EUR           1.0
# ..                                          ...           ...
# 478                                    0.50 EUR           1.0
# 479                                           -           NaN
# 480                                    0.10 EUR           2.0
# 481                                    0.20 EUR           2.0
# 482                                    0.20 EUR           1.0
#
#     7_A_Price in urban areas, outside rush hour  8_Price_UN_A  \
# 0                                      0.20 EUR           4.0
# 1                                      0.10 EUR           1.0
# 2                                      0.20 EUR           3.0
# 3                                      0.20 EUR           3.0
# 4                                      0.10 EUR           1.0
# ..                                          ...           ...
# 478                                    0.10 EUR           1.0
# 479                                           -           NaN
# 480                                    0.20 EUR           4.0
# 481                                    0.20 EUR           2.0
# 482                                    0.10 EUR           3.0
#
#     8_A_Price in urban areas, outside rush hour  1_Price_O_A  \
# 0                                      0.50 EUR            3
# 1                                      0.10 EUR            1
# 2                                      0.40 EUR            2
# 3                                      0.40 EUR            2
# 4                                      0.10 EUR            2
# ..                                          ...          ...
# ...
# ..                                       ...               ...
# 478           university (less than 4 years)               1.0
# 479                                      NaN               NaN
# 480           university (more than 4 years)               4.0
# 481           university (more than 4 years)               1.0
# 482                              high school               3.0
#
#      player.effect_rp_others  player.family  \
# 0                        1.0            3.0
# 1                        6.0            3.0
# 2                        2.0            2.0
# 3                        1.0            2.0
# 4                        7.0            2.0
# ..                       ...            ...
# 478                      1.0            1.0
# 479                      NaN            NaN
# 480                      4.0            4.0
# 481                      1.0            1.0
# 482                      3.0            1.0
#
#     How many people does your household have including you?  player.gender  \
# 0                                                    3                 1.0
# 1                                                    3                 0.0
# 2                                                    2                 0.0
# 3                                                    2                 0.0
# 4                                                    2                 0.0
# ..                                                 ...                 ...
# 478                                                  1                 0.0
# 479                                                NaN                 NaN
# 480                                                  4                 0.0
# 481                                                  1                 0.0
# 482                                                  1                 1.0
#
#     How do you identify as?  player.id_in_group  player.income  \
# 0                       man                 1.0            0.0
# 1                     woman                 2.0            3.0
# 2                     woman                 3.0            2.0
# 3                     woman                 4.0            0.0
# 4                     woman                 5.0            1.0
# ..                      ...                 ...            ...
# 478                   woman               385.0            0.0
# 479                     NaN                 NaN            NaN
# 480                   woman               396.0            4.0
# 481                   woman               399.0            1.0
# 482                     man               400.0            1.0
#
#     What is your income per year?  player.my_trip  \
# 0               less than 10k EUR            11.0
# 1                     30k-40k EUR            11.0
# 2                     20k-30k EUR            10.0
# 3               less than 10k EUR             9.0
# 4                     10k-20k EUR             9.0
# ..                            ...             ...
# 478             less than 10k EUR             7.0
# 479                           NaN             NaN
# 480             more than 40k EUR             9.0
# 481                   10k-20k EUR             9.0
# 482                   10k-20k EUR            10.0
#
#     Considering the last year, how often (in %) did you use your chosen transport mode for your daily trip?  \
# 0                                                 100%
# 1                                                 100%
# 2                                                  90%
# 3                                                  80%
# 4                                                  80%
# ..                                                 ...
# 478                                                60%
# 479                                                NaN
# 480                                                80%
# 481                                                80%
# 482                                                90%
#
#      player.revenues  \
# 0                6.0
# 1                3.0
# 2                3.0
# 3                1.0
# 4                6.0
# ..               ...
# 478              3.0
# 479              NaN
# 480              4.0
# 481              1.0
# 482              1.0
#
#     Revenues collected through taxes are used to create a well-functioning welfare state and society:  \
# 0                                                    6
# 1                                                    3
# 2                                                    3
# 3                                                    1
# 4                                                    6
# ..                                                 ...
# 478                                                  3
# 479                                                NaN
# 480                                                  4
# 481                                                  1
# 482                                                  1
#
#      player.road_pricing  \
# 0                    2.0
# 1                    6.0
# 2                    7.0
# 3                    1.0
# 4                    6.0
# ..                   ...
# 478                  2.0
# 479                  NaN
# 480                  5.0
# 481                  1.0
# 482                  3.0
#
#     The introduction of policies such as road pricing will alleviate congestion problems:  \
# 0                                                    2
# 1                                                    6
# 2                                                    7
# 3                                                    1
# 4                                                    6
# ..                                                 ...
# 478                                                  2
# 479                                                NaN
# 480                                                  5
# 481                                                  1
# 482                                                  3
#
#      player.tax  \
# 0           7.0
# 1           4.0
# 2           4.0
# 3           1.0
# 4           5.0
# ..          ...
# 478         5.0
# 479         NaN
# 480         3.0
# 481         5.0
# 482         5.0
#
#     Tax revenues should be used to help those who are more in need:  \
# 0                                                    7
# 1                                                    4
# 2                                                    4
# 3                                                    1
# 4                                                    5
# ..                                                 ...
# 478                                                  5
# 479                                                NaN
# 480                                                  3
# 481                                                  5
# 482                                                  5
#
#      player.tax_level  player.trust_county County council:  \
# 0                 2.0                  1.0               1
# 1                 7.0                  5.0               5
# 2                 4.0                  3.0               3
# 3                 2.0                  1.0               1
# 4                 5.0                  6.0               6
# ..                ...                  ...             ...
# 478               5.0                  5.0               5
# 479               NaN                  NaN             NaN
# 480               4.0                  1.0               1
# 481               7.0                  1.0               1
# 482               4.0                  1.0               1
#
#      player.trust_government Government:  player.trust_municipality  \
# 0                        4.0           4                        1.0
# 1                        1.0           1                        4.0
# 2                        2.0           2                        4.0
# 3                        1.0           1                        3.0
# 4                        7.0           7                        4.0
# ..                       ...         ...                        ...
# 478                      1.0           1                        5.0
# 479                      NaN         NaN                        NaN
# 480                      1.0           1                        1.0
# 481                      2.0           2                        1.0
# 482                      4.0           4                        4.0
#
#     Municipal council  player.trust_parlament  \
# 0                   1                     3.0
# 1                   4                     4.0
# 2                   4                     5.0
# 3                   3                     9.0
# 4                   4                     5.0
# ..                ...                     ...
# 478                 5                     2.0
# 479               NaN                     NaN
# 480                 1                     1.0
# 481                 1                     1.0
# 482                 4                     4.0
#
#     How much do you personally trust the following institutions from 1 to 7, where 1 means ‘No trust at all’ and 7 means ‘Trust compltely’? Parlament:   \
# 0                                                    3
# 1                                                    4
# 2                                                    5
# 3                                        I do not know
# 4                                                    5
# ..                                                 ...
# 478                                                  2
# 479                                                NaN
# 480                                                  1
# 481                                                  1
# 482                                                  4
#
#      player.trust_parties Political parties:   player.trust_politicians  \
# 0                     4.0                   4                       5.0
# 1                     1.0                   1                       1.0
# 2                     2.0                   2                       3.0
# 3                     1.0                   1                       1.0
# 4                     3.0                   3                       4.0
# ..                    ...                 ...                       ...
# 478                   1.0                   1                       1.0
# 479                   NaN                 NaN                       NaN
# 480                   1.0                   1                       1.0
# 481                   1.0                   1                       1.0
# 482                   1.0                   1                       1.0
#
#     National politicians:  player.vote  \
# 0                       5          3.0
# 1                       1          1.0
# 2                       3          1.0
# 3                       1         13.0
# 4                       4          3.0
# ..                    ...          ...
# 478                     1          1.0
# 479                   NaN          NaN
# 480                     1          1.0
# 481                     1         13.0
# 482                     1         13.0
#
#     Which political party you voted for in the last election?  \
# 0                                       Unidas Podemos
# 1                                      Partido Popular
# 2                                      Partido Popular
# 3                                prefiero no responder
# 4                                       Unidas Podemos
# ..                                                 ...
# 478                                    Partido Popular
# 479                                                NaN
# 480                                    Partido Popular
# 481                              prefiero no responder
# 482                              prefiero no responder
#
#      player.year_born session.code.1  subsession.round_number      treatment.1
# 0              1979.0       uln4i2w2                      1.0         Baseline
# 1              1999.0       uln4i2w2                      1.0        Pollution
# 2              1999.0       uln4i2w2                      1.0  Public Services
# 3              1999.0       uln4i2w2                      1.0     Road Pricing
# 4              2000.0       uln4i2w2                      1.0      Social Norm
# ..                ...            ...                      ...              ...
# 478            1997.0       heqbzlzk                      1.0      Social Norm
# 479               NaN            NaN                      NaN              NaN
# 480            1998.0       heqbzlzk                      1.0         Baseline
# 481            1971.0       heqbzlzk                      1.0     Road Pricing
# 482            1993.0       heqbzlzk                      1.0      Social Norm
#
# [483 rows x 296 columns]

# %%
column= 'What is the approximate cost of this trip (fuel, road tolls, parking, ticket price etc.), one way? If you are traveling by public transport and have a period ticket, please consider the average price per trip.'
tab=df1.groupby([column]).count()*100/num_participants
#df1=df1.rename(columns={'Do you own or have access to a motorbyke?':'Do you own or have access\n to a motorbike?'})
tab=tab.loc[['less than 1 EUR','1-2.5 EUR','2.5-4.99 EUR','5-9.99 EUR','10-19.99 EUR','More than 20 EUR']]
#tab=tab.rename(index={'Education place':'Education\n place','Trip within my job/for job purposes':'Trip within\n my job/for\n job purposes','Bring/pick up children or adult':'Bring/pick\n up children\n or adult','Errands or shopping':'Errands or\n shopping','Visit family or friend':'Visit family\n or friend','Leisure activity (cultural, sport, etc)':'Leisure \nactivity (cultural,\n sport, etc)'})

ax=tab.plot(kind='bar', y=1, title = 'What is the approximate cost of this trip (fuel, road tolls, parking, ticket\n price etc.), one way? If you are traveling by public transport and have\n a period ticket, please consider the average price per trip.', figsize=(8,4), color='moccasin', edgecolor='k', legend=False)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
#plt.ylim([0,181])
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\price.png')
plt.show()

# %%
column= 'If you were to make this trip using a different mode of travel than your usual mode, which would be the best alternative?'
tab=df1.groupby([column]).count()*100/num_participants
#df1=df1.rename(columns={'Do you own or have access to a motorbyke?':'Do you own or have access\n to a motorbike?'})
#tab=tab.loc[['Private car (driver)','Private car (passenger)','Bus','Metro, tram or light rail','Train','Walk','Bike (regular or electric)','E-scooter','Motorcycle','Ferry','I have no available alternatives']]
tab=tab.rename(index={'Private car (driver)':'Private car\n (driver)','Metro, tram or light rail':'Metro, tram\n or light rail','Private car (passenger)':'Private car\n (passenger)','Bike (regular or electric)':'Bike (regular\n or electric)','I have no available alternatives':'I have no\n available\n alternatives'})

ax=tab.plot(kind='bar', y=1, title = 'If you were to make this trip using a different mode of\n travel than your usual mode, which would be the best alternative?', figsize=(10,4), color='moccasin', edgecolor='k', legend=False)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
#plt.ylim([0,181])
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\alt.png')
plt.show()

# %%
df1.columns[42]
# Out:
# 'player.trip_alternative_justification'

# %%
#control question

column= 'control_question1'
tab=df1.groupby([column]).count()*100/num_participants
#df1=df1.rename(columns={'Do you own or have access to a motorbyke?':'Do you own or have access\n to a motorbike?'})
#tab=tab.loc[['Almost as good as my current choice','Somewhat worse than my current choice','Much worse than my current choice','I do not know']]
#tab=tab.rename(index={'Almost as good as my current choice':'Almost as good as\n my current choice','Somewhat worse than my current choice':'Somewhat worse than\n my current choice','Much worse than my current choice':'Much worse than\n my current choice'})

ax=tab.plot(kind='bar', y=1, title = column, figsize=(3,3), color='moccasin', edgecolor='k', legend=False)
plt.ylim([0,100])
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\control.png')
plt.show()

# %%
column= 'How would you rate your alternative?'
tab=df1.groupby([column]).count()*100/num_participants
#df1=df1.rename(columns={'Do you own or have access to a motorbyke?':'Do you own or have access\n to a motorbike?'})
tab=tab.loc[['Almost as good as my current choice','Somewhat worse than my current choice','Much worse than my current choice','I do not know']]
tab=tab.rename(index={'Almost as good as my current choice':'Almost as good as\n my current choice','Somewhat worse than my current choice':'Somewhat worse than\n my current choice','Much worse than my current choice':'Much worse than\n my current choice'})

ax=tab.plot(kind='bar', y=1, title = column, figsize=(7,4), color='moccasin', edgecolor='k', legend=False)
#plt.ylim([0,181])
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\rate_alt.png')
plt.show()

# %%
column= 'What is your employment status?'
tab=df1.groupby([column]).count()*100/num_participants

ax=tab.plot(kind='bar', y=1, title = column, figsize=(12,4), color='moccasin', edgecolor='k', legend=False)
#plt.ylim([0,181])
plt.xticks(rotation=0)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\gender.png')
plt.show()

# %%
#column= 'In which year were you born?'
#dens_a = stats.gaussian_kde(a['player.my_trip'])
#n, x_a, _ = plt.hist(df1[column],bins=30,density=True, label='Set B', color='moccasin', edgecolor='black')
#plt.plot(x_a,dens_a(x_a), label='Set B probability density function',color='r')
#a.groupby([column]).count().plot(kind='bar', y=1, title='', figsize=(7,5),color='moccasin', edgecolor='k', legend=False)
#plt.yticks([0,0.05,0.1,0.15,0.2],[0,5,10,15,20])
#plt.title('In which year were you born?')
#plt.tight_layout(pad=2, w_pad=8, h_pad=2)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\age.png')
#plt.show()

# %%
column= 'How do you identify as?'
tab=df1.groupby([column]).count()*100/num_participants
#df1=df1.rename(columns={'Do you own or have access to a motorbyke?':'Do you own or have access\n to a motorbike?'})
tab=tab.loc[['woman','man','prefer not to say']]
#tab=tab.rename(index={'Education place':'Education\n place','Trip within my job/for job purposes':'Trip within\n my job/for\n job purposes','Bring/pick up children or adult':'Bring/pick\n up children\n or adult','Errands or shopping':'Errands or\n shopping','Visit family or friend':'Visit family\n or friend','Leisure activity (cultural, sport, etc)':'Leisure \nactivity (cultural,\n sport, etc)'})

ax=tab.plot(kind='bar', y=1, title = column, figsize=(5,4), color='moccasin', edgecolor='k', legend=False)
#plt.ylim([0,181])
plt.xticks(rotation=0)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\gender.png')
plt.show()

# %%
column= 'What is your highest level of education?'
tab=df1.groupby([column]).count()*100/num_participants
tab=tab.rename(index={'elementary school':'elementary\n school','high school':'high\n school','university (less than 4 years)':'university (less\n than 4 years)','university (more than 4 years)':'university (more\n than 4 years)'})

ax=tab.plot(kind='bar', y=1, title = column, figsize=(6,4), color='moccasin', edgecolor='k', legend=False)
#plt.ylim([0,181])
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\edu.png')
plt.show()

# %%
column= 'What is your income per year?'
tab=df1.groupby([column]).count()*100/num_participants
#df1=df1.rename(columns={'Do you own or have access to a motorbyke?':'Do you own or have access\n to a motorbike?'})
tab=tab.loc[['less than 10k EUR','10k-20k EUR','20k-30k EUR','30k-40k EUR','more than 40k EUR','prefer not to say']]
#tab=tab.rename(index={'elementary school':'elementary\n school','high school':'high\n school','university (less than 4 years)':'university (less\n than 4 years)','university (more than 4 years)':'university (more\n than 4 years)'})

ax=tab.plot(kind='bar', y=1, title = column, figsize=(10,4), color='moccasin', edgecolor='k', legend=False)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
#plt.ylim([0,181])
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\income.png')
plt.show()

# %%
column= 'How many people does your household have including you?'
tab=df1.groupby([column]).count()*100/num_participants
#df1=df1.rename(columns={'Do you own or have access to a motorbyke?':'Do you own or have access\n to a motorbike?'})
#tab=tab.loc[['woman','man','prefer not to say']]
#tab=tab.rename(index={'elementary school':'elementary\n school','high school':'high\n school','university (less than 4 years)':'university (less\n than 4 years)','university (more than 4 years)':'university (more\n than 4 years)'})

ax=tab.plot(kind='bar', y=1, title = column, figsize=(6,4), color='moccasin', edgecolor='k', legend=False)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
#plt.ylim([0,181])
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\number_people.png')
plt.show()

# %%
column= 'How many children under the age of 15 live with you?'
tab=df1.groupby([column]).count()*100/num_participants
#df1=df1.rename(columns={'Do you own or have access to a motorbyke?':'Do you own or have access\n to a motorbike?'})
#tab=tab.loc[['woman','man','prefer not to say']]
#tab=tab.rename(index={'elementary school':'elementary\n school','high school':'high\n school','university (less than 4 years)':'university (less\n than 4 years)','university (more than 4 years)':'university (more\n than 4 years)'})

ax=tab.plot(kind='bar', y=1, title = column, figsize=(6,4), color='moccasin', edgecolor='k', legend=False)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
#plt.ylim([0,181])
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\child.png')
plt.show()

# %%
column= 'Which political party you voted for in the last election?'
tab=df1.groupby([column]).count()*100/num_participants
#df1=df1.rename(columns={'Do you own or have access to a motorbyke?':'Do you own or have access\n to a motorbike?'})
#tab=tab.loc[['PSOE','Partido Popular','Vox','Unidas Podemos','ERC-Cat','Ciudadanos','JxCat','PNV','EHB','MP-EQUO','BNG','Compromís','otro partido','prefiero no responder']]
tab=tab.rename(index={'Partido Popular':'Partido\n Popular','Unidas Podemos':'Unidas\n Podemos','otro partido':'otro\n partido','prefiero no responder':'prefiero \nno responder'})

ax=tab.plot(kind='bar', y=1, title = column, figsize=(13,4), color='moccasin', edgecolor='k', legend=False)
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
#plt.ylim([0,181])
plt.xticks(rotation=0)
plt.xlabel('')
plt.tight_layout(pad=2,w_pad=8, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\vote.png')
plt.show()

# %% [markdown]
# ## All plots

# %% [markdown]
# Some alternatives on x-axis are not in logical order

# %%
for i in [9,13,15,19,21,23,25,26,28,31,33,36,38,40,42,44,209,211,213,215,217,219,221,223,225,227,229,231,233,235,237,239,241]:
    column= df1.columns[i]
    
    df1.groupby([column]).count().plot(kind='bar', y=1, title=column, figsize=(9,9),color='moccasin', edgecolor='k', legend=False)
    plt.xticks(rotation=70)
    plt.xlabel('')
    #plt.axis().set_xlabel('')
    #plt.figure(figsize=(9,9))
    #plt.tight_layout(pad=2, w_pad=8, h_pad=2)
    #plt.savefig('ABCharts_all_madrid%d.png' %i)
    plt.show()

# %%
df1=df1.rename(columns={"How much do you personally trust the following institutions from 1 to 7, where 1 means ‘No trust at all’ and 7 means ‘Trust compltely’? Parlament: ": "Parlament","County council:":"County council","Government:": "Government", "National politicians:":"National politicians", "Political parties: ":"Political parties"})

# %%
column= 'Parlament'
    
df1.groupby([column]).count().plot(kind='bar', y=1, title=column, figsize=(9,9),color='moccasin', edgecolor='k', legend=False)
plt.xticks(rotation=70)
plt.xlabel('')

plt.show()

# %%
# for columns Parlamet, County council, Government, National politicians, Political parties compute the average trust and plot it
columns = ['Parlament','County council','Government','National politicians','Political parties']
df1[columns] = df1[columns].apply(pd.to_numeric, errors='coerce', axis=1)
df1[columns].mean().plot(kind='bar', figsize=(8,4), color='moccasin', edgecolor='k', legend=False)
plt.xticks(rotation=0)
plt.xlabel('')
plt.title('Average trust in institutions')
plt.tight_layout(pad=2, w_pad=8, h_pad=2)
plt.show()

# %%
df1
# Out:
#     participant.code        treatment  participant.id_in_session  \
# 0           ooxl8r2l         Baseline                          1
# 1           i6cytpys        Pollution                          2
# 2           js43i4q6  Public Services                          3
# 3           wjalnvbm     Road Pricing                          4
# 4           bt4ub78z      Social Norm                          5
# ..               ...              ...                        ...
# 478         emins2el      Social Norm                        385
# 479         rz5has1n        Pollution                        392
# 480         99ekoser         Baseline                        396
# 481         8nr05dcp     Road Pricing                        399
# 482         f1wh7sy7      Social Norm                        400
#
#      player.municipality_home What is the municipality of your home address?  \
# 0                          81                                Madrid - Centro
# 1                          85                 Madrid - Fuencarral - El Pardo
# 2                          78                            Madrid - Arganzuela
# 3                          73                                        Leganés
# 4                           3                                     Alamo (El)
# ..                        ...                                            ...
# 478                        81                                Madrid - Centro
# 479                        83                              Madrid - Chamberí
# 480                        85                 Madrid - Fuencarral - El Pardo
# 481                        46                               Collado Villalba
# 482                        64                                         Getafe
#
#      player.driving_license Do you have a driver license?  \
# 0                         1                           Yes
# 1                         1                           Yes
# 2                         1                           Yes
# 3                         1                           Yes
# 4                         1                           Yes
# ..                      ...                           ...
# 478                       1                           Yes
# 479                       1                           Yes
# 480                       1                           Yes
# 481                       1                           Yes
# 482                       1                           Yes
#
#      player.access_to_car Do you own or have access to a car?  \
# 0                       0                               I own
# 1                       1    I do not own, but have access to
# 2                       1    I do not own, but have access to
# 3                       1    I do not own, but have access to
# 4                       0                               I own
# ..                    ...                                 ...
# 478                     0                               I own
# 479                     2             I do not have access to
# 480                     0                               I own
# 481                     0                               I own
# 482                     0                               I own
#
#      player.car_type  \
# 0                0.0
# 1                1.0
# 2                1.0
# 3                1.0
# 4                0.0
# ..               ...
# 478              0.0
# 479              NaN
# 480              0.0
# 481              1.0
# 482              1.0
#
#     What kind of vehicle do you have access to? If you have access to multiple vehicles choose the one you use the most.  \
# 0                                             Gasoline
# 1                                               Diesel
# 2                                               Diesel
# 3                                               Diesel
# 4                                             Gasoline
# ..                                                 ...
# 478                                           Gasoline
# 479                                                  -
# 480                                           Gasoline
# 481                                             Diesel
# 482                                             Diesel
#
#      player.buy_car_type Are you planning to buy a car in the next year?  \
# 0                    NaN                                               -
# 1                    4.0                                              No
# 2                    4.0                                              No
# 3                    4.0                                              No
# 4                    NaN                                               -
# ..                   ...                                             ...
# 478                  NaN                                               -
# 479                  4.0                                              No
# 480                  NaN                                               -
# 481                  NaN                                               -
# 482                  NaN                                               -
#
#      player.access_to_bike  \
# 0                        1
# 1                        1
# 2                        0
# 3                        0
# 4                        0
# ..                     ...
# 478                      2
# 479                      2
# 480                      0
# 481                      2
# 482                      2
#
#     Do you own or have access to a bike (electric or regular)?  \
# 0                     I do not own, but have access to
# 1                     I do not own, but have access to
# 2                                                I own
# 3                                                I own
# 4                                                I own
# ..                                                 ...
# 478                            I do not have access to
# 479                            I do not have access to
# 480                                              I own
# 481                            I do not have access to
# 482                            I do not have access to
#
#      player.access_to_motorbyke Do you own or have access to a motorbyke?  \
# 0                             2                   I do not have access to
# 1                             2                   I do not have access to
# 2                             2                   I do not have access to
# 3                             2                   I do not have access to
# 4                             1          I do not own, but have access to
# ..                          ...                                       ...
# 478                           2                   I do not have access to
# 479                           2                   I do not have access to
# 480                           2                   I do not have access to
# 481                           2                   I do not have access to
# 482                           2                   I do not have access to
#
#      player.access_to_scooter Do you own or have access to a e-scooter?  \
# 0                           2                   I do not have access to
# 1                           2                   I do not have access to
# 2                           2                   I do not have access to
# 3                           2                   I do not have access to
# 4                           0                                     I own
# ..                        ...                                       ...
# 478                         2                   I do not have access to
# 479                         2                   I do not have access to
# 480                         2                   I do not have access to
# 481                         2                   I do not have access to
# 482                         2                   I do not have access to
#
#      player.employ_status What is your employment status?  \
# 0                       2                         Student
# 1                       0                Full-time worker
# 2                       0                Full-time worker
# 3                       2                         Student
# 4                       2                         Student
# ..                    ...                             ...
# 478                     2                         Student
# 479                     0                Full-time worker
# 480                     0                Full-time worker
# 481                     0                Full-time worker
# 482                     0                Full-time worker
#
#      player.municipality_destination  \
# 0                                 81
# 1                                 82
# 2                                 94
# 3                                 81
# 4                                 79
# ..                               ...
# 478                               64
# 479                               86
# 480                               92
# 481                               46
# 482                               91
#
#     Where is the destination of this trip? (municipality)  \
# 0                                      Madrid - Centro
# 1                                   Madrid - Chamartín
# 2                                      Madrid - Tetuán
# 3                                      Madrid - Centro
# 4                                     Madrid - Barajas
# ..                                                 ...
# 478                                             Getafe
# 479                                 Madrid - Hortaleza
# 480                                 Madrid - Salamanca
# 481                                   Collado Villalba
# 482                                    Madrid - Retiro
#
#      player.trip_purpose What is the purpose/destination of this trip?  \
# 0                      3               Bring/pick up children or adult
# 1                      0                                     Workplace
# 2                      0                                     Workplace
# 3                      1                               Education place
# 4                      4                           Errands or shopping
# ..                   ...                                           ...
# 478                    1                               Education place
# 479                    0                                     Workplace
# 480                    0                                     Workplace
# 481                    2           Trip within my job/for job purposes
# 482                    0                                     Workplace
#
#     player.trip_other  player.trip_moment  \
# 0                 NaN                   0
# 1                 NaN                   0
# 2                 NaN                   0
# 3                 NaN                   2
# 4                 NaN                   2
# ..                ...                 ...
# 478               NaN                   2
# 479               NaN                   0
# 480               NaN                   0
# 481               NaN                   0
# 482               NaN                   0
#
#     At what time of the day do you typically travel?  player.trip_mode  \
# 0                                            morning                 5
# 1                                            morning                 3
# 2                                            morning                 2
# 3                                            evening                 2
# 4                                            evening                 0
# ..                                               ...               ...
# 478                                          evening                 3
# 479                                          morning                 3
# 480                                          morning                 1
# 481                                          morning                 0
# 482                                          morning                 3
#
#     By which mode do you travel with during this trip? If you travel with multiple modes choose the mode that takes you the longest time.  \
# 0                                                 Walk
# 1                            Metro, tram or light rail
# 2                                                  Bus
# 3                                                  Bus
# 4                                 Private car (driver)
# ..                                                 ...
# 478                          Metro, tram or light rail
# 479                          Metro, tram or light rail
# 480                            Private car (passenger)
# 481                               Private car (driver)
# 482                          Metro, tram or light rail
#
#     player.mode_other  player.trip_traffic  \
# 0                 NaN                    2
# 1                 NaN                    1
# 2                 NaN                    0
# 3                 NaN                    1
# 4                 NaN                    1
# ..                ...                  ...
# 478               NaN                    1
# 479               NaN                    1
# 480               NaN                    1
# 481               NaN                    2
# 482               NaN                    0
#
#     How are the traffic conditions normally on the trip?  player.trip_time  \
# 0                               Little or no congested                   0
# 1                                   Somewhat congested                   1
# 2                                    Heavily congested                   1
# 3                                   Somewhat congested                   3
# 4                                   Somewhat congested                   1
# ..                                                 ...                 ...
# 478                                 Somewhat congested                   2
# 479                                 Somewhat congested                   2
# 480                                 Somewhat congested                   1
# 481                             Little or no congested                   0
# 482                                  Heavily congested                   2
#
#     What is the approximate travel time of this trip (one way)?  \
# 0                                        10-19 minutes
# 1                                        20-39 minutes
# 2                                        20-39 minutes
# 3                                            1-2 hours
# 4                                        20-39 minutes
# ..                                                 ...
# 478                                      40-59 minutes
# 479                                      40-59 minutes
# 480                                      20-39 minutes
# 481                                      10-19 minutes
# 482                                      40-59 minutes
#
#      player.trip_cost  \
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   5
# ..                ...
# 478                 2
# 479                 2
# 480                 1
# 481                 2
# 482                 3
#
#     What is the approximate cost of this trip (fuel, road tolls, parking, ticket price etc.), one way? If you are traveling by public transport and have a period ticket, please consider the average price per trip.  \
# 0                                      less than 1 EUR
# 1                                      less than 1 EUR
# 2                                      less than 1 EUR
# 3                                      less than 1 EUR
# 4                                     More than 20 EUR
# ..                                                 ...
# 478                                       2.5-4.99 EUR
# 479                                       2.5-4.99 EUR
# 480                                          1-2.5 EUR
# 481                                       2.5-4.99 EUR
# 482                                         5-9.99 EUR
#
#      player.trip_tolls  player.trip_alternative_mode  \
# 0                  NaN                             7
# 1                  NaN                             2
# 2                  NaN                             4
# 3                  NaN                             4
# 4                  1.0                             1
# ..                 ...                           ...
# 478                NaN                             1
# 479                NaN                             0
# 480                1.0                             3
# 481                1.0                            10
# 482                NaN                             0
#
#     If you were to make this trip using a different mode of travel than your usual mode, which would be the best alternative?  \
# 0                                            E-scooter
# 1                                                  Bus
# 2                                                Train
# 3                                                Train
# 4                              Private car (passenger)
# ..                                                 ...
# 478                            Private car (passenger)
# 479                               Private car (driver)
# 480                          Metro, tram or light rail
# 481                   I have no available alternatives
# 482                               Private car (driver)
#
#      player.trip_alternative_rate   How would you rate your alternative?  \
# 0                             1.0  Somewhat worse than my current choice
# 1                             0.0    Almost as good as my current choice
# 2                             1.0  Somewhat worse than my current choice
# 3                             1.0  Somewhat worse than my current choice
# 4                             0.0    Almost as good as my current choice
# ..                            ...                                    ...
# 478                           0.0    Almost as good as my current choice
# 479                           0.0    Almost as good as my current choice
# 480                           1.0  Somewhat worse than my current choice
# 481                           NaN                                      -
# 482                           0.0    Almost as good as my current choice
#
#                  player.trip_alternative_justification  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 478                                                NaN
# 479                                                NaN
# 480                                                NaN
# 481  En transporte público llevaria más tiempo. No ...
# 482                                                NaN
#
#      player.inequality_perception  \
# 0                               1
# 1                               3
# 2                               1
# 3                               2
# 4                               5
# ..                            ...
# 478                             1
# 479                             4
# 480                             4
# 481                             1
# 482                             3
#
#     What type of society do you think is Spain today – which diagram comes the closest?  \
# 0                                                    A
# 1                                                    C
# 2                                                    A
# 3                                                    B
# 4                                                    E
# ..                                                 ...
# 478                                                  A
# 479                                                  D
# 480                                                  D
# 481                                                  A
# 482                                                  C
#
#      player.inequality_wish  \
# 0                         4
# 1                         4
# 2                         4
# 3                         5
# 4                         4
# ..                      ...
# 478                       4
# 479                       4
# 480                       5
# 481                       3
# 482                       4
#
#     What do you think Spain ought to be like – which would you prefer?  \
# 0                                                    D
# 1                                                    D
# 2                                                    D
# 3                                                    E
# 4                                                    D
# ..                                                 ...
# 478                                                  D
# 479                                                  D
# 480                                                  E
# 481                                                  C
# 482                                                  D
#
#      player.income_distribution  \
# 0                             4
# 1                             2
# 2                             4
# 3                             3
# 4                             3
# ..                          ...
# 478                           3
# 479                           2
# 480                           2
# 481                           4
# 482                           3
#
#     How fair do you think the wealth distribution is in your country?  \
# 0                                          Very unfair
# 1                                                 Fair
# 2                                          Very unfair
# 3                                               Unfair
# 4                                               Unfair
# ..                                                 ...
# 478                                             Unfair
# 479                                               Fair
# 480                                               Fair
# 481                                        Very unfair
# 482                                             Unfair
#
#     session.code  control_question1  control_question2  attributes_binary_1  \
# 0       uln4i2w2                  3                NaN                  1.0
# 1       uln4i2w2                  3                NaN                  0.0
# 2       uln4i2w2                  3                NaN                  0.0
# 3       uln4i2w2                  3                NaN                  0.0
# 4       uln4i2w2                  3                NaN                  0.0
# ..           ...                ...                ...                  ...
# 478     heqbzlzk                  3                NaN                  1.0
# 479     heqbzlzk                  3                NaN                  NaN
# 480     heqbzlzk                  3                NaN                  0.0
# 481     heqbzlzk                  2                3.0                  0.0
# 482     heqbzlzk                  3                NaN                  1.0
#
#      attributes_binary_2  attributes_binary_3  attributes_binary_4  \
# 0                    1.0                  1.0                  1.0
# 1                    0.0                  0.0                  1.0
# 2                    0.0                  1.0                  0.0
# 3                    1.0                  0.0                  0.0
# 4                    0.0                  0.0                  0.0
# ..                   ...                  ...                  ...
# 478                  1.0                  1.0                  1.0
# 479                  NaN                  NaN                  NaN
# 480                  0.0                  0.0                  1.0
# 481                  0.0                  0.0                  0.0
# 482                  1.0                  0.0                  0.0
#
#      attributes_binary_5  1_alternative1  1_policy_choice  \
# 0                    0.0               5              3.0
# 1                    0.0               5              1.0
# 2                    0.0               5              2.0
# 3                    0.0               5              1.0
# 4                    0.0               1              2.0
# ..                   ...             ...              ...
# 478                  0.0               4              3.0
# 479                  NaN               4              1.0
# 480                  0.0               4              1.0
# 481                  0.0               5              3.0
# 482                  0.0               1              3.0
#
#      1_What is your preferred policy type?  2_policy_choice  \
# 0    None of them, keep the current system              3.0
# 1                                        A              1.0
# 2                                        B              3.0
# 3                                        A              2.0
# 4                                        B              1.0
# ..                                     ...              ...
# 478  None of them, keep the current system              1.0
# 479                                      A              2.0
# 480                                      A              1.0
# 481  None of them, keep the current system              3.0
# 482  None of them, keep the current system              3.0
#
#      2_What is your preferred policy type?  3_policy_choice  \
# 0    None of them, keep the current system              3.0
# 1                                        A              1.0
# 2    None of them, keep the current system              2.0
# 3                                        B              2.0
# 4                                        A              1.0
# ..                                     ...              ...
# 478                                      A              1.0
# 479                                      B              1.0
# 480                                      A              1.0
# 481  None of them, keep the current system              3.0
# 482  None of them, keep the current system              1.0
#
#      3_What is your preferred policy type?  4_policy_choice  \
# 0    None of them, keep the current system              2.0
# 1                                        A              2.0
# 2                                        B              1.0
# 3                                        B              2.0
# 4                                        A              2.0
# ..                                     ...              ...
# 478                                      A              2.0
# 479                                      A              2.0
# 480                                      A              2.0
# 481  None of them, keep the current system              3.0
# 482                                      A              1.0
#
#      4_What is your preferred policy type?  5_policy_choice  \
# 0                                        B              3.0
# 1                                        B              2.0
# 2                                        A              1.0
# 3                                        B              2.0
# 4                                        B              1.0
# ..                                     ...              ...
# 478                                      B              2.0
# 479                                      B              NaN
# 480                                      B              1.0
# 481  None of them, keep the current system              3.0
# 482                                      A              1.0
#
#      5_What is your preferred policy type?  6_policy_choice  \
# 0    None of them, keep the current system              3.0
# 1                                        B              1.0
# 2                                        A              2.0
# 3                                        B              2.0
# 4                                        A              2.0
# ..                                     ...              ...
# 478                                      B              1.0
# 479                                      -              NaN
# 480                                      A              2.0
# 481  None of them, keep the current system              3.0
# 482                                      A              3.0
#
#      6_What is your preferred policy type?  7_policy_choice  \
# 0    None of them, keep the current system              3.0
# 1                                        A              1.0
# 2                                        B              2.0
# 3                                        B              1.0
# 4                                        B              2.0
# ..                                     ...              ...
# 478                                      A              1.0
# 479                                      -              NaN
# 480                                      B              2.0
# 481  None of them, keep the current system              3.0
# 482  None of them, keep the current system              3.0
#
#      7_What is your preferred policy type?  8_policy_choice  \
# 0    None of them, keep the current system              3.0
# 1                                        A              1.0
# 2                                        B              2.0
# 3                                        A              2.0
# 4                                        B              2.0
# ..                                     ...              ...
# 478                                      A              2.0
# 479                                      -              NaN
# 480                                      B              1.0
# 481  None of them, keep the current system              3.0
# 482  None of them, keep the current system              3.0
#
#      8_What is your preferred policy type?  1_Price_UR_A  \
# 0    None of them, keep the current system             3
# 1                                        A             4
# 2                                        B             4
# 3                                        B             3
# 4                                        B             2
# ..                                     ...           ...
# 478                                      B             3
# 479                                      -             3
# 480                                      A             2
# 481  None of them, keep the current system             3
# 482  None of them, keep the current system             4
#
#     1_A_Price in urban areas, rush hour  2_Price_UR_A  \
# 0                              0.40 EUR           4.0
# 1                              0.50 EUR           4.0
# 2                              0.50 EUR           3.0
# 3                              0.40 EUR           3.0
# 4                              0.20 EUR           4.0
# ..                                  ...           ...
# 478                            0.40 EUR           4.0
# 479                            0.40 EUR           3.0
# 480                            0.20 EUR           3.0
# 481                            0.40 EUR           3.0
# 482                            0.50 EUR           4.0
#
#     2_A_Price in urban areas, rush hour  3_Price_UR_A  \
# 0                              0.50 EUR           4.0
# 1                              0.50 EUR           3.0
# 2                              0.40 EUR           1.0
# 3                              0.40 EUR           3.0
# 4                              0.50 EUR           2.0
# ..                                  ...           ...
# 478                            0.50 EUR           1.0
# 479                            0.40 EUR           1.0
# 480                            0.40 EUR           1.0
# 481                            0.40 EUR           3.0
# 482                            0.50 EUR           4.0
#
#     3_A_Price in urban areas, rush hour  4_Price_UR_A  \
# 0                              0.50 EUR           1.0
# 1                              0.40 EUR           3.0
# 2                              0.10 EUR           2.0
# 3                              0.40 EUR           2.0
# 4                              0.20 EUR           3.0
# ..                                  ...           ...
# 478                            0.10 EUR           4.0
# 479                            0.10 EUR           3.0
# 480                            0.10 EUR           2.0
# 481                            0.40 EUR           3.0
# 482                            0.50 EUR           1.0
#
#     4_A_Price in urban areas, rush hour  5_Price_UR_A  \
# 0                              0.10 EUR           4.0
# 1                              0.40 EUR           3.0
# 2                              0.20 EUR           1.0
# 3                              0.20 EUR           3.0
# 4                              0.40 EUR           2.0
# ..                                  ...           ...
# 478                            0.50 EUR           3.0
# 479                            0.40 EUR           4.0
# 480                            0.20 EUR           3.0
# 481                            0.40 EUR           2.0
# 482                            0.10 EUR           3.0
#
#     5_A_Price in urban areas, rush hour  6_Price_UR_A  \
# 0                              0.50 EUR           2.0
# 1                              0.40 EUR           1.0
# 2                              0.10 EUR           3.0
# 3                              0.40 EUR           3.0
# 4                              0.20 EUR           4.0
# ..                                  ...           ...
# 478                            0.40 EUR           4.0
# 479                            0.50 EUR           NaN
# 480                            0.40 EUR           4.0
# 481                            0.20 EUR           4.0
# 482                            0.40 EUR           3.0
#
#     6_A_Price in urban areas, rush hour  7_Price_UR_A  \
# 0                              0.20 EUR           4.0
# 1                              0.10 EUR           3.0
# 2                              0.40 EUR           2.0
# 3                              0.40 EUR           4.0
# 4                              0.50 EUR           1.0
# ..                                  ...           ...
# 478                            0.50 EUR           3.0
# 479                                   -           NaN
# 480                            0.50 EUR           4.0
# 481                            0.50 EUR           2.0
# 482                            0.40 EUR           1.0
#
#     7_A_Price in urban areas, rush hour  8_Price_UR_A  \
# 0                              0.50 EUR           3.0
# 1                              0.40 EUR           1.0
# 2                              0.20 EUR           4.0
# 3                              0.50 EUR           4.0
# 4                              0.10 EUR           1.0
# ..                                  ...           ...
# 478                            0.40 EUR           3.0
# 479                                   -           NaN
# 480                            0.50 EUR           3.0
# 481                            0.20 EUR           2.0
# 482                            0.10 EUR           4.0
#
#     8_A_Price in urban areas, rush hour  1_Price_UN_A  \
# 0                              0.40 EUR             3
# 1                              0.10 EUR             1
# 2                              0.50 EUR             1
# 3                              0.50 EUR             1
# 4                              0.10 EUR             1
# ..                                  ...           ...
# 478                            0.40 EUR             1
# 479                                   -             1
# 480                            0.40 EUR             1
# 481                            0.20 EUR             1
# 482                            0.50 EUR             3
#
#     1_A_Price in urban areas, outside rush hour  2_Price_UN_A  \
# 0                                      0.40 EUR           1.0
# 1                                      0.10 EUR           4.0
# 2                                      0.10 EUR           4.0
# 3                                      0.10 EUR           4.0
# 4                                      0.10 EUR           1.0
# ..                                          ...           ...
# 478                                    0.10 EUR           4.0
# 479                                    0.10 EUR           4.0
# 480                                    0.10 EUR           2.0
# 481                                    0.10 EUR           2.0
# 482                                    0.40 EUR           4.0
#
#     2_A_Price in urban areas, outside rush hour  3_Price_UN_A  \
# 0                                      0.10 EUR           1.0
# 1                                      0.50 EUR           2.0
# 2                                      0.50 EUR           1.0
# 3                                      0.50 EUR           3.0
# 4                                      0.10 EUR           2.0
# ..                                          ...           ...
# 478                                    0.50 EUR           1.0
# 479                                    0.50 EUR           1.0
# 480                                    0.20 EUR           1.0
# 481                                    0.20 EUR           4.0
# 482                                    0.50 EUR           2.0
#
#     3_A_Price in urban areas, outside rush hour  4_Price_UN_A  \
# 0                                      0.10 EUR           1.0
# 1                                      0.20 EUR           4.0
# 2                                      0.10 EUR           1.0
# 3                                      0.40 EUR           2.0
# 4                                      0.20 EUR           1.0
# ..                                          ...           ...
# 478                                    0.10 EUR           2.0
# 479                                    0.10 EUR           3.0
# 480                                    0.10 EUR           2.0
# 481                                    0.50 EUR           3.0
# 482                                    0.20 EUR           1.0
#
#     4_A_Price in urban areas, outside rush hour  5_Price_UN_A  \
# 0                                      0.10 EUR           4.0
# 1                                      0.50 EUR           1.0
# 2                                      0.10 EUR           1.0
# 3                                      0.20 EUR           1.0
# 4                                      0.10 EUR           1.0
# ..                                          ...           ...
# 478                                    0.20 EUR           1.0
# 479                                    0.40 EUR           4.0
# 480                                    0.20 EUR           3.0
# 481                                    0.40 EUR           2.0
# 482                                    0.10 EUR           2.0
#
#     5_A_Price in urban areas, outside rush hour  6_Price_UN_A  \
# 0                                      0.50 EUR           1.0
# 1                                      0.10 EUR           1.0
# 2                                      0.10 EUR           2.0
# 3                                      0.10 EUR           1.0
# 4                                      0.10 EUR           3.0
# ..                                          ...           ...
# 478                                    0.10 EUR           4.0
# 479                                    0.50 EUR           NaN
# 480                                    0.40 EUR           1.0
# 481                                    0.20 EUR           2.0
# 482                                    0.20 EUR           2.0
#
#     6_A_Price in urban areas, outside rush hour  7_Price_UN_A  \
# 0                                      0.10 EUR           2.0
# 1                                      0.10 EUR           1.0
# 2                                      0.20 EUR           2.0
# 3                                      0.10 EUR           2.0
# 4                                      0.40 EUR           1.0
# ..                                          ...           ...
# 478                                    0.50 EUR           1.0
# 479                                           -           NaN
# 480                                    0.10 EUR           2.0
# 481                                    0.20 EUR           2.0
# 482                                    0.20 EUR           1.0
#
#     7_A_Price in urban areas, outside rush hour  8_Price_UN_A  \
# 0                                      0.20 EUR           4.0
# 1                                      0.10 EUR           1.0
# 2                                      0.20 EUR           3.0
# 3                                      0.20 EUR           3.0
# 4                                      0.10 EUR           1.0
# ..                                          ...           ...
# 478                                    0.10 EUR           1.0
# 479                                           -           NaN
# 480                                    0.20 EUR           4.0
# 481                                    0.20 EUR           2.0
# 482                                    0.10 EUR           3.0
#
#     8_A_Price in urban areas, outside rush hour  1_Price_O_A  \
# 0                                      0.50 EUR            3
# 1                                      0.10 EUR            1
# 2                                      0.40 EUR            2
# 3                                      0.40 EUR            2
# 4                                      0.10 EUR            2
# ..                                          ...          ...
# ...
# 478              0.0                                                  0
# 479              NaN                                                NaN
# 480              0.0                                                  0
# 481              0.0                                                  0
# 482              0.0                                                  0
#
#                                        player.comments  player.education  \
# 0                                                  NaN               3.0
# 1    Creo que una pregunta interesante podría haber...               3.0
# 2                                                  NaN               3.0
# 3                                                  NaN               3.0
# 4                                                  NaN               2.0
# ..                                                 ...               ...
# 478                                                NaN               2.0
# 479                                                NaN               NaN
# 480                                                NaN               3.0
# 481                         No dispongo de cta. paypal               3.0
# 482  Valoraría añadir otras opciones en las votacio...               1.0
#
#     What is your highest level of education?  player.effect_rp  \
# 0             university (more than 4 years)               3.0
# 1             university (more than 4 years)               2.0
# 2             university (more than 4 years)               6.0
# 3             university (more than 4 years)               2.0
# 4             university (less than 4 years)               1.0
# ..                                       ...               ...
# 478           university (less than 4 years)               1.0
# 479                                      NaN               NaN
# 480           university (more than 4 years)               4.0
# 481           university (more than 4 years)               1.0
# 482                              high school               3.0
#
#      player.effect_rp_others  player.family  \
# 0                        1.0            3.0
# 1                        6.0            3.0
# 2                        2.0            2.0
# 3                        1.0            2.0
# 4                        7.0            2.0
# ..                       ...            ...
# 478                      1.0            1.0
# 479                      NaN            NaN
# 480                      4.0            4.0
# 481                      1.0            1.0
# 482                      3.0            1.0
#
#     How many people does your household have including you?  player.gender  \
# 0                                                    3                 1.0
# 1                                                    3                 0.0
# 2                                                    2                 0.0
# 3                                                    2                 0.0
# 4                                                    2                 0.0
# ..                                                 ...                 ...
# 478                                                  1                 0.0
# 479                                                NaN                 NaN
# 480                                                  4                 0.0
# 481                                                  1                 0.0
# 482                                                  1                 1.0
#
#     How do you identify as?  player.id_in_group  player.income  \
# 0                       man                 1.0            0.0
# 1                     woman                 2.0            3.0
# 2                     woman                 3.0            2.0
# 3                     woman                 4.0            0.0
# 4                     woman                 5.0            1.0
# ..                      ...                 ...            ...
# 478                   woman               385.0            0.0
# 479                     NaN                 NaN            NaN
# 480                   woman               396.0            4.0
# 481                   woman               399.0            1.0
# 482                     man               400.0            1.0
#
#     What is your income per year?  player.my_trip  \
# 0               less than 10k EUR            11.0
# 1                     30k-40k EUR            11.0
# 2                     20k-30k EUR            10.0
# 3               less than 10k EUR             9.0
# 4                     10k-20k EUR             9.0
# ..                            ...             ...
# 478             less than 10k EUR             7.0
# 479                           NaN             NaN
# 480             more than 40k EUR             9.0
# 481                   10k-20k EUR             9.0
# 482                   10k-20k EUR            10.0
#
#     Considering the last year, how often (in %) did you use your chosen transport mode for your daily trip?  \
# 0                                                 100%
# 1                                                 100%
# 2                                                  90%
# 3                                                  80%
# 4                                                  80%
# ..                                                 ...
# 478                                                60%
# 479                                                NaN
# 480                                                80%
# 481                                                80%
# 482                                                90%
#
#      player.revenues  \
# 0                6.0
# 1                3.0
# 2                3.0
# 3                1.0
# 4                6.0
# ..               ...
# 478              3.0
# 479              NaN
# 480              4.0
# 481              1.0
# 482              1.0
#
#     Revenues collected through taxes are used to create a well-functioning welfare state and society:  \
# 0                                                    6
# 1                                                    3
# 2                                                    3
# 3                                                    1
# 4                                                    6
# ..                                                 ...
# 478                                                  3
# 479                                                NaN
# 480                                                  4
# 481                                                  1
# 482                                                  1
#
#      player.road_pricing  \
# 0                    2.0
# 1                    6.0
# 2                    7.0
# 3                    1.0
# 4                    6.0
# ..                   ...
# 478                  2.0
# 479                  NaN
# 480                  5.0
# 481                  1.0
# 482                  3.0
#
#     The introduction of policies such as road pricing will alleviate congestion problems:  \
# 0                                                    2
# 1                                                    6
# 2                                                    7
# 3                                                    1
# 4                                                    6
# ..                                                 ...
# 478                                                  2
# 479                                                NaN
# 480                                                  5
# 481                                                  1
# 482                                                  3
#
#      player.tax  \
# 0           7.0
# 1           4.0
# 2           4.0
# 3           1.0
# 4           5.0
# ..          ...
# 478         5.0
# 479         NaN
# 480         3.0
# 481         5.0
# 482         5.0
#
#     Tax revenues should be used to help those who are more in need:  \
# 0                                                    7
# 1                                                    4
# 2                                                    4
# 3                                                    1
# 4                                                    5
# ..                                                 ...
# 478                                                  5
# 479                                                NaN
# 480                                                  3
# 481                                                  5
# 482                                                  5
#
#      player.tax_level  player.trust_county  County council  \
# 0                 2.0                  1.0             1.0
# 1                 7.0                  5.0             5.0
# 2                 4.0                  3.0             3.0
# 3                 2.0                  1.0             1.0
# 4                 5.0                  6.0             6.0
# ..                ...                  ...             ...
# 478               5.0                  5.0             5.0
# 479               NaN                  NaN             NaN
# 480               4.0                  1.0             1.0
# 481               7.0                  1.0             1.0
# 482               4.0                  1.0             1.0
#
#      player.trust_government  Government  player.trust_municipality  \
# 0                        4.0         4.0                        1.0
# 1                        1.0         1.0                        4.0
# 2                        2.0         2.0                        4.0
# 3                        1.0         1.0                        3.0
# 4                        7.0         7.0                        4.0
# ..                       ...         ...                        ...
# 478                      1.0         1.0                        5.0
# 479                      NaN         NaN                        NaN
# 480                      1.0         1.0                        1.0
# 481                      2.0         2.0                        1.0
# 482                      4.0         4.0                        4.0
#
#     Municipal council  player.trust_parlament  Parlament  \
# 0                   1                     3.0        3.0
# 1                   4                     4.0        4.0
# 2                   4                     5.0        5.0
# 3                   3                     9.0        NaN
# 4                   4                     5.0        5.0
# ..                ...                     ...        ...
# 478                 5                     2.0        2.0
# 479               NaN                     NaN        NaN
# 480                 1                     1.0        1.0
# 481                 1                     1.0        1.0
# 482                 4                     4.0        4.0
#
#      player.trust_parties  Political parties  player.trust_politicians  \
# 0                     4.0                4.0                       5.0
# 1                     1.0                1.0                       1.0
# 2                     2.0                2.0                       3.0
# 3                     1.0                1.0                       1.0
# 4                     3.0                3.0                       4.0
# ..                    ...                ...                       ...
# 478                   1.0                1.0                       1.0
# 479                   NaN                NaN                       NaN
# 480                   1.0                1.0                       1.0
# 481                   1.0                1.0                       1.0
# 482                   1.0                1.0                       1.0
#
#      National politicians  player.vote  \
# 0                     5.0          3.0
# 1                     1.0          1.0
# 2                     3.0          1.0
# 3                     1.0         13.0
# 4                     4.0          3.0
# ..                    ...          ...
# 478                   1.0          1.0
# 479                   NaN          NaN
# 480                   1.0          1.0
# 481                   1.0         13.0
# 482                   1.0         13.0
#
#     Which political party you voted for in the last election?  \
# 0                                       Unidas Podemos
# 1                                      Partido Popular
# 2                                      Partido Popular
# 3                                prefiero no responder
# 4                                       Unidas Podemos
# ..                                                 ...
# 478                                    Partido Popular
# 479                                                NaN
# 480                                    Partido Popular
# 481                              prefiero no responder
# 482                              prefiero no responder
#
#      player.year_born session.code.1  subsession.round_number      treatment.1
# 0              1979.0       uln4i2w2                      1.0         Baseline
# 1              1999.0       uln4i2w2                      1.0        Pollution
# 2              1999.0       uln4i2w2                      1.0  Public Services
# 3              1999.0       uln4i2w2                      1.0     Road Pricing
# 4              2000.0       uln4i2w2                      1.0      Social Norm
# ..                ...            ...                      ...              ...
# 478            1997.0       heqbzlzk                      1.0      Social Norm
# 479               NaN            NaN                      NaN              NaN
# 480            1998.0       heqbzlzk                      1.0         Baseline
# 481            1971.0       heqbzlzk                      1.0     Road Pricing
# 482            1993.0       heqbzlzk                      1.0      Social Norm
#
# [483 rows x 296 columns]

# %%
df1=df1.rename(columns={'How much do you agree with the following statements from 1 to 7, where 1 means ‘I completely disagree’ and 7 means ‘I completely agree’? Air pollution derived by cars is one of the major causes of premature death in Europe:': "Air pollution", "The introduction of policies such as road pricing will alleviate congestion problems:":"Road pricing", "Revenues collected through taxes are used to create a well-functioning welfare state and society:":"Revenues", 'Tax revenues should be used to help those who are more in need:':'Tax','I think the overall tax level is too high:':'Tax lev'})

# %%
columns = ['Air pollution','Road pricing','Revenues','Tax']
df1[columns] = df1[columns].apply(pd.to_numeric, errors='coerce', axis=1)
df1[columns].mean().plot(kind='bar', figsize=(6,3), color='moccasin', edgecolor='k', legend=False)
plt.xticks(rotation=0)
plt.xlabel('')
plt.title('Average agreement to the statements')
plt.tight_layout(pad=2, w_pad=8, h_pad=2)
plt.show()

# %%
for i in ['Air pollution','Road pricing','Revenues','Tax']:
    column= i
    
    df1.groupby([column]).count().plot(kind='bar', y=1, title=column, figsize=(5,3),color='azure', edgecolor='k', legend=False)
    plt.xticks(rotation=0)
    plt.xlabel('')

    #plt.savefig('BCharts_all_%d.png' %i)
    plt.show()

# %%
lst=['A', 'B', 'C', 'D', 'E','I do not know']

fig=plt.figure(figsize=(10,6))
barWidth = 0.25

bars1=df1.groupby([df1['What type of society do you think is Spain today – which diagram comes the closest?']]).count()['treatment'].loc[lst].tolist()
bars2=df1.groupby([df1['What do you think Spain ought to be like – which would you prefer?']]).count()['treatment'].loc[lst].tolist()

r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]

plt.bar(r1, bars1, width=barWidth, edgecolor='white', label='What type of society do you think is Spain today?')
plt.bar(r2, bars2, width=barWidth, edgecolor='white', label='What do you think Spain ought to be like?')
 
plt.xticks([r + barWidth for r in range(len(bars1))], ['A', 'B', 'C', 'D', 'E','I do not know'], fontsize=13)
plt.yticks(fontsize=11)
plt.legend()

#plt.savefig("table_Madrid.pdf")
plt.show()

# %%
new=df1.groupby(['By which mode do you travel with during this trip? If you travel with multiple modes choose the mode that takes you the longest time.','If you were to make this trip using a different mode of travel than your usual mode, which would be the best alternative?'])
chord=new.size().reset_index(name="Time")
#chord.to_excel("chord_madrid.xlsx")

# %%
# List of columns related to gender, age, and similar questions
columns_of_interest = ['How do you identify as?', 'Which year were you born?', 'How many children under the age of 15 live with you?', 'What is your income per year?', 'What is your employment status?']  # Replace with actual column names

# Calculate the statistics
statistics = df1[columns_of_interest].agg(['mean', 'max', 'min', 'count']).transpose()

# Rename the columns for clarity
statistics.columns = ['Mean', 'Maximum', 'Minimum', 'Total Number']

# Display the statistics table
print(statistics)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 5
#       2 columns_of_interest = ['How do you identify as?', 'Which year were you born?', 'How many children under the age of 15 live with you?', 'What is your income per year?', 'What is your employment status?']  # Replace with actual column names
#       4 # Calculate the statistics
# ----> 5 statistics = df1[columns_of_interest].agg(['mean', 'max', 'min', 'count']).transpose()
#       7 # Rename the columns for clarity
#       8 statistics.columns = ['Mean', 'Maximum', 'Minimum', 'Total Number']
#
# File c:\Users\PcLaptop\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:9196, in DataFrame.aggregate(self, func, axis, *args, **kwargs)
#    9193 relabeling, func, columns, order = reconstruct_func(func, **kwargs)
#    9195 op = frame_apply(self, func=func, axis=axis, args=args, kwargs=kwargs)
# -> 9196 result = op.agg()
#    9198 if relabeling:
#    9199     # This is to keep the order to columns occurrence unchanged, and also
#    9200     # keep the order of new columns occurrence unchanged
#    9201
#    9202     # For the return values of reconstruct_func, if relabeling is
#    9203     # False, columns and order will be None.
#    9204     assert columns is not None
#
# File c:\Users\PcLaptop\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:690, in FrameApply.agg(self)
#     688 result = None
#     689 try:
# --> 690     result = super().agg()
#     691 finally:
#     692     self.obj = obj
#
# File c:\Users\PcLaptop\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:166, in Apply.agg(self)
#     163     return self.agg_dict_like()
#     164 elif is_list_like(arg):
#     165     # we require a list, but not a 'str'
# --> 166     return self.agg_list_like()
#     168 if callable(arg):
#     169     f = com.get_cython_func(arg)
#
# File c:\Users\PcLaptop\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:351, in Apply.agg_list_like(self)
#     349 colg = obj._gotitem(col, ndim=1, subset=selected_obj.iloc[:, index])
#     350 if isinstance(colg, (ABCSeries, ABCDataFrame)):
# --> 351     new_res = colg.aggregate(
#     352         arg, self.axis, *self.args, **self.kwargs
#     353     )
#     354 else:
#     355     new_res = colg.aggregate(arg, *self.args, **self.kwargs)
#
# File c:\Users\PcLaptop\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:4463, in Series.aggregate(self, func, axis, *args, **kwargs)
#    4460     func = dict(kwargs.items())
#    4462 op = SeriesApply(self, func, convert_dtype=False, args=args, kwargs=kwargs)
# -> 4463 result = op.agg()
#    4464 return result
#
# File c:\Users\PcLaptop\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:1028, in SeriesApply.agg(self)
#    1027 def agg(self):
# -> 1028     result = super().agg()
#    1029     if result is None:
#    1030         f = self.f
#
# File c:\Users\PcLaptop\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:166, in Apply.agg(self)
#     163     return self.agg_dict_like()
#     164 elif is_list_like(arg):
#     165     # we require a list, but not a 'str'
# --> 166     return self.agg_list_like()
#     168 if callable(arg):
#     169     f = com.get_cython_func(arg)
#
# File c:\Users\PcLaptop\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:335, in Apply.agg_list_like(self)
#     333 colg = obj._gotitem(selected_obj.name, ndim=1, subset=selected_obj)
#     334 if isinstance(colg, (ABCSeries, ABCDataFrame)):
# --> 335     new_res = colg.aggregate(
#     336         a, self.axis, *self.args, **self.kwargs
#     337     )
#     338 else:
#     339     new_res = colg.aggregate(a, *self.args, **self.kwargs)
#
# File c:\Users\PcLaptop\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:4463, in Series.aggregate(self, func, axis, *args, **kwargs)
#    4460     func = dict(kwargs.items())
#    4462 op = SeriesApply(self, func, convert_dtype=False, args=args, kwargs=kwargs)
# -> 4463 result = op.agg()
#    4464 return result
#
# File c:\Users\PcLaptop\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:1028, in SeriesApply.agg(self)
#    1027 def agg(self):
# -> 1028     result = super().agg()
#    1029     if result is None:
#    1030         f = self.f
#
# File c:\Users\PcLaptop\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:160, in Apply.agg(self)
#     157 kwargs = self.kwargs
#     159 if isinstance(arg, str):
# --> 160     return self.apply_str()
#     162 if is_dict_like(arg):
#     163     return self.agg_dict_like()
#
# File c:\Users\PcLaptop\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:496, in Apply.apply_str(self)
#     494     if "axis" in arg_names:
#     495         self.kwargs["axis"] = self.axis
# --> 496 return self._try_aggregate_string_function(obj, f, *self.args, **self.kwargs)
#
# File c:\Users\PcLaptop\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:565, in Apply._try_aggregate_string_function(self, obj, arg, *args, **kwargs)
#     563 if f is not None:
#     564     if callable(f):
# --> 565         return f(*args, **kwargs)
#     567     # people may try to aggregate on a non-callable attribute
#     568     # but don't let them think they can pass args to it
#     569     assert len(args) == 0
#
# File c:\Users\PcLaptop\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:11556, in NDFrame._add_numeric_operations.<locals>.mean(self, axis, skipna, numeric_only, **kwargs)
#   11539 @doc(
#   11540     _num_doc,
#   11541     desc="Return the mean of the values over the requested axis.",
#    (...)
#   11554     **kwargs,
#   11555 ):
# > 11556     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\PcLaptop\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:11201, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11194 def mean(
#   11195     self,
#   11196     axis: Axis | None = 0,
#    (...)
#   11199     **kwargs,
#   11200 ) -> Series | float:
# > 11201     return self._stat_function(
#   11202         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11203     )
#
# File c:\Users\PcLaptop\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:11158, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11154     nv.validate_stat_func((), kwargs, fname=name)
#   11156 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11158 return self._reduce(
#   11159     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160 )
#
# File c:\Users\PcLaptop\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:4670, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4665     raise TypeError(
#    4666         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    4667         "with non-numeric dtypes."
#    4668     )
#    4669 with np.errstate(all="ignore"):
# -> 4670     return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\PcLaptop\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:96, in disallow.__call__.<locals>._f(*args, **kwargs)
#      94 try:
#      95     with np.errstate(invalid="ignore"):
# ---> 96         return f(*args, **kwargs)
#      97 except ValueError as e:
#      98     # we want to transform an object array
#      99     # ValueError message to the more typical TypeError
#     100     # e.g. this is normally a disallowed function on
#     101     # object arrays that contain strings
#     102     if is_object_dtype(args[0]):
#
# File c:\Users\PcLaptop\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:158, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     156         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157 else:
# --> 158     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     160 return result
#
# File c:\Users\PcLaptop\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:421, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     418 if datetimelike and mask is None:
#     419     mask = isna(values)
# --> 421 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     423 if datetimelike:
#     424     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File c:\Users\PcLaptop\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\nanops.py:727, in nanmean(values, axis, skipna, mask)
#     724     dtype_count = dtype
#     726 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 727 the_sum = _ensure_numeric(values.sum(axis, dtype=dtype_sum))
#     729 if axis is not None and getattr(the_sum, "ndim", False):
#     730     count = cast(np.ndarray, count)
#
# File c:\Users\PcLaptop\AppData\Local\Programs\Python\Python311\Lib\site-packages\numpy\core\_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: can only concatenate str (not "int") to str
