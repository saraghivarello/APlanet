# %%
import pandas as pd
import numpy as np
import math

# %% [markdown]
# ## Import data

# %%
file = r"C:\Users\PcLaptop\Documents\GitHub\APlanet\Pilot_1\Rearrange_datasets\Part2_data_to_rows.xlsx"

xl1= pd.ExcelFile(file)      # Load spreadsheet
df1 = xl1.parse('Sheet1')    # Load a sheet into a DataFrame by name: df1

df1 = df1.loc[:, (df1 != 0).any(axis=0)]
df1 = df1.dropna(how='all', axis=1)
#df1 = df1.drop(274)
#drop  column named 'Unnamed: 0'
df1 = df1.drop(['Unnamed: 0'], axis=1)

# %% [markdown]
# ## Add columns with text (of questions and answers)

# %%
# module
v=[]
for i in df1['participant.id_in_session']:
    if math.isnan(i) is True:
        v.append('-')
    else: v.append((i-1)%4+1)
df1.insert(loc=1, column='mod', value=v)

# %%
n=5
for k in range(1,7):

    v=[]
    for i in df1['%d_policy_choice' %k]:
        if math.isnan(i) is True:
            v.append('-')
        elif i==1:
            v.append('A')
        elif i==2:
            v.append('B')
        elif i==3:
            v.append('None of them, keep the current system')
    df1.insert(loc=n, column='%d_What is your preferred policy type?' %k, value=v)
    n+=2
        
    for j in ['A','B']:
            
        v=[]
        for i in df1['%d_Price_UR_%s' %(k,j)]:
            if math.isnan(i) is True:
                v.append('-')
            elif i==1:
                v.append('0.10 EUR')
            elif i==2:
                v.append('0.20 EUR')
            elif i==3:
                v.append('0.40 EUR')
            elif i==4:
                v.append('0.50 EUR')   
        df1.insert(loc=n, column='%d_%s_Price in urban areas, rush hour' %(k,j), value=v)
        n+=2

        # UN
        v=[]
        for i in df1['%d_Price_UN_%s' %(k,j)]:
            if math.isnan(i) is True:
                v.append('-')
            elif i==1:
                v.append('0.10 EUR')
            elif i==2:
                v.append('0.20 EUR')
            elif i==3:
                v.append('0.40 EUR')
            elif i==4:
                v.append('0.50 EUR')   
        df1.insert(loc=n, column='%d_%s_Price in urban areas, outside rush hour' %(k,j), value=v)
        n+=2

        # O
        v=[]
        for i in df1['%d_Price_O_%s' %(k,j)]:
            if math.isnan(i) is True:
                v.append('-')
            elif i==1:
                v.append('0.01 EUR')
            elif i==2:
                v.append('0.02 EUR')
            elif i==3:
                v.append('0.03 EUR')
            elif i==4:
                v.append('0.05 EUR')   
        df1.insert(loc=n, column='%d_%s_Price outside urban areas' %(k,j), value=v)
        n+=2
        
        # EV
        v=[]
        for i in df1['%d_EV_%s' %(k,j)]:
            if math.isnan(i) is True:
                v.append('-')
            elif i==1:
                v.append('0.01 EUR')
            elif i==2:
                v.append('0.02 EUR')
            elif i==3:
                v.append('0.03 EUR')
            elif i==4:
                v.append('0.05 EUR')   
        df1.insert(loc=n, column='%d_%s_Price for electric vehicles' %(k,j), value=v)
        n+=2

        # Revenue
        v=[]
        for i in df1['%d_Revenue_%s' %(k,j)]:
            if math.isnan(i) is True:
                v.append('-')
            elif i==1:
                v.append('General budget')
            elif i==2:
                v.append('Equal cash transfer')
            elif i==3:
                v.append('Cash transfer for low-income citizens')
            elif i==4:
                v.append('Investments in roads')
            elif i==5:
                v.append('Investments in public transport, walking and cycling')   
        df1.insert(loc=n, column='%d_%s_Use of revenue' %(k,j), value=v)
        n+=2

# %% [markdown]
# ## Check and export excel

# %%
np.shape(df1)
# Out:
# (284, 136)

# %%
pd.set_option('display.max_columns', None)
df1.head()
# Out:
#    participant.id_in_session  mod participant.code  \
# 0                          1    1         o9x6ki7q
# 1                          2    2         iu9re9u5
# 2                          3    3         0prglina
# 3                          4    4         76mq2acd
# 4                          5    1         n6c69l1z
#
#            participant.time_started  1_policy_choice  \
# 0  2022-07-18 17:15:55.868817+00:00              2.0
# 1  2022-07-18 13:56:52.428815+00:00              1.0
# 2  2022-07-18 09:56:59.145068+00:00              3.0
# 3  2022-07-18 21:47:35.300273+00:00              1.0
# 4  2022-07-18 22:45:11.140948+00:00              2.0
#
#    1_What is your preferred policy type?  1_Price_UR_A  \
# 0                                      B           1.0
# 1                                      A           2.0
# 2  None of them, keep the current system           2.0
# 3                                      A           4.0
# 4                                      B           3.0
#
#   1_A_Price in urban areas, rush hour  1_Price_UN_A  \
# 0                            0.10 EUR           1.0
# 1                            0.20 EUR           2.0
# 2                            0.20 EUR           2.0
# 3                            0.50 EUR           4.0
# 4                            0.40 EUR           3.0
#
#   1_A_Price in urban areas, outside rush hour  1_Price_O_A  \
# 0                                    0.10 EUR          1.0
# 1                                    0.20 EUR          2.0
# 2                                    0.20 EUR          4.0
# 3                                    0.50 EUR          4.0
# 4                                    0.40 EUR          4.0
#
#   1_A_Price outside urban areas  1_EV_A 1_A_Price for electric vehicles  \
# 0                      0.01 EUR     4.0                        0.05 EUR
# 1                      0.02 EUR     2.0                        0.02 EUR
# 2                      0.05 EUR     1.0                        0.01 EUR
# 3                      0.05 EUR     3.0                        0.03 EUR
# 4                      0.05 EUR     3.0                        0.03 EUR
#
#    1_Revenue_A                                 1_A_Use of revenue  \
# 0          2.0                                Equal cash transfer
# 1          3.0              Cash transfer for low-income citizens
# 2          2.0                                Equal cash transfer
# 3          5.0  Investments in public transport, walking and c...
# 4          4.0                               Investments in roads
#
#    1_Price_UR_B 1_B_Price in urban areas, rush hour  1_Price_UN_B  \
# 0           1.0                            0.10 EUR           1.0
# 1           3.0                            0.40 EUR           2.0
# 2           4.0                            0.50 EUR           4.0
# 3           4.0                            0.50 EUR           4.0
# 4           4.0                            0.50 EUR           3.0
#
#   1_B_Price in urban areas, outside rush hour  1_Price_O_B  \
# 0                                    0.10 EUR          1.0
# 1                                    0.20 EUR          4.0
# 2                                    0.50 EUR          1.0
# 3                                    0.50 EUR          4.0
# 4                                    0.40 EUR          2.0
#
#   1_B_Price outside urban areas  1_EV_B 1_B_Price for electric vehicles  \
# 0                      0.01 EUR     1.0                        0.01 EUR
# 1                      0.05 EUR     2.0                        0.02 EUR
# 2                      0.01 EUR     4.0                        0.05 EUR
# 3                      0.05 EUR     3.0                        0.03 EUR
# 4                      0.02 EUR     2.0                        0.02 EUR
#
#    1_Revenue_B                                 1_B_Use of revenue  \
# 0          3.0              Cash transfer for low-income citizens
# 1          5.0  Investments in public transport, walking and c...
# 2          3.0              Cash transfer for low-income citizens
# 3          2.0                                Equal cash transfer
# 4          5.0  Investments in public transport, walking and c...
#
#    2_policy_choice 2_What is your preferred policy type?  2_Price_UR_A  \
# 0              2.0                                     B           3.0
# 1              1.0                                     A           3.0
# 2              1.0                                     A           4.0
# 3              2.0                                     B           4.0
# 4              2.0                                     B           2.0
#
#   2_A_Price in urban areas, rush hour  2_Price_UN_A  \
# 0                            0.40 EUR           3.0
# 1                            0.40 EUR           3.0
# 2                            0.50 EUR           4.0
# 3                            0.50 EUR           4.0
# 4                            0.20 EUR           1.0
#
#   2_A_Price in urban areas, outside rush hour  2_Price_O_A  \
# 0                                    0.40 EUR          3.0
# 1                                    0.40 EUR          2.0
# 2                                    0.50 EUR          4.0
# 3                                    0.50 EUR          1.0
# 4                                    0.10 EUR          2.0
#
#   2_A_Price outside urban areas  2_EV_A 2_A_Price for electric vehicles  \
# 0                      0.03 EUR     3.0                        0.03 EUR
# 1                      0.02 EUR     4.0                        0.05 EUR
# 2                      0.05 EUR     1.0                        0.01 EUR
# 3                      0.01 EUR     1.0                        0.01 EUR
# 4                      0.02 EUR     3.0                        0.03 EUR
#
#    2_Revenue_A                     2_A_Use of revenue  2_Price_UR_B  \
# 0          1.0                         General budget           2.0
# 1          2.0                    Equal cash transfer           4.0
# 2          2.0                    Equal cash transfer           4.0
# 3          3.0  Cash transfer for low-income citizens           2.0
# 4          2.0                    Equal cash transfer           3.0
#
#   2_B_Price in urban areas, rush hour  2_Price_UN_B  \
# 0                            0.20 EUR           2.0
# 1                            0.50 EUR           3.0
# 2                            0.50 EUR           4.0
# 3                            0.20 EUR           2.0
# 4                            0.40 EUR           3.0
#
#   2_B_Price in urban areas, outside rush hour  2_Price_O_B  \
# 0                                    0.20 EUR          2.0
# 1                                    0.40 EUR          3.0
# 2                                    0.50 EUR          4.0
# 3                                    0.20 EUR          3.0
# 4                                    0.40 EUR          3.0
#
#   2_B_Price outside urban areas  2_EV_B 2_B_Price for electric vehicles  \
# 0                      0.02 EUR     3.0                        0.03 EUR
# 1                      0.03 EUR     2.0                        0.02 EUR
# 2                      0.05 EUR     4.0                        0.05 EUR
# 3                      0.03 EUR     2.0                        0.02 EUR
# 4                      0.03 EUR     1.0                        0.01 EUR
#
#    2_Revenue_B    2_B_Use of revenue  3_policy_choice  \
# 0          4.0  Investments in roads              1.0
# 1          4.0  Investments in roads              1.0
# 2          4.0  Investments in roads              2.0
# 3          1.0        General budget              1.0
# 4          2.0   Equal cash transfer              2.0
#
#   3_What is your preferred policy type?  3_Price_UR_A  \
# 0                                     A           4.0
# 1                                     A           1.0
# 2                                     B           2.0
# 3                                     A           2.0
# 4                                     B           2.0
#
#   3_A_Price in urban areas, rush hour  3_Price_UN_A  \
# 0                            0.50 EUR           4.0
# 1                            0.10 EUR           1.0
# 2                            0.20 EUR           1.0
# 3                            0.20 EUR           2.0
# 4                            0.20 EUR           2.0
#
#   3_A_Price in urban areas, outside rush hour  3_Price_O_A  \
# 0                                    0.50 EUR          1.0
# 1                                    0.10 EUR          1.0
# 2                                    0.10 EUR          4.0
# 3                                    0.20 EUR          2.0
# 4                                    0.20 EUR          2.0
#
#   3_A_Price outside urban areas  3_EV_A 3_A_Price for electric vehicles  \
# 0                      0.01 EUR     4.0                        0.05 EUR
# 1                      0.01 EUR     4.0                        0.05 EUR
# 2                      0.05 EUR     3.0                        0.03 EUR
# 3                      0.02 EUR     3.0                        0.03 EUR
# 4                      0.02 EUR     2.0                        0.02 EUR
#
#    3_Revenue_A                     3_A_Use of revenue  3_Price_UR_B  \
# 0          3.0  Cash transfer for low-income citizens           2.0
# 1          3.0  Cash transfer for low-income citizens           1.0
# 2          3.0  Cash transfer for low-income citizens           3.0
# 3          4.0                   Investments in roads           2.0
# 4          1.0                         General budget           2.0
#
#   3_B_Price in urban areas, rush hour  3_Price_UN_B  \
# 0                            0.20 EUR           2.0
# 1                            0.10 EUR           1.0
# 2                            0.40 EUR           1.0
# 3                            0.20 EUR           2.0
# 4                            0.20 EUR           2.0
#
#   3_B_Price in urban areas, outside rush hour  3_Price_O_B  \
# 0                                    0.20 EUR          4.0
# 1                                    0.10 EUR          1.0
# 2                                    0.10 EUR          1.0
# 3                                    0.20 EUR          2.0
# 4                                    0.20 EUR          2.0
#
#   3_B_Price outside urban areas  3_EV_B 3_B_Price for electric vehicles  \
# 0                      0.05 EUR     1.0                        0.01 EUR
# 1                      0.01 EUR     3.0                        0.03 EUR
# 2                      0.01 EUR     4.0                        0.05 EUR
# 3                      0.02 EUR     2.0                        0.02 EUR
# 4                      0.02 EUR     2.0                        0.02 EUR
#
#    3_Revenue_B                                 3_B_Use of revenue  \
# 0          2.0                                Equal cash transfer
# 1          5.0  Investments in public transport, walking and c...
# 2          4.0                               Investments in roads
# 3          2.0                                Equal cash transfer
# 4          4.0                               Investments in roads
#
#    4_policy_choice 4_What is your preferred policy type?  4_Price_UR_A  \
# 0              2.0                                     B           2.0
# 1              1.0                                     A           3.0
# 2              1.0                                     A           2.0
# 3              2.0                                     B           4.0
# 4              2.0                                     B           3.0
#
#   4_A_Price in urban areas, rush hour  4_Price_UN_A  \
# 0                            0.20 EUR           1.0
# 1                            0.40 EUR           3.0
# 2                            0.20 EUR           2.0
# 3                            0.50 EUR           4.0
# 4                            0.40 EUR           3.0
#
#   4_A_Price in urban areas, outside rush hour  4_Price_O_A  \
# 0                                    0.10 EUR          4.0
# 1                                    0.40 EUR          3.0
# 2                                    0.20 EUR          2.0
# 3                                    0.50 EUR          4.0
# 4                                    0.40 EUR          3.0
#
#   4_A_Price outside urban areas  4_EV_A 4_A_Price for electric vehicles  \
# 0                      0.05 EUR     3.0                        0.03 EUR
# 1                      0.03 EUR     4.0                        0.05 EUR
# 2                      0.02 EUR     3.0                        0.03 EUR
# 3                      0.05 EUR     3.0                        0.03 EUR
# 4                      0.03 EUR     2.0                        0.02 EUR
#
#    4_Revenue_A                                 4_A_Use of revenue  \
# 0          3.0              Cash transfer for low-income citizens
# 1          5.0  Investments in public transport, walking and c...
# 2          4.0                               Investments in roads
# 3          3.0              Cash transfer for low-income citizens
# 4          3.0              Cash transfer for low-income citizens
#
#    4_Price_UR_B 4_B_Price in urban areas, rush hour  4_Price_UN_B  \
# 0           3.0                            0.40 EUR           1.0
# 1           3.0                            0.40 EUR           3.0
# 2           3.0                            0.40 EUR           3.0
# 3           1.0                            0.10 EUR           1.0
# 4           3.0                            0.40 EUR           3.0
#
#   4_B_Price in urban areas, outside rush hour  4_Price_O_B  \
# 0                                    0.10 EUR          1.0
# 1                                    0.40 EUR          3.0
# 2                                    0.40 EUR          3.0
# 3                                    0.10 EUR          1.0
# 4                                    0.40 EUR          3.0
#
#   4_B_Price outside urban areas  4_EV_B 4_B_Price for electric vehicles  \
# 0                      0.01 EUR     4.0                        0.05 EUR
# 1                      0.03 EUR     3.0                        0.03 EUR
# 2                      0.03 EUR     3.0                        0.03 EUR
# 3                      0.01 EUR     2.0                        0.02 EUR
# 4                      0.03 EUR     1.0                        0.01 EUR
#
#    4_Revenue_B                                 4_B_Use of revenue  \
# 0          4.0                               Investments in roads
# 1          1.0                                     General budget
# 2          1.0                                     General budget
# 3          5.0  Investments in public transport, walking and c...
# 4          2.0                                Equal cash transfer
#
#    5_policy_choice  5_What is your preferred policy type?  5_Price_UR_A  \
# 0              2.0                                      B           3.0
# 1              3.0  None of them, keep the current system           4.0
# 2              1.0                                      A           1.0
# 3              2.0                                      B           2.0
# 4              2.0                                      B           2.0
#
#   5_A_Price in urban areas, rush hour  5_Price_UN_A  \
# 0                            0.40 EUR           3.0
# 1                            0.50 EUR           4.0
# 2                            0.10 EUR           1.0
# 3                            0.20 EUR           2.0
# 4                            0.20 EUR           1.0
#
#   5_A_Price in urban areas, outside rush hour  5_Price_O_A  \
# 0                                    0.40 EUR          3.0
# 1                                    0.50 EUR          4.0
# 2                                    0.10 EUR          1.0
# 3                                    0.20 EUR          3.0
# 4                                    0.10 EUR          1.0
#
#   5_A_Price outside urban areas  5_EV_A 5_A_Price for electric vehicles  \
# 0                      0.03 EUR     2.0                        0.02 EUR
# 1                      0.05 EUR     3.0                        0.03 EUR
# 2                      0.01 EUR     1.0                        0.01 EUR
# 3                      0.03 EUR     4.0                        0.05 EUR
# 4                      0.01 EUR     3.0                        0.03 EUR
#
#    5_Revenue_A                     5_A_Use of revenue  5_Price_UR_B  \
# 0          2.0                    Equal cash transfer           4.0
# 1          2.0                    Equal cash transfer           2.0
# 2          3.0  Cash transfer for low-income citizens           1.0
# 3          1.0                         General budget           4.0
# 4          2.0                    Equal cash transfer           4.0
#
#   5_B_Price in urban areas, rush hour  5_Price_UN_B  \
# 0                            0.50 EUR           3.0
# 1                            0.20 EUR           2.0
# 2                            0.10 EUR           1.0
# 3                            0.50 EUR           2.0
# 4                            0.50 EUR           1.0
#
#   5_B_Price in urban areas, outside rush hour  5_Price_O_B  \
# 0                                    0.40 EUR          1.0
# 1                                    0.20 EUR          2.0
# 2                                    0.10 EUR          1.0
# 3                                    0.20 EUR          2.0
# 4                                    0.10 EUR          3.0
#
#   5_B_Price outside urban areas  5_EV_B 5_B_Price for electric vehicles  \
# 0                      0.01 EUR     3.0                        0.03 EUR
# 1                      0.02 EUR     1.0                        0.01 EUR
# 2                      0.01 EUR     4.0                        0.05 EUR
# 3                      0.02 EUR     4.0                        0.05 EUR
# 4                      0.03 EUR     4.0                        0.05 EUR
#
#    5_Revenue_B                     5_B_Use of revenue  6_policy_choice  \
# 0          4.0                   Investments in roads              1.0
# 1          4.0                   Investments in roads              2.0
# 2          2.0                    Equal cash transfer              2.0
# 3          3.0  Cash transfer for low-income citizens              1.0
# 4          1.0                         General budget              1.0
#
#   6_What is your preferred policy type?  6_Price_UR_A  \
# 0                                     A           4.0
# 1                                     B           4.0
# 2                                     B           3.0
# 3                                     A           3.0
# 4                                     A           3.0
#
#   6_A_Price in urban areas, rush hour  6_Price_UN_A  \
# 0                            0.50 EUR           4.0
# 1                            0.50 EUR           3.0
# 2                            0.40 EUR           3.0
# 3                            0.40 EUR           3.0
# 4                            0.40 EUR           3.0
#
#   6_A_Price in urban areas, outside rush hour  6_Price_O_A  \
# 0                                    0.50 EUR          4.0
# 1                                    0.40 EUR          4.0
# 2                                    0.40 EUR          3.0
# 3                                    0.40 EUR          1.0
# 4                                    0.40 EUR          3.0
#
#   6_A_Price outside urban areas  6_EV_A 6_A_Price for electric vehicles  \
# 0                      0.05 EUR     4.0                        0.05 EUR
# 1                      0.05 EUR     2.0                        0.02 EUR
# 2                      0.03 EUR     2.0                        0.02 EUR
# 3                      0.01 EUR     1.0                        0.01 EUR
# 4                      0.03 EUR     3.0                        0.03 EUR
#
#    6_Revenue_A                                 6_A_Use of revenue  \
# 0          4.0                               Investments in roads
# 1          4.0                               Investments in roads
# 2          2.0                                Equal cash transfer
# 3          5.0  Investments in public transport, walking and c...
# 4          5.0  Investments in public transport, walking and c...
#
#    6_Price_UR_B 6_B_Price in urban areas, rush hour  6_Price_UN_B  \
# 0           4.0                            0.50 EUR           4.0
# 1           1.0                            0.10 EUR           1.0
# 2           4.0                            0.50 EUR           3.0
# 3           4.0                            0.50 EUR           3.0
# 4           1.0                            0.10 EUR           1.0
#
#   6_B_Price in urban areas, outside rush hour  6_Price_O_B  \
# 0                                    0.50 EUR          4.0
# 1                                    0.10 EUR          2.0
# 2                                    0.40 EUR          1.0
# 3                                    0.40 EUR          4.0
# 4                                    0.10 EUR          1.0
#
#   6_B_Price outside urban areas  6_EV_B 6_B_Price for electric vehicles  \
# 0                      0.05 EUR     1.0                        0.01 EUR
# 1                      0.02 EUR     2.0                        0.02 EUR
# 2                      0.01 EUR     3.0                        0.03 EUR
# 3                      0.05 EUR     1.0                        0.01 EUR
# 4                      0.01 EUR     4.0                        0.05 EUR
#
#    6_Revenue_B                                 6_B_Use of revenue
# 0          2.0                                Equal cash transfer
# 1          5.0  Investments in public transport, walking and c...
# 2          4.0                               Investments in roads
# 3          1.0                                     General budget
# 4          2.0                                Equal cash transfer

# %%
df1.to_excel("part2_text.xlsx")
