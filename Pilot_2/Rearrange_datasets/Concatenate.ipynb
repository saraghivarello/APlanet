# %%
import pandas as pd
import numpy as np
import math

# %% [markdown]
# ## Import data

# %%
file1 = r'C:\Users\PcLaptop\Documents\GitHub\APlanet\Pilot_2\Rearrange_datasets\part1_text_2.xlsx'

xl1 = pd.ExcelFile(file1)      # Load spreadsheet
df1 = xl1.parse('Sheet1')    # Load a sheet into a DataFrame by name: df1
#use participants as index
df1.set_index('participant.code', inplace=True)
np.shape(df1)
# Out:
# (483, 50)

# %%
file2 = r'C:\Users\PcLaptop\Documents\GitHub\APlanet\Pilot_2\Rearrange_datasets\part2_text.xlsx'

xl2 = pd.ExcelFile(file2)      # Load spreadsheet
df2 = xl2.parse('Sheet1')    # Load a sheet into a DataFrame by name: df1
df2.set_index('participant.code', inplace=True)
np.shape(df2)
# Out:
# (483, 186)

# %%
file3 = r'C:\Users\PcLaptop\Documents\GitHub\APlanet\Pilot_2\Rearrange_datasets\part3_text.xlsx'

xl3= pd.ExcelFile(file3)      # Load spreadsheet
df3 = xl3.parse('Sheet1')    # Load a sheet into a DataFrame by name: df1
#df3.drop(['participant.time_started','participant.code','participant.id_in_session','mod'], inplace=True, axis=1)
df3.set_index('participant.code', inplace=True)
np.shape(df3)
# Out:
# (480, 63)

# %% [markdown]
# ## Concatenate the three parts

# %%
result = pd.concat([df1,df2,df3], axis=1)
result.drop(['Unnamed: 0'], inplace=True, axis=1)

# %%
#discard rows in result dataframe that have more that 10 nan values

#result = result.replace('-', np.nan)
#result = result.dropna(thresh=10)
#result.reset_index(drop=True, inplace=True)

#result.to_excel(r'C:\Users\PcLaptop\Documents\GitHub\APlanet\Pilot_1\Rearrange_datasets\all_parts.xlsx')

# %%
pd.set_option('display.max_rows', None)
result.iloc[258:260]
# Out:
#                         treatment  participant.id_in_session  \
# participant.code
# zw6h1g9v          Public Services                        268
# lhana9pt             Road Pricing                        269
#
#                   player.municipality_home  \
# participant.code
# zw6h1g9v                                91
# lhana9pt                                64
#
#                  What is the municipality of your home address?  \
# participant.code
# zw6h1g9v                                        Madrid - Retiro
# lhana9pt                                                 Getafe
#
#                   player.driving_license Do you have a driver license?  \
# participant.code
# zw6h1g9v                               1                           Yes
# lhana9pt                               1                           Yes
#
#                   player.access_to_car Do you own or have access to a car?  \
# participant.code
# ...

# %%
result.head()
# Out:
#                         treatment  participant.id_in_session  \
# participant.code
# ooxl8r2l                 Baseline                          1
# i6cytpys                Pollution                          2
# js43i4q6          Public Services                          3
# wjalnvbm             Road Pricing                          4
# bt4ub78z              Social Norm                          5
#
#                   player.municipality_home  \
# participant.code
# ooxl8r2l                                81
# i6cytpys                                85
# js43i4q6                                78
# wjalnvbm                                73
# bt4ub78z                                 3
#
#                  What is the municipality of your home address?  \
# participant.code
# ooxl8r2l                                        Madrid - Centro
# i6cytpys                         Madrid - Fuencarral - El Pardo
# js43i4q6                                    Madrid - Arganzuela
# ...

# %%
result.to_excel(r'C:\Users\PcLaptop\Documents\GitHub\APlanet\Pilot_2\Rearrange_datasets\all_Madrid.xlsx')

# %%
np.shape(result)
# Out:
# (483, 296)

# %%
result
# Out:
#                         treatment  participant.id_in_session  \
# participant.code
# ooxl8r2l                 Baseline                          1
# i6cytpys                Pollution                          2
# js43i4q6          Public Services                          3
# wjalnvbm             Road Pricing                          4
# bt4ub78z              Social Norm                          5
# 5thamyfx                 Baseline                          6
# 8xnl007r                Pollution                          7
# wa9mirry          Public Services                          8
# 7swa81a6             Road Pricing                          9
# 8utng60s              Social Norm                         10
# iljz4kcr                 Baseline                         11
# g57v7f6b          Public Services                         13
# mjk6292s             Road Pricing                         14
# b2zbxt87              Social Norm                         15
# ...
