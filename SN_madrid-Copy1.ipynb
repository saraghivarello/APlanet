# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import pandas as pd
import scipy.stats as stats
import math

# %%
file = r"C:\Users\PcLaptop\Desktop\all_Madrid.xlsx"

xl1= pd.ExcelFile(file)      # Load spreadsheet
df1 = xl1.parse('Sheet1')    # Load a sheet into a DataFrame by name: df1
df1.index  = np.arange(len(df1))

# %%
dfa=df1
for i in range(181):
    if dfa['player.SN_car_A'][i]!=1:
        dfa=dfa.drop(i)

dfb=df1
for i in range(181):
    if dfb['player.SN_car_A'][i]!=0:
        dfb=dfb.drop(i)

# %%
x_a = np.linspace(0,100,21)
x_b = np.linspace(0,100,21)

# %%
dens_a = stats.gaussian_kde(dfa['player.EE'])
dens_b = stats.gaussian_kde(100-dfb['player.EE'])

plt.plot(x_a, dens_a(x_a), label='A: Car ',color='darkorange')
plt.plot(x_b, dens_b(x_b), label='A: Public transport',color='green')
plt.xlabel("Percentage")
plt.ylabel("PDF")
plt.legend(loc='upper right')
plt.axvline(26.52, color='k',ls='--')
plt.yticks((np.linspace(0,0.07,5)))
#plt.xticks((np.linspace(0,100,5)))
plt.tight_layout(pad=2, w_pad=4, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\kern1.png')
plt.show()

# %%
dfa.index= np.arange(len(dfa))
dfb.index= np.arange(len(dfb))
counta=0
countb=0
for i in range(len(dfb['player.PNB'])):
    if dfa['player.PNB'][i] > 50:
        counta+=1
    if dfb['player.PNB'][i] <= 50:
        countb+=1
(counta+countb)/181
# Out:
# 0.1712707182320442

# %%
dens_a = stats.gaussian_kde(dfa['player.PNB'])
dens_b = stats.gaussian_kde(100-dfb['player.PNB'])

plt.plot(x_a, dens_a(x_a), label='A: Car ',color='darkorange')
plt.plot(x_b, dens_b(x_b), label='A: Public transport',color='green')
plt.xlabel("Percentage")
plt.ylabel("PDF")
plt.legend(loc='upper right')
plt.axvline(100-dfb['player.PNB'].median(), color='g',ls='--')
plt.axvline(dfa['player.PNB'].median(), color='darkorange',ls='--')
#plt.fill_between(np.linspace(50,100,21),dens_a(np.linspace(50,100,21)),alpha=0.2)
#plt.fill_between(np.linspace(50,100,21),dens_b(np.linspace(50,100,21)),alpha=0.2)
plt.yticks((np.linspace(0,0.07,5)))
#plt.xticks((np.linspace(0,100,5)))
plt.tight_layout(pad=2, w_pad=4, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\kern2b.png')
plt.show()

# %%
dfa['player.PNB'].median()
# Out:
# 25.0

# %%
100-dfb['player.PNB'].median()
# Out:
# 20.0

# %%
dens_a = stats.gaussian_kde(dfa['player.NE'])
dens_b = stats.gaussian_kde(100-dfb['player.NE'])

plt.plot(x_a, dens_a(x_a), label='A: Car ',color='darkorange')
plt.plot(x_b,dens_b(x_b), label='A: Public transport',color='green')
plt.xlabel("Percentage")
plt.ylabel("PDF")
plt.legend(loc='upper right')
plt.axvline(17.12, color='k',ls='--')
plt.yticks((np.linspace(0,0.07,5)))
#plt.xticks((np.linspace(0,100,5)))
plt.tight_layout(pad=2, w_pad=4, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\kern3.png')
plt.show()

# %%
dens_a = stats.gaussian_kde(dfa['player.HH'])
dens_b = stats.gaussian_kde(100-dfb['player.LL'])

plt.plot(x_a, dens_a(x_a), label='A: Car ',color='darkorange')
plt.plot(x_b,dens_b(x_b), label='A: Public transport',color='green')
plt.xlabel("Percentage")
plt.ylabel("PDF")
plt.legend(loc='upper right')
plt.yticks((np.linspace(0,0.04,5)))
#plt.xticks((np.linspace(0,100,5)))
plt.tight_layout(pad=2, w_pad=4, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\kernHH.png')
plt.show()

# %%
np.mean(dfa['player.HH']),np.std(dfa['player.HH']),np.mean(100-dfb['player.LL']),np.std(100-dfb['player.LL'])
# Out:
# (43.62637362637363, 35.2128998439612, 32.65555555555556, 29.17882074805138)

# %%
dens_a = stats.gaussian_kde(dfa['player.HL'])
dens_b = stats.gaussian_kde(100-dfb['player.LH'])

plt.plot(x_a, dens_a(x_a), label='A: Car ',color='darkorange')
plt.plot(x_b,dens_b(x_b), label='A: Public transport',color='green')
plt.xlabel("Percentage")
plt.ylabel("PDF")
plt.legend(loc='upper right')
plt.yticks((np.linspace(0,0.04,5)))
#plt.xticks((np.linspace(0,100,5)))
plt.tight_layout(pad=2, w_pad=4, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\kernHL.png')
plt.show()

# %%
np.mean(dfa['player.HL']),np.std(dfa['player.HL']),np.mean(100-dfb['player.LH']),np.std(100-dfb['player.LH'])
# Out:
# (40.989010989010985, 33.1982041436358, 30.377777777777776, 28.046222870182547)

# %%
dens_a = stats.gaussian_kde(dfa['player.LH'])
dens_b = stats.gaussian_kde(100-dfb['player.HL'])

plt.plot(x_a, dens_a(x_a), label='A: Car ',color='darkorange')
plt.plot(x_b,dens_b(x_b), label='A: Public transport',color='green')
plt.xlabel("Percentage")
plt.ylabel("PDF")
plt.legend(loc='upper right')
plt.yticks((np.linspace(0,0.04,5)))
#plt.xticks((np.linspace(0,100,5)))
plt.tight_layout(pad=2, w_pad=4, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\kernLH.png')
plt.show()

# %%
np.mean(dfa['player.LH']),np.std(dfa['player.LH']),np.mean(100-dfb['player.HL']),np.std(100-dfb['player.HL'])
# Out:
# (40.9010989010989, 32.97919922026608, 33.01111111111111, 29.079391115604906)

# %%
dens_a = stats.gaussian_kde(dfa['player.LL'])
dens_b = stats.gaussian_kde(100-dfb['player.HH'])

plt.plot(x_a, dens_a(x_a), label='A: Car ',color='darkorange')
plt.plot(x_b,dens_b(x_b), label='A: Public transport',color='green')
plt.xlabel("Percentage")
plt.ylabel("PDF")
plt.legend(loc='upper right')
plt.yticks((np.linspace(0,0.04,5)))
#plt.xticks((np.linspace(0,100,5)))
plt.tight_layout(pad=2, w_pad=4, h_pad=3)
#plt.savefig(r'C:\Users\Sara\Dropbox (Politecnico Di Torino Studenti)\Aplanet_\bars\kernLL.png')
plt.show()

# %%
np.mean(dfa['player.LL']),np.std(dfa['player.LL']),np.mean(100-dfb['player.HH']),np.std(100-dfb['player.HH'])
# Out:
# (42.72527472527472, 35.22613475786794, 29.333333333333332, 27.900617277122105)

# %%
fig, axs = plt.subplots(nrows=3, ncols=2,  figsize=(17, 18))
fig.suptitle('Social norms in Madrid', fontsize=30)

dens_a = stats.gaussian_kde(dfa['player.EE'])
n, x_a, _ = axs[0,0].hist(dfa['player.EE'],bins=20, density=True, label='Set A', color='khaki', edgecolor='black')
axs[0,0].plot(x_a,dens_a(x_a), label='Set A probability density function',color='darkorange')
axs[0,0].set_title("What share (in %) of other participants in the survey do you think have\n chosen one of the transport modes 'Driving private vehicle' for their daily trip?")
axs[0,0].set_xlabel("Percentage")
axs[0,0].set_ylabel("PDF")
axs[0,0].legend(loc='upper right')
axs[0,0].set_yticks((np.linspace(0,0.07,5)))
#axs[0,0].set_xticks((np.linspace(0,100,5)))


dens_b = stats.gaussian_kde(100-dfb['player.EE'])
n, x_b, _ = axs[0,1].hist((100-dfb['player.EE']),bins=20, density=True, label='Set B', color='#BCEE68', edgecolor='black')
axs[0,1].plot(x_b,dens_b(x_b), label='Set B probability density function',color='green')
axs[0,1].set_title("100% - What share (in %) of other participants in the survey do you think have chosen\n one of the transport modes 'Public Transport, cycling and walking' for their daily trip?")
axs[0,1].set_xlabel("Percentage")
axs[0,1].set_ylabel("PDF")
axs[0,1].legend(loc='upper right')
axs[0,1].set_yticks((np.linspace(0,0.07,5)))
#axs[0,1].set_xticks((np.linspace(0,100,5)))



dens_a = stats.gaussian_kde(dfa['player.PNB'])
n, x_a, _ = axs[1,0].hist(dfa['player.PNB'],bins=20, density=True, label='Set A', color='khaki', edgecolor='black')
axs[1,0].plot(x_a,dens_a(x_a), label='Set A probability density function',color='darkorange')
axs[1,0].set_title("What should be the ideal percentage of people using\n mode 'Private transport' in your town, in your opinion?")
axs[1,0].set_xlabel("Percentage")
axs[1,0].set_ylabel("PDF")
axs[1,0].legend(loc='upper right')
axs[1,0].set_yticks((np.linspace(0,0.07,5)))
#axs[1,0].set_xticks((np.linspace(0,100,5)))


dens_b = stats.gaussian_kde(100-dfb['player.PNB'])
n, x_b, _ = axs[1,1].hist((100-dfb['player.PNB']),bins=20, density=True, label='Set B', color='#BCEE68', edgecolor='black')
axs[1,1].plot(x_b,dens_b(x_b), label='Set B probability density function',color='green')
axs[1,1].set_title("100% - What should be the ideal percentage of people using\n 'Public Transport, cycling and walking' in your town, in your opinion?")
axs[1,1].set_xlabel("Percentage")
axs[1,1].set_ylabel("PDF")
axs[1,1].legend(loc='upper right')
axs[1,1].set_yticks((np.linspace(0,0.07,5)))
#axs[1,1].set_xticks((np.linspace(0,100,5)))


dens_a = stats.gaussian_kde(dfa['player.NE'])
n, x_a, _ = axs[2,0].hist(dfa['player.NE'],bins=20, density=True, label='Set A', color='khaki', edgecolor='black')
axs[2,0].plot(x_a,dens_a(x_a), label='Set A probability density function',color='darkorange')
axs[2,0].set_title("On average, how many participants (in %) do you think\n have chosen 'Private transport' in the previous question?")
axs[2,0].set_xlabel("Percentage")
axs[2,0].set_ylabel("PDF")
axs[2,0].legend(loc='upper right')
axs[2,0].set_yticks((np.linspace(0,0.07,5)))
#axs[2,0].set_xticks((np.linspace(0,100,5)))


dens_b = stats.gaussian_kde(100-dfb['player.NE'])
n, x_b, _ = axs[2,1].hist((100-dfb['player.NE']),bins=20, density=True, label='Set B', color='#BCEE68', edgecolor='black')
axs[2,1].plot(x_b,dens_b(x_b), label='Set B probability density function',color='green')
axs[2,1].set_title("100% - On average, how many participants (in %) do you think have\n chosen 'Public Transport, cycling and walking' in the previous question? ")
axs[2,1].set_xlabel("Percentage")
axs[2,1].set_ylabel("PDF")
axs[2,1].legend(loc='upper right')
axs[2,1].set_yticks((np.linspace(0,0.07,5)))
#axs[2,1].set_xticks((np.linspace(0,100,5)))


plt.tight_layout(pad=2, w_pad=4, h_pad=3)
#plt.savefig('hist_EE_Madrid_.pdf')

plt.show()

# %%
fig, axs = plt.subplots(nrows=4, ncols=2,  figsize=(17, 18))
#fig.suptitle('Social norms in all population', fontsize=30)

dens_a = stats.gaussian_kde(dfa['player.HH'])
n, x_a, _ = axs[0,0].hist(dfa['player.HH'],bins=20, density=True, label='Set A', color='khaki', edgecolor='black')
axs[0,0].plot(x_a,dens_a(x_a), label='Set A probability density function',color='darkorange')
axs[0,0].set_title("Imagine that " + r"$\bf{most}$ "+"of the people answering this survey say they use\n'Driving private vehicle' to “go to work” and " + r"$\bf{most}$ "+"of them think that other\n people should also use 'Driving private vehicle'.\n Which mode would you chose then?")
axs[0,0].set_xlabel("Percentage")
axs[0,0].set_ylabel("PDF")
axs[0,0].legend(loc='upper right')
axs[0,0].set_yticks((np.linspace(0,0.04,5)))

dens_b = stats.gaussian_kde(100-dfb['player.LL'])
n, x_b, _ = axs[0,1].hist((100-dfb['player.LL']),bins=20, density=True, label='Set B', color='#BCEE68', edgecolor='black')
axs[0,1].plot(x_b,dens_b(x_b), label='Set B probability density function',color='green')
axs[0,1].set_title("100% - Imagine that " + r"$\bf{few}$ "+"of the people answering this survey say they use\n'Public Transport, cycling and walking' to “go to work” and " + r"$\bf{few}$ "+"of them think\n that other people should also use 'Public Transport, cycling and walking'.\n Which mode would you chose then?")
axs[0,1].set_xlabel("Percentage")
axs[0,1].set_ylabel("PDF")
axs[0,1].legend(loc='upper right')
axs[0,1].set_yticks((np.linspace(0,0.04,5)))


dens_a = stats.gaussian_kde(dfa['player.HL'])
n, x_a, _ = axs[1,0].hist(dfa['player.HL'],bins=20, density=True, label='Set A', color='khaki', edgecolor='black')
axs[1,0].plot(x_a,dens_a(x_a), label='Set A probability density function',color='darkorange')
axs[1,0].set_title("Imagine that " + r"$\bf{most}$ "+"of the people answering this survey say they use\n'Driving private vehicle' to “go to work” and " + r"$\bf{few}$ "+"of them think that other\n people should also use 'Driving private vehicle'.\n Which mode would you chose then?")
axs[1,0].set_xlabel("Percentage")
axs[1,0].set_ylabel("PDF")
axs[1,0].legend(loc='upper right')
axs[1,0].set_yticks((np.linspace(0,0.04,5)))

dens_b = stats.gaussian_kde(100-dfb['player.LH'])
n, x_b, _ = axs[1,1].hist((100-dfb['player.LH']),bins=20, density=True, label='Set B', color='#BCEE68', edgecolor='black')
axs[1,1].plot(x_b,dens_b(x_b), label='Set B probability density function',color='green')
axs[1,1].set_title("100% - Imagine that " + r"$\bf{few}$ "+"of the people answering this survey say they use \n'Public Transport, cycling and walking' to “go to work” and " + r"$\bf{most}$ "+"of them think\n that other people should also use 'Public Transport, cycling and walking'.\n Which mode would you chose then?")
axs[1,1].set_xlabel("Percentage")
axs[1,1].set_ylabel("PDF")
axs[1,1].legend(loc='upper right')
axs[1,1].set_yticks((np.linspace(0,0.04,5)))

dens_a = stats.gaussian_kde(dfa['player.LH'])
n, x_a, _ = axs[2,0].hist(dfa['player.LH'],bins=20, density=True, label='Set A', color='khaki', edgecolor='black')
axs[2,0].plot(x_a,dens_a(x_a), label='Set A probability density function',color='darkorange')
axs[2,0].set_title("Imagine that " + r"$\bf{few}$ "+"of the people answering this survey say they use\n'Driving private vehicle' to “go to work” and " + r"$\bf{most}$ "+"of them think\n that other people should also use 'Driving private vehicle'.\n Which mode would you chose then?")
axs[2,0].set_xlabel("Percentage")
axs[2,0].set_ylabel("PDF")
axs[2,0].legend(loc='upper right')
axs[2,0].set_yticks((np.linspace(0,0.04,5)))

dens_b = stats.gaussian_kde(100-dfb['player.HL'])
n, x_b, _ = axs[2,1].hist((100-dfb['player.HL']),bins=20, density=True, label='Set B', color='#BCEE68', edgecolor='black')
axs[2,1].plot(x_b,dens_b(x_b), label='Set B probability density function',color='green')
axs[2,1].set_title("100% - Imagine that " + r"$\bf{most}$ "+"of the people answering this survey say they use\n 'Public Transport, cycling and walking' to “go to work” and " + r"$\bf{few}$ "+"of them think\n that other people should also use 'Public Transport, cycling and walking'.\n Which mode would you chose then?")
axs[2,1].set_xlabel("Percentage")
axs[2,1].set_ylabel("PDF")
axs[2,1].legend(loc='upper right')
axs[2,1].set_xticks(np.linspace(0,100,5))
axs[2,1].set_xticklabels(np.linspace(0,100,5)) 
axs[2,1].set_yticks((np.linspace(0,0.04,5)))

dens_a = stats.gaussian_kde(dfa['player.LL'])
n, x_a, _ = axs[3,0].hist(dfa['player.LL'],bins=20, density=True, label='Set A', color='khaki', edgecolor='black')
axs[3,0].plot(x_a,dens_a(x_a), label='Set A probability density function',color='darkorange')
axs[3,0].set_title("Imagine that " + r"$\bf{few}$ "+"of the people answering this survey say they use\n 'Driving private vehicle' to “go to work” and " + r"$\bf{few}$ "+"of them think that other\n people should also use 'Driving private vehicle'.\n Which mode would you chose then?")
axs[3,0].set_xlabel("Percentage")
axs[3,0].set_ylabel("PDF")
axs[3,0].legend(loc='upper right')
#axs[3,0].set_xticklabels(np.linspace(0,100,5)) 
axs[3,0].set_yticks((np.linspace(0,0.04,5)))

dens_b = stats.gaussian_kde(100-dfb['player.HH'])
n, x_b, _ = axs[3,1].hist((100-dfb['player.HH']),bins=20, density=True, label='Set B', color='#BCEE68', edgecolor='black')
axs[3,1].plot(x_b,dens_b(x_b), label='Set B probability density function',color='green')
axs[3,1].set_title("100% - Imagine that " + r"$\bf{most}$ "+"of the people answering this survey say they use\n 'Public Transport, cycling and walking' to “go to work” and " + r"$\bf{most}$ "+ "of them think\n that other people should also use 'Public Transport, cycling and walking'.\n Which mode would you chose then?")
axs[3,1].set_xlabel("Percentage")
axs[3,1].set_ylabel("PDF")
axs[3,1].legend(loc='upper right')
#axs[3,1].set_xticks(np.linspace(0,100,5))
#axs[3,1].set_xticklabels(np.linspace(0,100,5)) 
axs[3,1].set_yticks((np.linspace(0,0.04,5)))

plt.tight_layout(pad=2, w_pad=4, h_pad=3)
#plt.savefig('hist_HL_Madrid_.pdf')

plt.show()

# %%
pd.set_option('display.max_columns', None)
dfa
# Out:
#     Unnamed: 0  participant.id_in_session  mod participant.code  \
# 0            0                          2    2         iu9re9u5
# 1            1                          4    4         76mq2acd
# 2            2                          5    1         n6c69l1z
# 3            3                          8    4         p7eprbp3
# 4            4                         11    3         epujf994
# ..         ...                        ...  ...              ...
# 86         168                        282    2         72nl8nvf
# 87         169                        283    3         ktv4wkpv
# 88         170                        284    4         coxg1hlg
# 89         171                        287    3         pqhakbh7
# 90         172                        288    4         6mrig9en
#
#             participant.time_started  player.inequality_perception  \
# 0   2022-07-18 13:56:52.428815+00:00                             3
# 1   2022-07-18 21:47:35.300273+00:00                             3
# 2   2022-07-18 22:45:11.140948+00:00                             3
# 3   2022-07-18 10:05:54.744504+00:00                             2
# 4   2022-07-18 10:53:49.868989+00:00                             3
# ..                               ...                           ...
# 86  2022-07-18 14:48:10.233811+00:00                             3
# 87  2022-07-18 15:33:52.323538+00:00                             4
# 88  2022-07-18 15:59:22.961901+00:00                             5
# 89  2022-07-19 08:01:45.129683+00:00                             3
# 90  2022-07-18 17:59:54.081962+00:00                             2
#
#    What type of society do you think is Spain today – which diagram comes the closest?  \
# 0                                                   C
# 1                                                   C
# 2                                                   C
# 3                                                   B
# 4                                                   C
# ..                                                ...
# 86                                                  C
# 87                                                  D
# 88                                                  E
# 89                                                  C
# 90                                                  B
#
#     player.inequality_wish  \
# 0                        4
# 1                        4
# 2                        4
# 3                        5
# 4                        4
# ..                     ...
# 86                       4
# 87                       5
# 88                       4
# 89                       5
# 90                       4
#
#    What do you think Spain ought to be like – which would you prefer?  \
# 0                                                   D
# 1                                                   D
# 2                                                   D
# 3                                                   E
# 4                                                   D
# ..                                                ...
# 86                                                  D
# 87                                                  E
# 88                                                  D
# 89                                                  E
# 90                                                  D
#
#     player.income_distribution  \
# 0                            3
# 1                            3
# 2                            2
# 3                            3
# 4                            4
# ..                         ...
# 86                           3
# 87                           3
# 88                           2
# 89                           3
# 90                           3
#
#    How fair do you think the wealth distribution is in your country?  \
# 0                                              Unfair
# 1                                              Unfair
# 2                                                Fair
# 3                                              Unfair
# 4                                         Very unfair
# ..                                                ...
# 86                                             Unfair
# 87                                             Unfair
# 88                                               Fair
# 89                                             Unfair
# 90                                             Unfair
#
#     player.postal_code                          participant._municipality  \
# 0                28028                                  Salamanca, Madrid
# 1                28041                                 Villaverde, Madrid
# 2                28033                                  Hortaleza, Madrid
# 3                28031                          Villa de Vallecas, Madrid
# 4                28039                                     Tetuán, Madrid
# ..                 ...                                                ...
# 86               28004                                     Centro, Madrid
# 87               28924                                    Norte, Alcorcón
# 88               28911  Leganés, Área metropolitana de Madrid y Corred...
# 89               28015                                   Chamberí, Madrid
# 90               28032                                  Vicálvaro, Madrid
#
#    The participant lives in Madrid:  player.driving_license  \
# 0                               Yes                       1
# 1                               Yes                       1
# 2                               Yes                       1
# 3                               Yes                       1
# 4                               Yes                       1
# ..                              ...                     ...
# 86                              Yes                       0
# 87                              Yes                       0
# 88                              Yes                       0
# 89                              Yes                       0
# 90                              Yes                       0
#
#    Do you have a driver license?  player.access_to_car  \
# 0                            Yes                     0
# 1                            Yes                     1
# 2                            Yes                     0
# 3                            Yes                     1
# 4                            Yes                     1
# ..                           ...                   ...
# 86                            No                     2
# 87                            No                     2
# 88                            No                     2
# 89                            No                     1
# 90                            No                     1
#
#    Do you own or have access to a car?  player.car_type  \
# 0                                I own              1.0
# 1     I do not own, but have access to              0.0
# 2                                I own              0.0
# 3     I do not own, but have access to              1.0
# 4     I do not own, but have access to              1.0
# ..                                 ...              ...
# 86             I do not have access to              NaN
# 87             I do not have access to              NaN
# 88             I do not have access to              NaN
# 89    I do not own, but have access to              2.0
# 90    I do not own, but have access to              1.0
#
#    What kind of vehicle do you have access to? If you have access to multiple vehicles choose the one you use the most.  \
# 0                                              Diesel
# 1                                            Gasoline
# 2                                            Gasoline
# 3                                              Diesel
# 4                                              Diesel
# ..                                                ...
# 86                                                  -
# 87                                                  -
# 88                                                  -
# 89                           Hybrid or plug-in hybrid
# 90                                             Diesel
#
#     player.access_to_bike  \
# 0                       2
# 1                       0
# 2                       2
# 3                       0
# 4                       0
# ..                    ...
# 86                      2
# 87                      0
# 88                      0
# 89                      1
# 90                      0
#
#    Do you own or have access to a bike (electric or regular)?  \
# 0                             I do not have access to
# 1                                               I own
# 2                             I do not have access to
# 3                                               I own
# 4                                               I own
# ..                                                ...
# 86                            I do not have access to
# 87                                              I own
# 88                                              I own
# 89                   I do not own, but have access to
# 90                                              I own
#
#     player.access_to_motorbyke Do you own or have access to a motorbyke?  \
# 0                            2                   I do not have access to
# 1                            2                   I do not have access to
# 2                            2                   I do not have access to
# 3                            2                   I do not have access to
# 4                            2                   I do not have access to
# ..                         ...                                       ...
# 86                           2                   I do not have access to
# 87                           2                   I do not have access to
# 88                           2                   I do not have access to
# 89                           2                   I do not have access to
# 90                           2                   I do not have access to
#
#     player.access_to_scooter Do you own or have access to a e-scooter?  \
# 0                          2                   I do not have access to
# 1                          2                   I do not have access to
# 2                          2                   I do not have access to
# 3                          2                   I do not have access to
# 4                          2                   I do not have access to
# ..                       ...                                       ...
# 86                         2                   I do not have access to
# 87                         1          I do not own, but have access to
# 88                         2                   I do not have access to
# 89                         2                   I do not have access to
# 90                         1          I do not own, but have access to
#
#     player.employ_status What is your employment status?  \
# 0                      2                         Student
# 1                      0                Full-time worker
# 2                      0                Full-time worker
# 3                      0                Full-time worker
# 4                      0                Full-time worker
# ..                   ...                             ...
# 86                     2                         Student
# 87                     2                         Student
# 88                     2                         Student
# 89                     1                Part-time worker
# 90                     4                      Unemployed
#
#    player.trip_destination  player.trip_purpose  \
# 0                   Madrid                    1
# 1                   GETAFE                    0
# 2                  Pozuelo                    0
# 3      Madrid (Las Tablas)                    0
# 4                   Úbeda                     5
# ..                     ...                  ...
# 86                  Madrid                    4
# 87               Gimnasio                     6
# 88                  Getafe                    2
# 89                 Leganés                    1
# 90                  Madrid                    1
#
#    What is the purpose/destination of this trip? player.trip_other  \
# 0                                Education place               NaN
# 1                                      Workplace               NaN
# 2                                      Workplace               NaN
# 3                                      Workplace               NaN
# 4                         Visit family or friend               NaN
# ..                                           ...               ...
# 86                           Errands or shopping               NaN
# 87       Leisure activity (cultural, sport, etc)               NaN
# 88           Trip within my job/for job purposes               NaN
# 89                               Education place               NaN
# 90                               Education place               NaN
#
#     player.trip_moment At what time of the day do you typically travel?  \
# 0                    0                                          morning
# 1                    0                                          morning
# 2                    0                                          morning
# 3                    0                                          morning
# 4                    2                                          evening
# ..                 ...                                              ...
# 86                   2                                          evening
# 87                   2                                          evening
# 88                   0                                          morning
# 89                   1                                        afternoon
# 90                   0                                          morning
#
#     player.trip_mode  \
# 0                  2
# 1                  0
# 2                  0
# 3                  4
# 4                  4
# ..               ...
# 86                 3
# 87                 3
# 88                 3
# 89                 4
# 90                 4
#
#    By which mode do you travel with during this trip? If you travel with multiple modes choose the mode that takes you the longest time.  \
# 0                                                 Bus
# 1                                Private car (driver)
# 2                                Private car (driver)
# 3                                               Train
# 4                                               Train
# ..                                                ...
# 86                          Metro, tram or light rail
# 87                          Metro, tram or light rail
# 88                          Metro, tram or light rail
# 89                                              Train
# 90                                              Train
#
#    player.mode_other  player.trip_traffic  \
# 0                NaN                    1
# 1                NaN                    1
# 2                NaN                    2
# 3                NaN                    1
# 4                NaN                    1
# ..               ...                  ...
# 86               NaN                    1
# 87               NaN                    1
# 88               NaN                    1
# 89               NaN                    1
# 90               NaN                    0
#
#    How are the traffic conditions normally on the trip?  player.trip_time  \
# 0                                  Somewhat congested                   1
# 1                                  Somewhat congested                   0
# 2                              Little or no congested                   1
# 3                                  Somewhat congested                   2
# 4                                  Somewhat congested                   4
# ..                                                ...                 ...
# 86                                 Somewhat congested                   0
# 87                                 Somewhat congested                   0
# 88                                 Somewhat congested                   0
# 89                                 Somewhat congested                   1
# 90                                  Heavily congested                   3
#
#    What is the approximate travel time of this trip (one way)?  \
# 0                                       20-39 minutes
# 1                                       10-19 minutes
# 2                                       20-39 minutes
# 3                                       40-59 minutes
# 4                                   more than 2 hours
# ..                                                ...
# 86                                      10-19 minutes
# 87                                      10-19 minutes
# 88                                      10-19 minutes
# 89                                      20-39 minutes
# 90                                          1-2 hours
#
#     player.trip_cost  \
# 0                  0
# 1                  1
# 2                  2
# 3                  1
# 4                  5
# ..               ...
# 86                 0
# 87                 2
# 88                 0
# 89                 0
# 90                 3
#
#    What is the approximate cost of this trip (fuel, road tolls, parking, ticket price etc.), one way? If you are traveling by public transport and have a period ticket, please consider the average price per trip.  \
# 0                                     less than 1 EUR
# 1                                           1-2.5 EUR
# 2                                        2.5-4.99 EUR
# 3                                           1-2.5 EUR
# 4                                    More than 20 EUR
# ..                                                ...
# 86                                    less than 1 EUR
# 87                                       2.5-4.99 EUR
# 88                                    less than 1 EUR
# 89                                    less than 1 EUR
# 90                                         5-9.99 EUR
#
#     player.trip_alternative_mode  \
# 0                              1
# 1                              1
# 2                              4
# 3                              0
# 4                              1
# ..                           ...
# 86                            11
# 87                             0
# 88                             2
# 89                             1
# 90                             0
#
#    If you were to make this trip using a different mode of travel than your usual mode, which would be the best alternative?  \
# 0                             Private car (passenger)
# 1                             Private car (passenger)
# 2                                               Train
# 3                                Private car (driver)
# 4                             Private car (passenger)
# ..                                                ...
# 86                   I have no available alternatives
# 87                               Private car (driver)
# 88                                                Bus
# 89                            Private car (passenger)
# 90                               Private car (driver)
#
#     player.trip_alternative_rate   How would you rate your alternative?  \
# 0                              2      Much worse than my current choice
# 1                              1  Somewhat worse than my current choice
# 2                              2      Much worse than my current choice
# 3                              0    Almost as good as my current choice
# 4                              0    Almost as good as my current choice
# ..                           ...                                    ...
# 86                             3                          I do not know
# 87                             1  Somewhat worse than my current choice
# 88                             2      Much worse than my current choice
# 89                             2      Much worse than my current choice
# 90                             0    Almost as good as my current choice
#
#     player.trip_alternative_justification  player.control_question  \
# 0                                     NaN                        3
# 1                                     NaN                        3
# 2                                     NaN                        3
# 3                                     NaN                        3
# 4                                     NaN                        3
# ..                                    ...                      ...
# 86                                    NaN                        3
# 87                                    NaN                        3
# 88                                    NaN                        3
# 89                                    NaN                        3
# 90                                    NaN                        3
#
#    Answer to control question:  player.alternative1  \
# 0                      Correct                    4
# 1                      Correct                    5
# 2                      Correct                    5
# 3                      Correct                    4
# 4                      Correct                    4
# ..                         ...                  ...
# 86                     Correct                    2
# 87                     Correct                    5
# 88                     Correct                    5
# 89                     Correct                    4
# 90                     Correct                    5
#
#                                         Alternative 1  player.alternative2  \
# 0                                Investments in roads                    2
# 1   Investments in public transport, walking and c...                    4
# 2   Investments in public transport, walking and c...                    4
# 3                                Investments in roads                    5
# 4                                Investments in roads                    5
# ..                                                ...                  ...
# 86                                Equal cash transfer                    1
# 87  Investments in public transport, walking and c...                    4
# 88  Investments in public transport, walking and c...                    4
# 89                               Investments in roads                    5
# 90  Investments in public transport, walking and c...                    4
#
#                                         Alternative 2  player.alternative3  \
# 0                                 Equal cash transfer                    5
# 1                                Investments in roads                    2
# 2                                Investments in roads                    1
# 3   Investments in public transport, walking and c...                    3
# 4   Investments in public transport, walking and c...                    1
# ..                                                ...                  ...
# 86                                     General budget                    3
# 87                               Investments in roads                    3
# 88                               Investments in roads                    1
# 89  Investments in public transport, walking and c...                    3
# 90                               Investments in roads                    1
#
#                                         Alternative 3  player.alternative4  \
# 0   Investments in public transport, walking and c...                    1
# 1                                 Equal cash transfer                    3
# 2                                      General budget                    3
# 3               Cash transfer for low-income citizens                    1
# 4                                      General budget                    3
# ..                                                ...                  ...
# 86              Cash transfer for low-income citizens                    5
# 87              Cash transfer for low-income citizens                    2
# 88                                     General budget                    3
# 89              Cash transfer for low-income citizens                    2
# 90                                     General budget                    3
#
#                                         Alternative 4  player.alternative5  \
# 0                                      General budget                    3
# 1               Cash transfer for low-income citizens                    1
# 2               Cash transfer for low-income citizens                    2
# 3                                      General budget                    2
# 4               Cash transfer for low-income citizens                    2
# ..                                                ...                  ...
# 86  Investments in public transport, walking and c...                    4
# 87                                Equal cash transfer                    1
# 88              Cash transfer for low-income citizens                    2
# 89                                Equal cash transfer                    1
# 90              Cash transfer for low-income citizens                    2
#
#                             Alternative 5  1_policy_choice  \
# 0   Cash transfer for low-income citizens                1
# 1                          General budget                1
# 2                     Equal cash transfer                2
# 3                     Equal cash transfer                3
# 4                     Equal cash transfer                2
# ..                                    ...              ...
# 86                   Investments in roads                2
# 87                         General budget                1
# 88                    Equal cash transfer                2
# 89                         General budget                1
# 90                    Equal cash transfer                2
#
#     1_What is your preferred policy type?  1_Price_UR_A  \
# 0                                       A             2
# 1                                       A             4
# 2                                       B             3
# 3   None of them, keep the current system             2
# 4                                       B             3
# ..                                    ...           ...
# 86                                      B             4
# 87                                      A             3
# 88                                      B             4
# 89                                      A             1
# 90                                      B             2
#
#    1_A_Price in urban areas, rush hour  1_Price_UN_A  \
# 0                             0.20 EUR             2
# 1                             0.50 EUR             4
# 2                             0.40 EUR             3
# 3                             0.20 EUR             1
# 4                             0.40 EUR             3
# ..                                 ...           ...
# 86                            0.50 EUR             2
# 87                            0.40 EUR             1
# 88                            0.50 EUR             4
# 89                            0.10 EUR             1
# 90                            0.20 EUR             2
#
#    1_A_Price in urban areas, outside rush hour  1_Price_O_A  \
# 0                                     0.20 EUR            2
# 1                                     0.50 EUR            4
# 2                                     0.40 EUR            4
# 3                                     0.10 EUR            1
# 4                                     0.40 EUR            3
# ..                                         ...          ...
# 86                                    0.20 EUR            2
# 87                                    0.10 EUR            1
# 88                                    0.50 EUR            4
# 89                                    0.10 EUR            1
# 90                                    0.20 EUR            2
#
#    1_A_Price outside urban areas  1_EV_A 1_A_Price for electric vehicles  \
# 0                       0.02 EUR       2                        0.02 EUR
# 1                       0.05 EUR       3                        0.03 EUR
# 2                       0.05 EUR       3                        0.03 EUR
# 3                       0.01 EUR       3                        0.03 EUR
# 4                       0.03 EUR       3                        0.03 EUR
# ..                           ...     ...                             ...
# 86                      0.02 EUR       4                        0.05 EUR
# 87                      0.01 EUR       4                        0.05 EUR
# 88                      0.05 EUR       3                        0.03 EUR
# 89                      0.01 EUR       4                        0.05 EUR
# 90                      0.02 EUR       2                        0.02 EUR
#
#     1_Revenue_A                                 1_A_Use of revenue  \
# 0             3              Cash transfer for low-income citizens
# 1             5  Investments in public transport, walking and c...
# 2             4                               Investments in roads
# 3             2                                Equal cash transfer
# 4             1                                     General budget
# ..          ...                                                ...
# 86            3              Cash transfer for low-income citizens
# 87            4                               Investments in roads
# 88            3              Cash transfer for low-income citizens
# 89            2                                Equal cash transfer
# 90            1                                     General budget
#
#     1_Price_UR_B 1_B_Price in urban areas, rush hour  1_Price_UN_B  \
# 0              3                            0.40 EUR             2
# 1              4                            0.50 EUR             4
# 2              4                            0.50 EUR             3
# 3              4                            0.50 EUR             1
# 4              3                            0.40 EUR             3
# ..           ...                                 ...           ...
# 86             2                            0.20 EUR             2
# 87             2                            0.20 EUR             1
# 88             1                            0.10 EUR             1
# 89             1                            0.10 EUR             1
# 90             2                            0.20 EUR             2
#
#    1_B_Price in urban areas, outside rush hour  1_Price_O_B  \
# 0                                     0.20 EUR            4
# 1                                     0.50 EUR            4
# 2                                     0.40 EUR            2
# 3                                     0.10 EUR            3
# 4                                     0.40 EUR            3
# ..                                         ...          ...
# 86                                    0.20 EUR            3
# 87                                    0.10 EUR            4
# 88                                    0.10 EUR            1
# 89                                    0.10 EUR            1
# 90                                    0.20 EUR            2
#
#    1_B_Price outside urban areas  1_EV_B 1_B_Price for electric vehicles  \
# 0                       0.05 EUR       2                        0.02 EUR
# 1                       0.05 EUR       3                        0.03 EUR
# 2                       0.02 EUR       2                        0.02 EUR
# 3                       0.03 EUR       4                        0.05 EUR
# 4                       0.03 EUR       4                        0.05 EUR
# ..                           ...     ...                             ...
# 86                      0.03 EUR       4                        0.05 EUR
# 87                      0.05 EUR       3                        0.03 EUR
# 88                      0.01 EUR       2                        0.02 EUR
# 89                      0.01 EUR       1                        0.01 EUR
# 90                      0.02 EUR       2                        0.02 EUR
#
#     1_Revenue_B                                 1_B_Use of revenue  \
# 0             5  Investments in public transport, walking and c...
# 1             2                                Equal cash transfer
# 2             5  Investments in public transport, walking and c...
# 3             1                                     General budget
# 4             5  Investments in public transport, walking and c...
# ..          ...                                                ...
# 86            1                                     General budget
# 87            3              Cash transfer for low-income citizens
# 88            5  Investments in public transport, walking and c...
# 89            3              Cash transfer for low-income citizens
# 90            4                               Investments in roads
#
#     2_policy_choice  2_What is your preferred policy type?  2_Price_UR_A  \
# 0                 1                                      A             3
# 1                 2                                      B             4
# 2                 2                                      B             2
# 3                 2                                      B             3
# 4                 2                                      B             3
# ..              ...                                    ...           ...
# 86                3  None of them, keep the current system             2
# 87                1                                      A             2
# 88                1                                      A             2
# 89                2                                      B             3
# 90                1                                      A             3
#
#    2_A_Price in urban areas, rush hour  2_Price_UN_A  \
# 0                             0.40 EUR             3
# 1                             0.50 EUR             4
# 2                             0.20 EUR             1
# 3                             0.40 EUR             3
# 4                             0.40 EUR             2
# ..                                 ...           ...
# 86                            0.20 EUR             2
# 87                            0.20 EUR             2
# 88                            0.20 EUR             2
# 89                            0.40 EUR             1
# 90                            0.40 EUR             3
#
#    2_A_Price in urban areas, outside rush hour  2_Price_O_A  \
# 0                                     0.40 EUR            2
# 1                                     0.50 EUR            1
# 2                                     0.10 EUR            2
# 3                                     0.40 EUR            3
# 4                                     0.20 EUR            4
# ..                                         ...          ...
# 86                                    0.20 EUR            2
# 87                                    0.20 EUR            2
# 88                                    0.20 EUR            3
# 89                                    0.10 EUR            1
# 90                                    0.40 EUR            3
#
#    2_A_Price outside urban areas  2_EV_A 2_A_Price for electric vehicles  \
# 0                       0.02 EUR       4                        0.05 EUR
# 1                       0.01 EUR       1                        0.01 EUR
# 2                       0.02 EUR       3                        0.03 EUR
# 3                       0.03 EUR       1                        0.01 EUR
# 4                       0.05 EUR       2                        0.02 EUR
# ..                           ...     ...                             ...
# 86                      0.02 EUR       2                        0.02 EUR
# 87                      0.02 EUR       3                        0.03 EUR
# 88                      0.03 EUR       2                        0.02 EUR
# 89                      0.01 EUR       4                        0.05 EUR
# 90                      0.03 EUR       3                        0.03 EUR
#
#     2_Revenue_A                                 2_A_Use of revenue  \
# 0             2                                Equal cash transfer
# 1             3              Cash transfer for low-income citizens
# 2             2                                Equal cash transfer
# 3             2                                Equal cash transfer
# 4             5  Investments in public transport, walking and c...
# ..          ...                                                ...
# 86            2                                Equal cash transfer
# 87            4                               Investments in roads
# 88            1                                     General budget
# 89            4                               Investments in roads
# 90            5  Investments in public transport, walking and c...
#
#     2_Price_UR_B 2_B_Price in urban areas, rush hour  2_Price_UN_B  \
# 0              4                            0.50 EUR             3
# 1              2                            0.20 EUR             2
# 2              3                            0.40 EUR             3
# 3              2                            0.20 EUR             1
# 4              2                            0.20 EUR             2
# ..           ...                                 ...           ...
# 86             2                            0.20 EUR             2
# 87             3                            0.40 EUR             3
# 88             4                            0.50 EUR             4
# 89             2                            0.20 EUR             1
# 90             1                            0.10 EUR             1
#
#    2_B_Price in urban areas, outside rush hour  2_Price_O_B  \
# 0                                     0.40 EUR            3
# 1                                     0.20 EUR            3
# 2                                     0.40 EUR            3
# 3                                     0.10 EUR            2
# 4                                     0.20 EUR            2
# ..                                         ...          ...
# 86                                    0.20 EUR            2
# 87                                    0.40 EUR            3
# 88                                    0.50 EUR            1
# 89                                    0.10 EUR            4
# 90                                    0.10 EUR            1
#
#    2_B_Price outside urban areas  2_EV_B 2_B_Price for electric vehicles  \
# 0                       0.03 EUR       2                        0.02 EUR
# 1                       0.03 EUR       2                        0.02 EUR
# 2                       0.03 EUR       1                        0.01 EUR
# 3                       0.02 EUR       3                        0.03 EUR
# 4                       0.02 EUR       2                        0.02 EUR
# ..                           ...     ...                             ...
# 86                      0.02 EUR       3                        0.03 EUR
# 87                      0.03 EUR       3                        0.03 EUR
# 88                      0.01 EUR       1                        0.01 EUR
# 89                      0.05 EUR       3                        0.03 EUR
# 90                      0.01 EUR       4                        0.05 EUR
#
#     2_Revenue_B                     2_B_Use of revenue  3_policy_choice  \
# 0             4                   Investments in roads                1
# 1             1                         General budget                1
# 2             2                    Equal cash transfer                2
# 3             2                    Equal cash transfer                2
# 4             3  Cash transfer for low-income citizens                1
# ..          ...                                    ...              ...
# 86            4                   Investments in roads                1
# 87            1                         General budget                1
# 88            3  Cash transfer for low-income citizens                1
# 89            3  Cash transfer for low-income citizens                2
# 90            2                    Equal cash transfer                1
#
#    3_What is your preferred policy type?  3_Price_UR_A  \
# 0                                      A             1
# 1                                      A             2
# 2                                      B             2
# 3                                      B             1
# 4                                      A             1
# ..                                   ...           ...
# 86                                     A             4
# 87                                     A             4
# 88                                     A             2
# 89                                     B             4
# 90                                     A             3
#
#    3_A_Price in urban areas, rush hour  3_Price_UN_A  \
# 0                             0.10 EUR             1
# 1                             0.20 EUR             2
# 2                             0.20 EUR             2
# 3                             0.10 EUR             1
# 4                             0.10 EUR             1
# ..                                 ...           ...
# 86                            0.50 EUR             4
# 87                            0.50 EUR             4
# 88                            0.20 EUR             2
# 89                            0.50 EUR             4
# 90                            0.40 EUR             3
#
#    3_A_Price in urban areas, outside rush hour  3_Price_O_A  \
# ...
# 0              prefer not to say              3
# 1                    20k-30k EUR              1
# 2              less than 10k EUR              4
# 3                    20k-30k EUR              4
# 4              less than 10k EUR              4
# ..                           ...            ...
# 86             prefer not to say              4
# 87             prefer not to say              4
# 88             prefer not to say              4
# 89             less than 10k EUR              4
# 90             less than 10k EUR              4
#
#     How many people does your household have including you?  player.children  \
# 0                                                   3                      0
# 1                                                   1                      0
# 2                                                   4                      0
# 3                                                   4                      0
# 4                                                   4                      0
# ..                                                ...                    ...
# 86                                                  4                      1
# 87                                                  4                      0
# 88                                                  4                      0
# 89                                                  4                      0
# 90                                                  4                      0
#
#     How many children under the age of 15 live with you?  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ..                                                ...
# 86                                                  1
# 87                                                  0
# 88                                                  0
# 89                                                  0
# 90                                                  0
#
#     player.trust_parlament  \
# 0                        1
# 1                        3
# 2                        4
# 3                        4
# 4                        4
# ..                     ...
# 86                       1
# 87                       3
# 88                       3
# 89                       3
# 90                       4
#
#    How much do you personally trust the following institutions from 1 to 7, where 1 means ‘No trust at all’ and 7 means ‘Trust compltely’? Parlament:   \
# 0                                                   1
# 1                                                   3
# 2                                                   4
# 3                                                   4
# 4                                                   4
# ..                                                ...
# 86                                                  1
# 87                                                  3
# 88                                                  3
# 89                                                  3
# 90                                                  4
#
#     player.trust_county County council:  player.trust_municipality  \
# 0                     1               1                          1
# 1                     4               4                          4
# 2                     4               4                          5
# 3                     6               6                          5
# 4                     7               7                          6
# ..                  ...             ...                        ...
# 86                    1               1                          1
# 87                    3               3                          5
# 88                    4               4                          4
# 89                    4               4                          3
# 90                    1               1                          2
#
#    Municipal council  player.trust_government Government:  \
# 0                  1                        1           1
# 1                  4                        4           4
# 2                  5                        2           2
# 3                  5                        2           2
# 4                  6                        1           1
# ..               ...                      ...         ...
# 86                 1                        1           1
# 87                 5                        3           3
# 88                 4                        4           4
# 89                 3                        3           3
# 90                 2                        4           4
#
#     player.trust_politicians National politicians:  player.trust_parties  \
# 0                          1                     1                     1
# 1                          3                     3                     2
# 2                          3                     3                     3
# 3                          3                     3                     2
# 4                          5                     5                     4
# ..                       ...                   ...                   ...
# 86                         1                     1                     1
# 87                         2                     2                     2
# 88                         1                     1                     1
# 89                         1                     1                     1
# 90                         2                     2                     3
#
#    Political parties:   player.vote  \
# 0                    1           13
# 1                    2            9
# 2                    3            1
# 3                    2            1
# 4                    4            1
# ..                 ...          ...
# 86                   1            0
# 87                   2           13
# 88                   1           13
# 89                   1           12
# 90                   3            9
#
#    Which political party you voted for in the last election?  \
# 0                               prefiero no responder
# 1                                             MP-EQUO
# 2                                     Partido Popular
# 3                                     Partido Popular
# 4                                     Partido Popular
# ..                                                ...
# 86                                               PSOE
# 87                              prefiero no responder
# 88                              prefiero no responder
# 89                                       otro partido
# 90                                            MP-EQUO
#
#     player.air_pollution  \
# 0                      3
# 1                      2
# 2                      5
# 3                      3
# 4                      6
# ..                   ...
# 86                     3
# 87                     6
# 88                     7
# 89                     3
# 90                     6
#
#    How much do you agree with the following statements from 1 to 7, where 1 means ‘I completely disagree’ and 7 means ‘I completely agree’? Air pollution derived by cars is one of the major causes of premature death in Europe:  \
# 0                                                   3
# 1                                                   2
# 2                                                   5
# 3                                                   3
# 4                                                   6
# ..                                                ...
# 86                                                  3
# 87                                                  6
# 88                                                  7
# 89                                                  3
# 90                                                  6
#
#     player.road_pricing  \
# 0                     3
# 1                     4
# 2                     6
# 3                     5
# 4                     3
# ..                  ...
# 86                    4
# 87                    5
# 88                    5
# 89                    6
# 90                    6
#
#    The introduction of policies such as road pricing will alleviate congestion problems:  \
# 0                                                   3
# 1                                                   4
# 2                                                   6
# 3                                                   5
# 4                                                   3
# ..                                                ...
# 86                                                  4
# 87                                                  5
# 88                                                  5
# 89                                                  6
# 90                                                  6
#
#     player.revenues  \
# 0                 2
# 1                 5
# 2                 6
# 3                 2
# 4                 4
# ..              ...
# 86                3
# 87                2
# 88                6
# 89                2
# 90                7
#
#    Revenues collected through taxes are used to create a well-functioning welfare state and society:  \
# 0                                                   2
# 1                                                   5
# 2                                                   6
# 3                                                   2
# 4                                                   4
# ..                                                ...
# 86                                                  3
# 87                                                  2
# 88                                                  6
# 89                                                  2
# 90                                                  7
#
#     player.tax  \
# 0            3
# 1            3
# 2            6
# 3            5
# 4            5
# ..         ...
# 86           4
# 87           4
# 88           7
# 89           4
# 90           6
#
#    Tax revenues should be used to help those who are more in need:  \
# 0                                                   3
# 1                                                   3
# 2                                                   6
# 3                                                   5
# 4                                                   5
# ..                                                ...
# 86                                                  4
# 87                                                  4
# 88                                                  7
# 89                                                  4
# 90                                                  6
#
#                                       player.comments
# 0                                             gracias
# 1                                        Buen trabajo
# 2                                       todo correcto
# 3                                                   .
# 4   Espero que no utilicen estos datos para aplica...
# ..                                                ...
# 86                                     muchas gracias
# 87                Hay demasiadas preguntas similares
# 88                                                  .
# 89                                                  .
# 90                                                 :)
#
# [91 rows x 245 columns]
